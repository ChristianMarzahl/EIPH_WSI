# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'marzahl' #'exact'
configuration.password = '#####' #'exact'
configuration.host = "https://exact.cs.fau.de" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %%
annotation_types_points = {}

for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.id] = annotation_type

annotation_types_points
# Out:
# {384: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 384,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  385: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 385,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 1,
#   'vector_type': 1},
#  386: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 386,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 2,
#   'vector_type': 1},
#  387: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 387,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 3,
#   'vector_type': 1},
#  388: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 388,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 4,
#   'vector_type': 1},
#  389: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 389,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 5,
#   'vector_type': 1},
#  393: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 393,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 6,
#   'vector_type': 1},
#  394: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 394,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 7,
#   'vector_type': 1},
#  395: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 395,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 8,
#   'vector_type': 1},
#  396: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 396,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 9,
#   'vector_type': 1},
#  397: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 397,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 10,
#   'vector_type': 1},
#  398: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 398,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 11,
#   'vector_type': 1},
#  399: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 399,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  400: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 400,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  401: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 401,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  402: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 402,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  403: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 403,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  404: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 404,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  405: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 405,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  406: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 406,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  407: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 407,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  408: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 408,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  409: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 409,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  410: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 410,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  411: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 411,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotations = []

for image_set_name in tqdm(["CCMCT_2.0HT", "CCMCT_Aperio", "CCMCT_Axio", "CCMCT_S210", 
                       "Cyto_2.0HT", "Cyto_Aperio", "Cyto_Axio", "Cyto_S210"]):
    
    scanner = image_set_name.split("_")[1]
    image_set = image_sets_api.list_image_sets(name=image_set_name, expand="product_set,product_set.annotationtype_set").results[0]

    for image_id in image_set.images:

        image = images_api.retrieve_image(id=image_id)
        
        image_width, image_height = image.width, image.height

        for anno in annotations_api.list_annotations(image=image_id, pagination=False, # BoundBox ID
                                                     deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:

            image_type = "CCMCT" if "CCMCT" in image_set_name else "Cyto"
            
            if anno.annotation_type in annotation_types_points:
            
                anno.annotation_type = annotation_types_points[anno.annotation_type]
                annotations.append([scanner, image.id, image.name, image_type, image_width, image_height, 
                                    anno.id, anno.vector, anno.unique_identifier, anno.annotation_type.id, 
                                    anno.annotation_type.name])


annotations = pd.DataFrame(annotations, columns=["scanner", "image_id", "image_name", "image_type", "image_width", "image_height",
                                                 "id", "vector", "unique_identifier", "annotation_type", "type_name"])
annotations.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:18<00:00,  2.36s/it]
#   scanner  image_id               image_name image_type  image_width  \
# 0   2.0HT     10410  N2_CCMCT_380609B_1.ndpi      CCMCT       147456
# 1   2.0HT     10410  N2_CCMCT_380609B_1.ndpi      CCMCT       147456
# 2   2.0HT     10410  N2_CCMCT_380609B_1.ndpi      CCMCT       147456
# 3   2.0HT     10410  N2_CCMCT_380609B_1.ndpi      CCMCT       147456
# 4   2.0HT     10410  N2_CCMCT_380609B_1.ndpi      CCMCT       147456
#
#    image_height       id                                             vector  \
# 0        107008  2755406  {'x1': 20354, 'x2': 20408, 'y1': 16752, 'y2': ...
# 1        107008  2755407  {'x1': 20256, 'x2': 20310, 'y1': 35448, 'y2': ...
# 2        107008  2755408  {'x1': 20445, 'x2': 20499, 'y1': 54139, 'y2': ...
# 3        107008  2755409  {'x1': 26495, 'x2': 26549, 'y1': 71854, 'y2': ...
# 4        107008  2755410  {'x1': 35443, 'x2': 35497, 'y1': 90091, 'y2': ...
#
#                       unique_identifier  annotation_type type_name
# 0  95183f6e-0a00-4de4-9c97-fedfec655a27              384        L0
# 1  cc3def2b-5631-4619-ab08-51f2a69c667d              385        L1
# 2  2d3de917-e55a-470f-8af2-10eb49b69687              386        L2
# 3  611f9d35-6cdb-42ef-bc38-2f44c9aaa257              387        L3
# 4  bf3ef0d3-5153-4693-96ba-96047cb3ae24              388        L4

# %%
annotations.to_csv("GT.csv", index=False)

# %%
df = annotations[(annotations["image_type"] == "CCMCT") & 
                    (annotations["type_name"] == "L20")]

df
# Out:
#     scanner  image_id               image_name image_type  image_width  \
# 20    2.0HT     10410  N2_CCMCT_380609B_1.ndpi      CCMCT       147456
# 45    2.0HT     10404  N2_CCMCT_518711B_1.ndpi      CCMCT       122880
# 69    2.0HT     10402  N2_CCMCT_183715A_1.ndpi      CCMCT        86016
# 139  Aperio     10416    A_CCMCT_518711B_1.svs      CCMCT       107999
# 164  Aperio     10415    A_CCMCT_380609B_1.svs      CCMCT       125999
# 188  Aperio     10401    A_CCMCT_183715A_1.svs      CCMCT        77399
# 282    Axio     10412    Z_CCMCT_518711B_1.tif      CCMCT       119809
# 306    Axio     10409    Z_CCMCT_183715A_1.tif      CCMCT        85167
# 376    S210     10413  N1_CCMCT_518711B_1.ndpi      CCMCT       122880
# 401    S210     10411  N1_CCMCT_380609B_1.ndpi      CCMCT       153600
# 425    S210     10408  N1_CCMCT_183715A_1.ndpi      CCMCT        96000
#
#      image_height       id                                             vector  \
# 20         107008  2755426  {'x1': 128606, 'x2': 128660, 'y1': 16173, 'y2'...
# 45          96768  2755451  {'x1': 100721, 'x2': 100775, 'y1': 14803, 'y2'...
# 69          75008  2755476  {'x1': 71178, 'x2': 71232, 'y1': 10794, 'y2': ...
# 139         83794  2755301  {'x1': 88792, 'x2': 88842, 'y1': 13945, 'y2': ...
# 164         89356  2755326  {'x1': 112217, 'x2': 112267, 'y1': 12091, 'y2'...
# 188         66558  2755351  {'x1': 63177, 'x2': 63227, 'y1': 9866, 'y2': 9...
# 282         93153  2755576  {'x1': 98936, 'x2': 98992, 'y1': 13460, 'y2': ...
# 306         72527  2755601  {'x1': 70670, 'x2': 70726, 'y1': 8618, 'y2': 8...
# 376         98560  2755676  {'x1': 102275, 'x2': 102331, 'y1': 17241, 'y2'...
# 401        112640  2755701  {'x1': 130955, 'x2': 131011, 'y1': 18371, 'y2'...
# 425         84480  2755726  {'x1': 75826, 'x2': 75882, 'y1': 17232, 'y2': ...
#
#                         unique_identifier  annotation_type type_name
# 20   1f8ca805-a23e-4eec-8aad-8bec244fc890              407       L20
# 45   efbb7806-adfc-4f92-be3a-208391499fc1              407       L20
# 69   294c4a75-4ba2-444f-9792-8f4ba22549c5              407       L20
# 139  efbb7806-adfc-4f92-be3a-208391499fc1              407       L20
# 164  1f8ca805-a23e-4eec-8aad-8bec244fc890              407       L20
# 188  294c4a75-4ba2-444f-9792-8f4ba22549c5              407       L20
# 282  efbb7806-adfc-4f92-be3a-208391499fc1              407       L20
# 306  294c4a75-4ba2-444f-9792-8f4ba22549c5              407       L20
# 376  efbb7806-adfc-4f92-be3a-208391499fc1              407       L20
# 401  1f8ca805-a23e-4eec-8aad-8bec244fc890              407       L20
# 425  294c4a75-4ba2-444f-9792-8f4ba22549c5              407       L20

# %%
annotations_api.list_annotations(image=10410, pagination=False, deleted=False, fields="annotation_type,id,image,vector,unique_identifier,deleted").results
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755406,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '95183f6e-0a00-4de4-9c97-fedfec655a27',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 20354, 'x2': 20408, 'y1': 16752, 'y2': 16806},
#   'verified_by_user': None},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755407,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'cc3def2b-5631-4619-ab08-51f2a69c667d',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 20256, 'x2': 20310, 'y1': 35448, 'y2': 35502},
#   'verified_by_user': None},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755408,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '2d3de917-e55a-470f-8af2-10eb49b69687',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 20445, 'x2': 20499, 'y1': 54139, 'y2': 54193},
#   'verified_by_user': None},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755409,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '611f9d35-6cdb-42ef-bc38-2f44c9aaa257',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 26495, 'x2': 26549, 'y1': 71854, 'y2': 71908},
#   'verified_by_user': None},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755410,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'bf3ef0d3-5153-4693-96ba-96047cb3ae24',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 35443, 'x2': 35497, 'y1': 90091, 'y2': 90145},
#   'verified_by_user': None},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755411,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'e0765891-b4ff-4eec-9443-77a37c32ae76',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 46848, 'x2': 46902, 'y1': 16685, 'y2': 16739},
#   'verified_by_user': None},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755412,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '2331e98a-3cd0-44c5-bf5a-a57ce20d37f2',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 48615, 'x2': 48669, 'y1': 35168, 'y2': 35222},
#   'verified_by_user': None},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755413,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'a7a9941f-7307-4276-9017-22828fc8013c',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 43440, 'x2': 43494, 'y1': 54272, 'y2': 54326},
#   'verified_by_user': None},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755414,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '7d35c9a8-6f0b-4fb8-ac47-fbb8352eb0c3',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 47740, 'x2': 47794, 'y1': 73824, 'y2': 73878},
#   'verified_by_user': None},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755415,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'e1dfa3c3-28bc-4d12-9a3a-37b3b77746bc',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 46025, 'x2': 46079, 'y1': 91334, 'y2': 91388},
#   'verified_by_user': None},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755416,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '4a65486b-11af-4e75-bf9a-cb1dea43c15f',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 73782, 'x2': 73836, 'y1': 16584, 'y2': 16638},
#   'verified_by_user': None},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755417,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'ce71cdb5-5764-46a8-925b-b436bdbfd1df',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 72931, 'x2': 72985, 'y1': 35728, 'y2': 35782},
#   'verified_by_user': None},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755418,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'f06e8946-1679-448a-a743-c40deafed44c',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 72633, 'x2': 72687, 'y1': 54512, 'y2': 54566},
#   'verified_by_user': None},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755419,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '5956fa92-834c-4e96-80ab-d5ed4a923214',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 72360, 'x2': 72414, 'y1': 71057, 'y2': 71111},
#   'verified_by_user': None},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755420,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '6056cfea-067e-4cb9-8aae-9fb8d4becbcb',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 73864, 'x2': 73918, 'y1': 93385, 'y2': 93439},
#   'verified_by_user': None},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755421,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'd896ff6b-9d95-4316-affb-af36ff0cc3b7',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 91914, 'x2': 91968, 'y1': 13067, 'y2': 13121},
#   'verified_by_user': None},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755422,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'f3115c15-ff56-4ecf-8039-2f019ca02327',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 99774, 'x2': 99828, 'y1': 35132, 'y2': 35186},
#   'verified_by_user': None},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755423,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '6c920499-c9bf-4277-b382-d916332da5d7',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 100691, 'x2': 100745, 'y1': 56074, 'y2': 56128},
#   'verified_by_user': None},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755424,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '5cc4e10f-74af-41c6-adf1-f9427b1f3299',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 103153, 'x2': 103207, 'y1': 72631, 'y2': 72685},
#   'verified_by_user': None},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755425,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'b17e8936-7b87-4ccc-a613-af57183a2cf5',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 102140, 'x2': 102194, 'y1': 91533, 'y2': 91587},
#   'verified_by_user': None},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755426,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '1f8ca805-a23e-4eec-8aad-8bec244fc890',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 128606, 'x2': 128660, 'y1': 16173, 'y2': 16227},
#   'verified_by_user': None},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755427,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'bd460419-2e47-46c5-8112-b5cdaed66178',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 118907, 'x2': 118961, 'y1': 40624, 'y2': 40678},
#   'verified_by_user': None},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755428,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '58f2c103-e029-4064-bb67-c7807eafa68f',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 126200, 'x2': 126254, 'y1': 53835, 'y2': 53889},
#   'verified_by_user': None},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755429,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'd7a95146-a971-49f5-a2e6-b85d891dc551',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 127193, 'x2': 127247, 'y1': 72476, 'y2': 72530},
#   'verified_by_user': None},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': False,
#   'description': None,
#   'id': 2755430,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'bf487559-bfca-4a98-abb4-15e963f25aa5',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 127471, 'x2': 127525, 'y1': 91168, 'y2': 91222},
#   'verified_by_user': None}]
