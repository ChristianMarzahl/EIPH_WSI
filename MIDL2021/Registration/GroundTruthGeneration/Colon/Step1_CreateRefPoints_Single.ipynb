# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import json

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'exact' #'exact'
configuration.password = 'exact' #'exact'
configuration.host = "http://127.0.0.1:1337" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download Rect annotation

# %%
annotation_types_points = {}
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
            
for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.name] = annotation_type

annotation_types_points
# Out:
# {'L0': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 21,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L1': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 22,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L2': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 23,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L3': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 24,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L4': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 25,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L5': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 26,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L6': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 27,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L7': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 28,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L8': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 29,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L9': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 30,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L10': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 31,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L11': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 32,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L12': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 33,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L13': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 34,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L14': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 35,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L15': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 36,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L16': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 37,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L17': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 38,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L18': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 39,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L19': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 40,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L20': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 41,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L21': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 42,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L22': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 43,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L23': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 44,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L24': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 45,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotation_types_ref_rect
# Out:
# {'area_hit_test': True,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 5000,
#  'default_width': 5000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 10,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 6,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="Single_IHC", expand="product_set,product_set.annotationtype_set").results[0]


for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id, annotation_type=annotation_types_ref_rect.id, # BoundBox ID
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        annotations.append([image.id, image.name, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "id", "vector", "unique_identifier", "annotation_type"])
annotations.head()
# Out:
#    image_id                image_name     id  \
# 0       324     CRC-AI-15 X40 IHC.tif  25977
# 1       326    CRC-AI-8 E X40 IHC.tif  25978
# 2       327    CRC-AI-8 H X40 IHC.tif  25979
# 3       329   CRC-AI-11 F X40 IHC.tif  25976
# 4       331  CRC-AI-14 1G X40 IHC.tif  25980
#
#                                               vector  \
# 0   {'x1': 91, 'x2': 72457, 'y1': 2624, 'y2': 76976}
# 1  {'x1': 4835, 'x2': 62584, 'y1': 1822, 'y2': 58...
# 2   {'x1': 29, 'x2': 62223, 'y1': 2888, 'y2': 87710}
# 3  {'x1': 103, 'x2': 51830, 'y1': 2211, 'y2': 103...
# 4    {'x1': 76, 'x2': 65264, 'y1': 729, 'y2': 88611}
#
#                       unique_identifier  annotation_type
# 0  4d344740-52a8-4ef1-b194-8d1cf97e2766               10
# 1  20ddc2d1-fa7c-415a-a0ec-d42fb138ecf5               10
# 2  042796b5-5adf-4414-9e2c-7d8d4dd10e73               10
# 3  7018a17f-6bf7-4816-90e6-a763e2b852d9               10
# 4  34042d48-9390-46c9-8ed5-944ea7af32c6               10

# %%
num_lines = 5
patch_size = 100

registration_points = []
for id, bounding_box in annotations.iterrows():
    
    box_width = bounding_box.vector["x2"] - bounding_box.vector["x1"]
    box_height = bounding_box.vector["y2"] - bounding_box.vector["y1"]
    
    step_size_x = box_width // num_lines
    step_size_y = box_height // num_lines
        
    point_index = 0
    for x in range(bounding_box.vector["x1"] + step_size_x //2, bounding_box.vector["x2"], step_size_x):
        for y in range(bounding_box.vector["y1"] + step_size_y //2, bounding_box.vector["y2"], step_size_y):
            
            ref_point = annotation_types_points[f"L{point_index}"]
                
            vector = {"x1": x - patch_size, "y1": y - patch_size, 
                          "x2": x + patch_size, "y2": y + patch_size}
                
            point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id]
                
            registration_points.append(point)
                
            point_index += 1
    
registration_points = pd.DataFrame(registration_points, 
                                   columns=["image_id", "vector", "point_index", "point_name", "point_id"])
registration_points
# Out:
#      image_id                                             vector  point_index  \
# 0         324  {'x1': 7227, 'y1': 9959, 'x2': 7427, 'y2': 10159}            0
# 1         324  {'x1': 7227, 'y1': 24829, 'x2': 7427, 'y2': 25...            1
# 2         324  {'x1': 7227, 'y1': 39699, 'x2': 7427, 'y2': 39...            2
# 3         324  {'x1': 7227, 'y1': 54569, 'x2': 7427, 'y2': 54...            3
# 4         324  {'x1': 7227, 'y1': 69439, 'x2': 7427, 'y2': 69...            4
# ..        ...                                                ...          ...
# 120       331  {'x1': 58642, 'y1': 9417, 'x2': 58842, 'y2': 9...           20
# 121       331  {'x1': 58642, 'y1': 26993, 'x2': 58842, 'y2': ...           21
# 122       331  {'x1': 58642, 'y1': 44569, 'x2': 58842, 'y2': ...           22
# 123       331  {'x1': 58642, 'y1': 62145, 'x2': 58842, 'y2': ...           23
# 124       331  {'x1': 58642, 'y1': 79721, 'x2': 58842, 'y2': ...           24
#
#     point_name  point_id
# 0           L0        21
# 1           L1        22
# 2           L2        23
# 3           L3        24
# 4           L4        25
# ..         ...       ...
# 120        L20        41
# 121        L21        42
# 122        L22        43
# 123        L23        44
# 124        L24        45
#
# [125 rows x 5 columns]

# %% [markdown]
# ## Upload ref Points to EXACT

# %%
annotations_to_upload = []

for id, bounding_box in tqdm(registration_points.iterrows()):
    
    
    exact_annos =  annotations_api.list_annotations(image=bounding_box.image_id, annotation_type=bounding_box.point_id).results
    
    if len(exact_annos) == 0:
        anno = Annotation(annotation_type=bounding_box.point_id, 
                          vector=bounding_box.vector, 
                          image=bounding_box.image_id)

        annotations_to_upload.append(anno)

    else:
        prinf(f"ImageId: {bounding_box.image_id}, AnnotationType: {bounding_box.point_id} combination allready exists!")
# Out:
# 125it [00:42,  2.98it/s]

# %%
annotations_to_upload[:3]
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 324,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 9959, 'y2': 10159},
#   'verified_by_user': None},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 324,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 24829, 'y2': 25029},
#   'verified_by_user': None},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 324,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 39699, 'y2': 39899},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
#annotations_api.create_annotation(body=annotations_to_upload)
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25981,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982126),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982099),
#   'unique_identifier': 'f52b1e31-3df8-4041-9902-66bc6edef761',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 9959, 'y2': 10159},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25982,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982194),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982180),
#   'unique_identifier': 'b8ca1cea-38ef-4818-b050-d77ef0e44e21',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 24829, 'y2': 25029},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25983,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982249),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982235),
#   'unique_identifier': '9d817eda-dd12-49b4-a942-9d7ddd77f305',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 39699, 'y2': 39899},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25984,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982302),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982288),
#   'unique_identifier': '04454db4-2e29-4e18-8f8e-271d8e154507',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 54569, 'y2': 54769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25985,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982377),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982362),
#   'unique_identifier': '81ee0679-7857-4fc4-a402-df65b0576831',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7227, 'x2': 7427, 'y1': 69439, 'y2': 69639},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25986,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982432),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982417),
#   'unique_identifier': 'ea3c1191-aee4-4978-b819-ca8381f1cd68',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21700, 'x2': 21900, 'y1': 9959, 'y2': 10159},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25987,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982485),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982471),
#   'unique_identifier': '95a0c9ce-104d-4857-9a84-6ddff37327a5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21700, 'x2': 21900, 'y1': 24829, 'y2': 25029},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25988,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982539),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982524),
#   'unique_identifier': '7f89ed95-9405-4c86-a441-23adb4d2796d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21700, 'x2': 21900, 'y1': 39699, 'y2': 39899},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25989,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982592),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982578),
#   'unique_identifier': '234aa509-83fe-4b5d-a5f6-51ccbb489c38',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21700, 'x2': 21900, 'y1': 54569, 'y2': 54769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25990,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982645),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982631),
#   'unique_identifier': 'c38dbe70-b800-49ea-a76c-87abf24b417a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21700, 'x2': 21900, 'y1': 69439, 'y2': 69639},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25991,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982698),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982684),
#   'unique_identifier': '8621cbc1-4cd3-4d95-8340-3bf2e350cb7a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36173, 'x2': 36373, 'y1': 9959, 'y2': 10159},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25992,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982751),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982737),
#   'unique_identifier': '80283ce2-30ac-4d89-ad6b-ec03c9fd5894',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36173, 'x2': 36373, 'y1': 24829, 'y2': 25029},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25993,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982804),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982789),
#   'unique_identifier': '7c43b0f8-b7ad-49e9-a0ef-11806dd654c6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36173, 'x2': 36373, 'y1': 39699, 'y2': 39899},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25994,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982857),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982842),
#   'unique_identifier': '42eb06e9-97b5-41f3-8542-ee139c32114c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36173, 'x2': 36373, 'y1': 54569, 'y2': 54769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25995,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982910),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982896),
#   'unique_identifier': '132d27d5-69f1-484c-8df8-c257d0019dd4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36173, 'x2': 36373, 'y1': 69439, 'y2': 69639},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25996,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982963),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 982949),
#   'unique_identifier': '8307c1ad-84fd-4f2f-ac62-95776d567052',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50646, 'x2': 50846, 'y1': 9959, 'y2': 10159},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25997,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983016),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983002),
#   'unique_identifier': 'd7f1f686-1833-4306-a005-d30a88f6eecf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50646, 'x2': 50846, 'y1': 24829, 'y2': 25029},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25998,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983068),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983054),
#   'unique_identifier': '1ba9d25e-15fb-409c-a221-e74946b49984',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50646, 'x2': 50846, 'y1': 39699, 'y2': 39899},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 25999,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983121),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983107),
#   'unique_identifier': 'fe9f0436-272c-4a6e-a63d-9e4e8faf04c5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50646, 'x2': 50846, 'y1': 54569, 'y2': 54769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26000,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983174),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983160),
#   'unique_identifier': 'f210326c-1690-4917-82c5-354595ebe66c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50646, 'x2': 50846, 'y1': 69439, 'y2': 69639},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26001,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983227),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983212),
#   'unique_identifier': '97890d27-36d2-41db-9305-f02088448aef',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 65119, 'x2': 65319, 'y1': 9959, 'y2': 10159},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26002,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983280),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983266),
#   'unique_identifier': '39553594-a309-4977-9658-6c05361df99c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 65119, 'x2': 65319, 'y1': 24829, 'y2': 25029},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26003,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983349),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983320),
#   'unique_identifier': 'b867c6cd-0386-45e4-aefc-bf3fb919c73a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 65119, 'x2': 65319, 'y1': 39699, 'y2': 39899},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26004,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983407),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983392),
#   'unique_identifier': 'a18cc5b7-8471-4e4e-9c5c-773d0387bf8c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 65119, 'x2': 65319, 'y1': 54569, 'y2': 54769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26005,
#   'image': 324,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983460),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983446),
#   'unique_identifier': '4538814f-8162-4722-9e08-41d2f6661ee3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 65119, 'x2': 65319, 'y1': 69439, 'y2': 69639},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26006,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983514),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983499),
#   'unique_identifier': '87a0c9b7-79c3-4ec9-8a50-7430313b9641',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 10509, 'x2': 10709, 'y1': 7358, 'y2': 7558},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26007,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983567),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983553),
#   'unique_identifier': '7f6fc6f1-66c2-4856-add0-6dcca72b8f91',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 10509, 'x2': 10709, 'y1': 18631, 'y2': 18831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26008,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983620),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983605),
#   'unique_identifier': '031ff1c4-ff2b-4321-8efc-43b2cb4a2d00',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 10509, 'x2': 10709, 'y1': 29904, 'y2': 30104},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26009,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983672),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983658),
#   'unique_identifier': '556d5bf8-4cd4-4c51-888a-1d3a3c661e91',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 10509, 'x2': 10709, 'y1': 41177, 'y2': 41377},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26010,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983725),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983711),
#   'unique_identifier': '29d00a56-6fe0-4472-949c-409c4407d724',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 10509, 'x2': 10709, 'y1': 52450, 'y2': 52650},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26011,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983778),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983764),
#   'unique_identifier': '08570962-0563-40b4-accf-1d1c7854c312',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 22058, 'x2': 22258, 'y1': 7358, 'y2': 7558},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26012,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983831),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983817),
#   'unique_identifier': '354500fa-2c8e-45a4-95d8-26f7c10674eb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 22058, 'x2': 22258, 'y1': 18631, 'y2': 18831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26013,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983884),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983870),
#   'unique_identifier': '7f0f296c-fc65-419e-ac7c-79a7920ac9bc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 22058, 'x2': 22258, 'y1': 29904, 'y2': 30104},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26014,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983937),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983923),
#   'unique_identifier': '321c5016-f987-4b3e-a5df-0f4779cab266',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 22058, 'x2': 22258, 'y1': 41177, 'y2': 41377},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26015,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983989),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 983975),
#   'unique_identifier': '20ca1dca-b5ca-49ab-90aa-f14469985ab4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 22058, 'x2': 22258, 'y1': 52450, 'y2': 52650},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26016,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984043),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984028),
#   'unique_identifier': '53eb3b72-5b37-4f10-b548-e8f17dc3bb49',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33607, 'x2': 33807, 'y1': 7358, 'y2': 7558},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26017,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984096),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984082),
#   'unique_identifier': 'd62cc80c-0a71-4859-8b20-02d2f3a57abf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33607, 'x2': 33807, 'y1': 18631, 'y2': 18831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26018,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984149),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984135),
#   'unique_identifier': '7f88bae1-fc9b-4f1c-929f-ee07cb1aaec8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33607, 'x2': 33807, 'y1': 29904, 'y2': 30104},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26019,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984202),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984188),
#   'unique_identifier': 'bd60f1e2-e9c5-43fe-8dce-bc6a5c48dc9a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33607, 'x2': 33807, 'y1': 41177, 'y2': 41377},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26020,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984255),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984241),
#   'unique_identifier': 'c5225a74-47a7-418b-a026-27356f8f8213',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33607, 'x2': 33807, 'y1': 52450, 'y2': 52650},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26021,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984308),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984294),
#   'unique_identifier': '80885cfe-4f01-45aa-9391-bdd5b799a942',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45156, 'x2': 45356, 'y1': 7358, 'y2': 7558},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26022,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984381),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984366),
#   'unique_identifier': '603eb78f-b079-4ee1-8e17-0ccba80bb6bf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45156, 'x2': 45356, 'y1': 18631, 'y2': 18831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26023,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984435),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984421),
#   'unique_identifier': '5c7a375f-c6ba-45ba-8491-17ff5bfa6f0d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45156, 'x2': 45356, 'y1': 29904, 'y2': 30104},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26024,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984488),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984474),
#   'unique_identifier': 'f8965a74-5473-4f13-8764-562d80d03cf9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45156, 'x2': 45356, 'y1': 41177, 'y2': 41377},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26025,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984541),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984527),
#   'unique_identifier': 'aebcf9bd-b1a7-4c41-9d72-55f6503cd6e4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45156, 'x2': 45356, 'y1': 52450, 'y2': 52650},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26026,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984594),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984580),
#   'unique_identifier': 'ee32fac8-749a-4fb5-831b-d92632ca32c2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56705, 'x2': 56905, 'y1': 7358, 'y2': 7558},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26027,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984647),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984633),
#   'unique_identifier': '89d40300-7049-4387-988c-b57b1c5a8c43',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56705, 'x2': 56905, 'y1': 18631, 'y2': 18831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26028,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984700),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984686),
#   'unique_identifier': 'aca89bf3-62ec-4f8b-a53d-8e91a1a26f0f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56705, 'x2': 56905, 'y1': 29904, 'y2': 30104},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26029,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984753),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984739),
#   'unique_identifier': '3fbdfbe9-7a65-496a-9faa-8a943ed3b72d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56705, 'x2': 56905, 'y1': 41177, 'y2': 41377},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26030,
#   'image': 326,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984806),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984792),
#   'unique_identifier': '70a7fa04-cce6-4dc0-ae99-f1fd1bb78959',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56705, 'x2': 56905, 'y1': 52450, 'y2': 52650},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26031,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984859),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984845),
#   'unique_identifier': 'f29b8d47-cb1a-4d8f-bb05-3142ee1fb744',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6148, 'x2': 6348, 'y1': 11270, 'y2': 11470},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26032,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984912),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984898),
#   'unique_identifier': '4fd3f6b0-5cd9-4d26-95b2-cf17e9fb65c8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6148, 'x2': 6348, 'y1': 28234, 'y2': 28434},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26033,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984965),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 984950),
#   'unique_identifier': '95f24a98-d2f4-4e52-8ef4-d3de79135022',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6148, 'x2': 6348, 'y1': 45198, 'y2': 45398},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26034,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985017),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985003),
#   'unique_identifier': '2ce883d0-4cfb-43c9-8f8f-093a597b7de9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6148, 'x2': 6348, 'y1': 62162, 'y2': 62362},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26035,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985070),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985056),
#   'unique_identifier': 'bd65e94c-c41c-4ec4-9d28-48cd902d9411',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6148, 'x2': 6348, 'y1': 79126, 'y2': 79326},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26036,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985123),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985109),
#   'unique_identifier': '98c9ddea-e811-4ff4-b56f-de45a31a9169',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18586, 'x2': 18786, 'y1': 11270, 'y2': 11470},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26037,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985175),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985162),
#   'unique_identifier': '0e3ec0a3-e989-48fa-a2d2-a92a7365f27d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18586, 'x2': 18786, 'y1': 28234, 'y2': 28434},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26038,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985228),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985214),
#   'unique_identifier': 'e62e1b50-3684-4d1c-9b58-08a358c5de3e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18586, 'x2': 18786, 'y1': 45198, 'y2': 45398},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26039,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985281),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985267),
#   'unique_identifier': '7cea1270-46c6-42f4-bd3a-ade0a8e88387',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18586, 'x2': 18786, 'y1': 62162, 'y2': 62362},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26040,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985351),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985333),
#   'unique_identifier': '9165b052-b281-4c6d-a909-1c3a1c58ec07',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18586, 'x2': 18786, 'y1': 79126, 'y2': 79326},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26041,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985408),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985393),
#   'unique_identifier': '756bc159-cf64-4c1a-8526-c1ee387a04a4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31024, 'x2': 31224, 'y1': 11270, 'y2': 11470},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26042,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985462),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985447),
#   'unique_identifier': 'f9e8764d-1d34-42c7-95ef-6ff5b61c2d46',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31024, 'x2': 31224, 'y1': 28234, 'y2': 28434},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26043,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985515),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985501),
#   'unique_identifier': '37058c4d-1053-42d3-b874-3ea48e8e88bd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31024, 'x2': 31224, 'y1': 45198, 'y2': 45398},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26044,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985568),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985554),
#   'unique_identifier': 'b4ee2c78-0569-4701-b38f-4927f7f6eb87',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31024, 'x2': 31224, 'y1': 62162, 'y2': 62362},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26045,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985621),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985607),
#   'unique_identifier': '7adb951a-372e-4682-9f63-10d4d2c9f651',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31024, 'x2': 31224, 'y1': 79126, 'y2': 79326},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26046,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985674),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985660),
#   'unique_identifier': '09f65f0b-f41a-4de5-ad92-9ee0803ad4ac',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43462, 'x2': 43662, 'y1': 11270, 'y2': 11470},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26047,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985727),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985713),
#   'unique_identifier': 'f5d39f89-ed83-4502-9c02-a4812bc75e99',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43462, 'x2': 43662, 'y1': 28234, 'y2': 28434},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26048,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985780),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985766),
#   'unique_identifier': '4a8567fc-8944-4c30-871f-68419fe312cf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43462, 'x2': 43662, 'y1': 45198, 'y2': 45398},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26049,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985833),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985819),
#   'unique_identifier': 'bb543b68-a2c8-4d66-a5d8-dc91cb3f7abc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43462, 'x2': 43662, 'y1': 62162, 'y2': 62362},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26050,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985886),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985872),
#   'unique_identifier': '97979a91-50f0-4921-a3aa-f084947b5564',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43462, 'x2': 43662, 'y1': 79126, 'y2': 79326},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26051,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985939),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985925),
#   'unique_identifier': 'b59cd305-a2b0-4090-89fe-eb32ac465a5b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 55900, 'x2': 56100, 'y1': 11270, 'y2': 11470},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26052,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985992),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 985978),
#   'unique_identifier': '74317148-8803-4b83-bf68-68e3069b9a61',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 55900, 'x2': 56100, 'y1': 28234, 'y2': 28434},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26053,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986045),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986031),
#   'unique_identifier': '2bbff44d-0733-46c5-812c-ad57f7bf6afd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 55900, 'x2': 56100, 'y1': 45198, 'y2': 45398},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26054,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986099),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986085),
#   'unique_identifier': '8bfc1698-0e93-4f3f-8588-30ff81b85d18',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 55900, 'x2': 56100, 'y1': 62162, 'y2': 62362},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26055,
#   'image': 327,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986152),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986138),
#   'unique_identifier': '63e76eee-a35f-41b5-8165-676f943ed29a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 55900, 'x2': 56100, 'y1': 79126, 'y2': 79326},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26056,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986205),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986191),
#   'unique_identifier': 'c10a8bb0-1463-47cd-b90c-f470ea438e13',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 5175, 'x2': 5375, 'y1': 12206, 'y2': 12406},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26057,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986258),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986244),
#   'unique_identifier': 'cb571d49-e4e3-47d0-9620-797d39c9a324',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 5175, 'x2': 5375, 'y1': 32396, 'y2': 32596},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26058,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986311),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986297),
#   'unique_identifier': 'b3a95aab-d4ca-489d-8b08-70036821058b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 5175, 'x2': 5375, 'y1': 52586, 'y2': 52786},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26059,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986384),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986369),
#   'unique_identifier': 'cd99e98f-8394-4295-9748-ee803b51aad0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 5175, 'x2': 5375, 'y1': 72776, 'y2': 72976},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26060,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986438),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986424),
#   'unique_identifier': 'c02c703d-555f-46e2-be73-e5a28e3fd25c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 5175, 'x2': 5375, 'y1': 92966, 'y2': 93166},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26061,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986491),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986477),
#   'unique_identifier': '692e45e8-457c-496e-add7-e2747bf0f05c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15520, 'x2': 15720, 'y1': 12206, 'y2': 12406},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26062,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986544),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986530),
#   'unique_identifier': '48584a1d-e598-4fc6-a25c-2a62148082bc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15520, 'x2': 15720, 'y1': 32396, 'y2': 32596},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26063,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986596),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986582),
#   'unique_identifier': '1c8cb611-af81-4319-a3c1-22879dd41823',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15520, 'x2': 15720, 'y1': 52586, 'y2': 52786},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26064,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986649),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986635),
#   'unique_identifier': '5a750854-5819-417b-9367-432b8e722a0b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15520, 'x2': 15720, 'y1': 72776, 'y2': 72976},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26065,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986701),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986687),
#   'unique_identifier': '42890d5f-58be-4db6-bcdc-9a6e7cd9bf31',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15520, 'x2': 15720, 'y1': 92966, 'y2': 93166},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26066,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986754),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986740),
#   'unique_identifier': '817f8b92-e6b4-4c97-b709-fcd8f96eec0b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25865, 'x2': 26065, 'y1': 12206, 'y2': 12406},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26067,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986807),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 986792),
#   'unique_identifier': '14e88465-9914-4dd5-b8e2-62ed196aaca7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25865, 'x2': 26065, 'y1': 32396, 'y2': 32596},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
# ...
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26077,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987372),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987357),
#   'unique_identifier': '6d60ac41-58b4-4fce-9506-05c020de21e0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46555, 'x2': 46755, 'y1': 32396, 'y2': 32596},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26078,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987426),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987412),
#   'unique_identifier': 'cbe5a053-156e-47c1-875e-8068d85b3f22',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46555, 'x2': 46755, 'y1': 52586, 'y2': 52786},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26079,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987479),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987465),
#   'unique_identifier': '3fb403fc-77ee-456c-9291-9c5daaa93fc5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46555, 'x2': 46755, 'y1': 72776, 'y2': 72976},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26080,
#   'image': 329,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987532),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987518),
#   'unique_identifier': '90d8bb1b-ef27-46e1-ab04-67e24471126c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46555, 'x2': 46755, 'y1': 92966, 'y2': 93166},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26081,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987585),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987571),
#   'unique_identifier': '7bcdc6f3-b5cf-41d2-af73-2852d7ad4240',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6494, 'x2': 6694, 'y1': 9417, 'y2': 9617},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26082,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987638),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987624),
#   'unique_identifier': '77c215ec-6c4f-4561-9326-4115bd00bc4a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6494, 'x2': 6694, 'y1': 26993, 'y2': 27193},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26083,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987690),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987676),
#   'unique_identifier': '58bab310-0cca-46d0-bfc6-52d176a18f06',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6494, 'x2': 6694, 'y1': 44569, 'y2': 44769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26084,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987743),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987729),
#   'unique_identifier': '515a5e10-6410-4e31-8ff1-3dd38cec8f30',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6494, 'x2': 6694, 'y1': 62145, 'y2': 62345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26085,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987795),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987781),
#   'unique_identifier': '19ca03ec-9798-4bd7-863d-97c89e8d3788',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6494, 'x2': 6694, 'y1': 79721, 'y2': 79921},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26086,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987848),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987834),
#   'unique_identifier': 'e1968287-0559-4f43-89f5-194f668477b7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19531, 'x2': 19731, 'y1': 9417, 'y2': 9617},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26087,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987901),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987887),
#   'unique_identifier': 'e5dabb71-f29d-48e0-a3bf-d9e2f48ac24d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19531, 'x2': 19731, 'y1': 26993, 'y2': 27193},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26088,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987955),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987941),
#   'unique_identifier': 'b21190f1-5054-40fd-8ca0-b4d69b94ee5d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19531, 'x2': 19731, 'y1': 44569, 'y2': 44769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26089,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988008),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 987994),
#   'unique_identifier': '6d26dfe8-c33e-4d12-b3f8-01171450aec0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19531, 'x2': 19731, 'y1': 62145, 'y2': 62345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26090,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988060),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988046),
#   'unique_identifier': '8f30287d-57ab-4f7b-8e34-11bdb7248e54',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19531, 'x2': 19731, 'y1': 79721, 'y2': 79921},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26091,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988113),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988099),
#   'unique_identifier': '90572960-dcfd-445e-9f01-79a313bc3456',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32568, 'x2': 32768, 'y1': 9417, 'y2': 9617},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26092,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988166),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988152),
#   'unique_identifier': '5e8b180c-cd06-4056-a342-1d312e878de9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32568, 'x2': 32768, 'y1': 26993, 'y2': 27193},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26093,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988219),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988205),
#   'unique_identifier': '0e1c3083-151c-482e-b090-5ab8f3708a4c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32568, 'x2': 32768, 'y1': 44569, 'y2': 44769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26094,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988271),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988257),
#   'unique_identifier': 'dabe672b-570c-4787-a674-531d658aba01',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32568, 'x2': 32768, 'y1': 62145, 'y2': 62345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26095,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988340),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988310),
#   'unique_identifier': '02412e77-6d75-44bf-833e-f71510162f55',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32568, 'x2': 32768, 'y1': 79721, 'y2': 79921},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26096,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988398),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988384),
#   'unique_identifier': 'd02517fd-eea7-4fd7-96ff-cab5dfc665e0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45605, 'x2': 45805, 'y1': 9417, 'y2': 9617},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26097,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988451),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988437),
#   'unique_identifier': '43456e83-0bda-4700-856f-3472996d0f78',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45605, 'x2': 45805, 'y1': 26993, 'y2': 27193},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26098,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988504),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988490),
#   'unique_identifier': 'f88ca87a-7b20-4713-8da2-9b7bb94989a0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45605, 'x2': 45805, 'y1': 44569, 'y2': 44769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26099,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988557),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988543),
#   'unique_identifier': 'bbbaf6b8-ae60-4278-ba0a-0d94dee336d9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45605, 'x2': 45805, 'y1': 62145, 'y2': 62345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26100,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988609),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988595),
#   'unique_identifier': '4de4de7b-2348-40b6-a634-d5ac621b06b4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45605, 'x2': 45805, 'y1': 79721, 'y2': 79921},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26101,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988662),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988648),
#   'unique_identifier': 'c087f152-ee2c-4d39-b350-5f0a19278d3f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58642, 'x2': 58842, 'y1': 9417, 'y2': 9617},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26102,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988715),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988701),
#   'unique_identifier': '0bd2dfcc-79da-439b-9200-b405ebea8406',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58642, 'x2': 58842, 'y1': 26993, 'y2': 27193},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26103,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988768),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988754),
#   'unique_identifier': 'a4bec180-cd41-4c78-b899-32d8f43487ad',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58642, 'x2': 58842, 'y1': 44569, 'y2': 44769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26104,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988821),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988807),
#   'unique_identifier': 'e12a6e56-a5c4-4151-9581-a6217ef91aaa',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58642, 'x2': 58842, 'y1': 62145, 'y2': 62345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26105,
#   'image': 331,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988873),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 27, 49, 988859),
#   'unique_identifier': '53d11e13-756a-45f1-b744-a22d6c3404a6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58642, 'x2': 58842, 'y1': 79721, 'y2': 79921},
#   'verified_by_user': 'False'}]
