# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import pickle
import numpy as np

# %%
from openslide import OpenSlide

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %%
# Python < 3.8?
import sys
#! pip install pickle5

if sys.version_info.minor < 8:
    import pickle5 as pickle

# %%
import sys
sys.path.append("../..")
from registration_tree import Rect, QuadTree

# %%
slide_list = {path.name: path for path in Path(r"D:\Datasets\ColonCancer\SingleSlide").glob("*/*.*") 
                      if path.suffix in [".tif"]}

slide_list
# Out:
# {'CRC-AI-11 F X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-11 F X40.tif'),
#  'CRC-AI-14 1G X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-14 1G X40.tif'),
#  'CRC-AI-15 X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-15 X40.tif'),
#  'CRC-AI-8 E X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-8 E X40.tif'),
#  'CRC-AI-8 H X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-8 H X40.tif'),
#  'CRC-AI-11 F X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-11 F X40 IHC.tif'),
#  'CRC-AI-14 1G X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-14 1G X40 IHC.tif'),
#  'CRC-AI-15 X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-15 X40 IHC.tif'),
#  'CRC-AI-8 E X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-8 E X40 IHC.tif'),
#  'CRC-AI-8 H X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-8 H X40 IHC.tif')}

# %%
configuration = Configuration()
configuration.username = 'exact' #'exact'
configuration.password = 'exact' #'exact'
configuration.host = "http://127.0.0.1:1337" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %%
annotation_types_points = {}

for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.id] = annotation_type

annotation_types_points
# Out:
# {21: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 21,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  22: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 22,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  23: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 23,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  24: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 24,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  25: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 25,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  26: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 26,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  27: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 27,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  28: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 28,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  29: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 29,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  30: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 30,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  31: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 31,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  32: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 32,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  33: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 33,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  34: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 34,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  35: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 35,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  36: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 36,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  37: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 37,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  38: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 38,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  39: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 39,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  40: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 40,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  41: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 41,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  42: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 42,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  43: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 43,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  44: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 44,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  45: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 45,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="Single_IHC", expand="product_set,product_set.annotationtype_set").results[0]

for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id,
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        if anno.annotation_type in annotation_types_points:
            short = Path(image.name).stem.split("X40")[0]
            
            annotations.append([image.id, image.name, short, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "image_name_short", "id", "vector", "unique_identifier", "annotation_type"])
annotations
# Out:
#      image_id                image_name image_name_short     id  \
# 0         324     CRC-AI-15 X40 IHC.tif       CRC-AI-15   25981
# 1         324     CRC-AI-15 X40 IHC.tif       CRC-AI-15   25982
# 2         324     CRC-AI-15 X40 IHC.tif       CRC-AI-15   25983
# 3         324     CRC-AI-15 X40 IHC.tif       CRC-AI-15   25984
# 4         324     CRC-AI-15 X40 IHC.tif       CRC-AI-15   25985
# ..        ...                       ...              ...    ...
# 120       331  CRC-AI-14 1G X40 IHC.tif    CRC-AI-14 1G   26101
# 121       331  CRC-AI-14 1G X40 IHC.tif    CRC-AI-14 1G   26102
# 122       331  CRC-AI-14 1G X40 IHC.tif    CRC-AI-14 1G   26103
# 123       331  CRC-AI-14 1G X40 IHC.tif    CRC-AI-14 1G   26104
# 124       331  CRC-AI-14 1G X40 IHC.tif    CRC-AI-14 1G   26105
#
#                                                 vector  \
# 0    {'x1': 7227, 'x2': 7427, 'y1': 9959, 'y2': 10159}
# 1    {'x1': 7227, 'x2': 7427, 'y1': 24829, 'y2': 25...
# 2    {'x1': 7227, 'x2': 7427, 'y1': 39699, 'y2': 39...
# 3    {'x1': 7227, 'x2': 7427, 'y1': 54569, 'y2': 54...
# 4    {'x1': 7227, 'x2': 7427, 'y1': 69439, 'y2': 69...
# ..                                                 ...
# 120  {'x1': 58642, 'x2': 58842, 'y1': 9417, 'y2': 9...
# 121  {'x1': 58642, 'x2': 58842, 'y1': 26993, 'y2': ...
# 122  {'x1': 58642, 'x2': 58842, 'y1': 44569, 'y2': ...
# 123  {'x1': 58642, 'x2': 58842, 'y1': 62145, 'y2': ...
# 124  {'x1': 58642, 'x2': 58842, 'y1': 79721, 'y2': ...
#
#                         unique_identifier  annotation_type
# 0    f52b1e31-3df8-4041-9902-66bc6edef761               21
# 1    b8ca1cea-38ef-4818-b050-d77ef0e44e21               22
# 2    9d817eda-dd12-49b4-a942-9d7ddd77f305               23
# 3    04454db4-2e29-4e18-8f8e-271d8e154507               24
# 4    81ee0679-7857-4fc4-a402-df65b0576831               25
# ..                                    ...              ...
# 120  c087f152-ee2c-4d39-b350-5f0a19278d3f               41
# 121  0bd2dfcc-79da-439b-9200-b405ebea8406               42
# 122  a4bec180-cd41-4c78-b899-32d8f43487ad               43
# 123  e12a6e56-a5c4-4151-9581-a6217ef91aaa               44
# 124  53d11e13-756a-45f1-b744-a22d6c3404a6               45
#
# [125 rows x 7 columns]

# %%
annotations["x1"] = [vector['x1'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y1"] = [vector['y1'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["x2"] = [vector['x2'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y2"] = [vector['y2'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(annotations["y1"], annotations["y2"])]

annotations["anno_width"] = [x2-x1 for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["anno_height"]= [y2-y1 for y1, y2 in zip(annotations["y1"], annotations["y2"])]

# %%
transformed_annotations_to_upload = []

for image_set_name in tqdm(["Single_HE"]):
    image_set = image_sets_api.list_image_sets(name=image_set_name, expand="product_set,product_set.annotationtype_set").results[0]

    for image_id in image_set.images:
        
        target_image = images_api.retrieve_image(id=image_id)
        short = Path(target_image.name).stem.replace("40X", "X40").split("X40")[0]
        
        source_annos = annotations[annotations["image_name_short"] == short]
        
        source_name = list(source_annos["image_name"].unique())[0]
        target_name = target_image.name
        
        qtree = pickle.load(open(f'../../ColonCancer/Depth_2/2048/{Path(source_name).stem}-To-{Path(target_name).stem}.pickle', "rb" ))
        #qtree.source_slide = OpenSlide(str(slide_list[source_name]))
        #qtree.target_slide = OpenSlide(str(slide_list[target_name]))
        
        for id, source_anno in source_annos.iterrows():

            box = [source_anno.center_x, source_anno.center_y, source_anno.anno_width, source_anno.anno_height]

            trans_box = qtree.transform_boxes(np.array([box]))[0]

            new_x1 = int(trans_box[0] - trans_box[2] // 2)
            new_y1 = int(trans_box[1] - trans_box[3] // 2)
            new_x2 = int(trans_box[0] + trans_box[2] // 2)
            new_y2 = int(trans_box[1] + trans_box[3] // 2)

            vector = {'x1': new_x1, 'x2': new_x2, 'y1': new_y1, 'y2': new_y2}

            anno = Annotation(annotation_type=source_anno.annotation_type, 
                                  vector=vector, 
                                  image=target_image.id,
                                 unique_identifier=source_anno.unique_identifier)

            transformed_annotations_to_upload.append(anno)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.17s/it]

# %%
transformed_annotations_to_upload[:3]
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 325,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'f52b1e31-3df8-4041-9902-66bc6edef761',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 6329, 'x2': 6527, 'y1': 8953, 'y2': 9151},
#   'verified_by_user': None},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 325,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'b8ca1cea-38ef-4818-b050-d77ef0e44e21',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 6448, 'x2': 6648, 'y1': 23852, 'y2': 24052},
#   'verified_by_user': None},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 325,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '9d817eda-dd12-49b4-a942-9d7ddd77f305',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 6570, 'x2': 6770, 'y1': 38767, 'y2': 38967},
#   'verified_by_user': None}]

# %%
annotations_api.create_annotation(body=transformed_annotations_to_upload)
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26106,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262489),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262456),
#   'unique_identifier': 'f52b1e31-3df8-4041-9902-66bc6edef761',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6329, 'x2': 6527, 'y1': 8953, 'y2': 9151},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26107,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262570),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262555),
#   'unique_identifier': 'b8ca1cea-38ef-4818-b050-d77ef0e44e21',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6448, 'x2': 6648, 'y1': 23852, 'y2': 24052},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26108,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262630),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262615),
#   'unique_identifier': '9d817eda-dd12-49b4-a942-9d7ddd77f305',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6570, 'x2': 6770, 'y1': 38767, 'y2': 38967},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26109,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262689),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262674),
#   'unique_identifier': '04454db4-2e29-4e18-8f8e-271d8e154507',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6662, 'x2': 6862, 'y1': 53667, 'y2': 53867},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26110,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262746),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262732),
#   'unique_identifier': '81ee0679-7857-4fc4-a402-df65b0576831',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6827, 'x2': 7025, 'y1': 68732, 'y2': 68934},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26111,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262804),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262790),
#   'unique_identifier': 'ea3c1191-aee4-4978-b819-ca8381f1cd68',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 20805, 'x2': 21005, 'y1': 8573, 'y2': 8773},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26112,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262881),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262848),
#   'unique_identifier': '95a0c9ce-104d-4857-9a84-6ddff37327a5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 20907, 'x2': 21105, 'y1': 23726, 'y2': 23926},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26113,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262949),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 262934),
#   'unique_identifier': '7f89ed95-9405-4c86-a441-23adb4d2796d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21049, 'x2': 21249, 'y1': 38642, 'y2': 38842},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26114,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263022),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263004),
#   'unique_identifier': '234aa509-83fe-4b5d-a5f6-51ccbb489c38',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21167, 'x2': 21367, 'y1': 53652, 'y2': 53852},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26115,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263088),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263069),
#   'unique_identifier': 'c38dbe70-b800-49ea-a76c-87abf24b417a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21274, 'x2': 21474, 'y1': 68674, 'y2': 68872},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26116,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263147),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263133),
#   'unique_identifier': '8621cbc1-4cd3-4d95-8340-3bf2e350cb7a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35278, 'x2': 35478, 'y1': 8434, 'y2': 8634},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26117,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263205),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263191),
#   'unique_identifier': '80283ce2-30ac-4d89-ad6b-ec03c9fd5894',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35369, 'x2': 35567, 'y1': 23615, 'y2': 23815},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26118,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263263),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263248),
#   'unique_identifier': '7c43b0f8-b7ad-49e9-a0ef-11806dd654c6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35532, 'x2': 35732, 'y1': 38540, 'y2': 38740},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26119,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263339),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263318),
#   'unique_identifier': '42eb06e9-97b5-41f3-8542-ee139c32114c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35650, 'x2': 35850, 'y1': 53550, 'y2': 53750},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26120,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263401),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263387),
#   'unique_identifier': '132d27d5-69f1-484c-8df8-c257d0019dd4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35750, 'x2': 35950, 'y1': 68568, 'y2': 68766},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26121,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263474),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263454),
#   'unique_identifier': '8307c1ad-84fd-4f2f-ac62-95776d567052',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49618, 'x2': 49816, 'y1': 8674, 'y2': 8874},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26122,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263553),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263538),
#   'unique_identifier': 'd7f1f686-1833-4306-a005-d30a88f6eecf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49734, 'x2': 49932, 'y1': 23581, 'y2': 23781},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26123,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263612),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263598),
#   'unique_identifier': '1ba9d25e-15fb-409c-a221-e74946b49984',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50028, 'x2': 50228, 'y1': 38791, 'y2': 38991},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26124,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263669),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263656),
#   'unique_identifier': 'fe9f0436-272c-4a6e-a63d-9e4e8faf04c5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50135, 'x2': 50335, 'y1': 53686, 'y2': 53886},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26125,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263727),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263713),
#   'unique_identifier': 'f210326c-1690-4917-82c5-354595ebe66c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50219, 'x2': 50417, 'y1': 68531, 'y2': 68729},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26126,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263792),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263773),
#   'unique_identifier': '97890d27-36d2-41db-9305-f02088448aef',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64049, 'x2': 64247, 'y1': 8588, 'y2': 8788},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26127,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263903),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263857),
#   'unique_identifier': '39553594-a309-4977-9658-6c05361df99c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64165, 'x2': 64363, 'y1': 23495, 'y2': 23695},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26128,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263996),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 263974),
#   'unique_identifier': 'b867c6cd-0386-45e4-aefc-bf3fb919c73a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64485, 'x2': 64685, 'y1': 38687, 'y2': 38887},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26129,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264088),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264064),
#   'unique_identifier': 'a18cc5b7-8471-4e4e-9c5c-773d0387bf8c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64607, 'x2': 64807, 'y1': 53611, 'y2': 53811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26130,
#   'image': 325,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264177),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264158),
#   'unique_identifier': '4538814f-8162-4722-9e08-41d2f6661ee3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64689, 'x2': 64887, 'y1': 68421, 'y2': 68621},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26131,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264250),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264235),
#   'unique_identifier': '87a0c9b7-79c3-4ec9-8a50-7430313b9641',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7055, 'x2': 7255, 'y1': 8211, 'y2': 8409},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26132,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264309),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264295),
#   'unique_identifier': '7f6fc6f1-66c2-4856-add0-6dcca72b8f91',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7075, 'x2': 7275, 'y1': 19481, 'y2': 19679},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26133,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264373),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264353),
#   'unique_identifier': '031ff1c4-ff2b-4321-8efc-43b2cb4a2d00',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7095, 'x2': 7295, 'y1': 30751, 'y2': 30949},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26134,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264443),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264429),
#   'unique_identifier': '556d5bf8-4cd4-4c51-888a-1d3a3c661e91',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7149, 'x2': 7347, 'y1': 42021, 'y2': 42219},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26135,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264502),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264488),
#   'unique_identifier': '29d00a56-6fe0-4472-949c-409c4407d724',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7175, 'x2': 7373, 'y1': 53278, 'y2': 53476},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26136,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264560),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264546),
#   'unique_identifier': '08570962-0563-40b4-accf-1d1c7854c312',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18605, 'x2': 18805, 'y1': 8187, 'y2': 8387},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26137,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264618),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264604),
#   'unique_identifier': '354500fa-2c8e-45a4-95d8-26f7c10674eb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18633, 'x2': 18833, 'y1': 19466, 'y2': 19666},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26138,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264676),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264662),
#   'unique_identifier': '7f0f296c-fc65-419e-ac7c-79a7920ac9bc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18662, 'x2': 18862, 'y1': 30744, 'y2': 30944},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26139,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264734),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264720),
#   'unique_identifier': '321c5016-f987-4b3e-a5df-0f4779cab266',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18674, 'x2': 18874, 'y1': 41998, 'y2': 42196},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26140,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264792),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264778),
#   'unique_identifier': '20ca1dca-b5ca-49ab-90aa-f14469985ab4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18694, 'x2': 18894, 'y1': 53268, 'y2': 53466},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26141,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264851),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264837),
#   'unique_identifier': '53eb3b72-5b37-4f10-b548-e8f17dc3bb49',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30160, 'x2': 30360, 'y1': 8159, 'y2': 8359},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26142,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264937),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264921),
#   'unique_identifier': 'd62cc80c-0a71-4859-8b20-02d2f3a57abf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30188, 'x2': 30388, 'y1': 19437, 'y2': 19637},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26143,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265014),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 264993),
#   'unique_identifier': '7f88bae1-fc9b-4f1c-929f-ee07cb1aaec8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30217, 'x2': 30417, 'y1': 30716, 'y2': 30916},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26144,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265109),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265092),
#   'unique_identifier': 'bd60f1e2-e9c5-43fe-8dce-bc6a5c48dc9a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30232, 'x2': 30432, 'y1': 41975, 'y2': 42173},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26145,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265170),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265156),
#   'unique_identifier': 'c5225a74-47a7-418b-a026-27356f8f8213',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30252, 'x2': 30452, 'y1': 53245, 'y2': 53443},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26146,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265233),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265219),
#   'unique_identifier': '80885cfe-4f01-45aa-9391-bdd5b799a942',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41708, 'x2': 41908, 'y1': 8131, 'y2': 8331},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26147,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265292),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265278),
#   'unique_identifier': '603eb78f-b079-4ee1-8e17-0ccba80bb6bf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41734, 'x2': 41934, 'y1': 19412, 'y2': 19612},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26148,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265362),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265347),
#   'unique_identifier': '5c7a375f-c6ba-45ba-8491-17ff5bfa6f0d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41759, 'x2': 41959, 'y1': 30694, 'y2': 30894},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26149,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265421),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265407),
#   'unique_identifier': 'f8965a74-5473-4f13-8764-562d80d03cf9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41794, 'x2': 41994, 'y1': 41992, 'y2': 42192},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26150,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265478),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265464),
#   'unique_identifier': 'aebcf9bd-b1a7-4c41-9d72-55f6503cd6e4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41823, 'x2': 42023, 'y1': 53280, 'y2': 53480},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26151,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265536),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265522),
#   'unique_identifier': 'ee32fac8-749a-4fb5-831b-d92632ca32c2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53265, 'x2': 53463, 'y1': 8135, 'y2': 8333},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26152,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265594),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265580),
#   'unique_identifier': '89d40300-7049-4387-988c-b57b1c5a8c43',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53283, 'x2': 53481, 'y1': 19365, 'y2': 19563},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26153,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265652),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265638),
#   'unique_identifier': 'aca89bf3-62ec-4f8b-a53d-8e91a1a26f0f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53300, 'x2': 53498, 'y1': 30596, 'y2': 30794},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26154,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265709),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265695),
#   'unique_identifier': '3fbdfbe9-7a65-496a-9faa-8a943ed3b72d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53349, 'x2': 53549, 'y1': 41968, 'y2': 42168},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26155,
#   'image': 328,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265767),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265753),
#   'unique_identifier': '70a7fa04-cce6-4dc0-ae99-f1fd1bb78959',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53378, 'x2': 53578, 'y1': 53255, 'y2': 53455},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26156,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265830),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265816),
#   'unique_identifier': 'f29b8d47-cb1a-4d8f-bb05-3142ee1fb744',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19049, 'x2': 19247, 'y1': 13843, 'y2': 14043},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26157,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265923),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265899),
#   'unique_identifier': '4fd3f6b0-5cd9-4d26-95b2-cf17e9fb65c8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19036, 'x2': 19234, 'y1': 30808, 'y2': 31006},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26158,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266022),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 265996),
#   'unique_identifier': '95f24a98-d2f4-4e52-8ef4-d3de79135022',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19034, 'x2': 19232, 'y1': 47768, 'y2': 47966},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26159,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266116),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266097),
#   'unique_identifier': '2ce883d0-4cfb-43c9-8f8f-093a597b7de9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19030, 'x2': 19230, 'y1': 64737, 'y2': 64937},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26160,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266199),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266179),
#   'unique_identifier': 'bd65e94c-c41c-4ec4-9d28-48cd902d9411',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19026, 'x2': 19226, 'y1': 81698, 'y2': 81898},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26161,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266294),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266267),
#   'unique_identifier': '98c9ddea-e811-4ff4-b56f-de45a31a9169',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31479, 'x2': 31677, 'y1': 13847, 'y2': 14047},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26162,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266391),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266366),
#   'unique_identifier': '0e3ec0a3-e989-48fa-a2d2-a92a7365f27d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31473, 'x2': 31671, 'y1': 30803, 'y2': 31001},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26163,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266487),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266466),
#   'unique_identifier': 'e62e1b50-3684-4d1c-9b58-08a358c5de3e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31470, 'x2': 31668, 'y1': 47764, 'y2': 47962},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26164,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266582),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266558),
#   'unique_identifier': '7cea1270-46c6-42f4-bd3a-ade0a8e88387',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31472, 'x2': 31672, 'y1': 64740, 'y2': 64940},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26165,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266673),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266652),
#   'unique_identifier': '9165b052-b281-4c6d-a909-1c3a1c58ec07',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31466, 'x2': 31666, 'y1': 81695, 'y2': 81895},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26166,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266755),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266735),
#   'unique_identifier': '756bc159-cf64-4c1a-8526-c1ee387a04a4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43923, 'x2': 44123, 'y1': 13843, 'y2': 14043},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26167,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266837),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266817),
#   'unique_identifier': 'f9e8764d-1d34-42c7-95ef-6ff5b61c2d46',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43914, 'x2': 44114, 'y1': 30806, 'y2': 31006},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26168,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266944),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 266924),
#   'unique_identifier': '37058c4d-1053-42d3-b874-3ea48e8e88bd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43905, 'x2': 44105, 'y1': 47770, 'y2': 47970},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26169,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267024),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267005),
#   'unique_identifier': 'b4ee2c78-0569-4701-b38f-4927f7f6eb87',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43898, 'x2': 44096, 'y1': 64733, 'y2': 64931},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26170,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267107),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267086),
#   'unique_identifier': '7adb951a-372e-4682-9f63-10d4d2c9f651',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 43892, 'x2': 44090, 'y1': 81697, 'y2': 81897},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26171,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267189),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267170),
#   'unique_identifier': '09f65f0b-f41a-4de5-ad92-9ee0803ad4ac',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56363, 'x2': 56563, 'y1': 13851, 'y2': 14051},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26172,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267271),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267251),
#   'unique_identifier': 'f5d39f89-ed83-4502-9c02-a4812bc75e99',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56356, 'x2': 56556, 'y1': 30812, 'y2': 31012},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26173,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267353),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267334),
#   'unique_identifier': '4a8567fc-8944-4c30-871f-68419fe312cf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56342, 'x2': 56542, 'y1': 47779, 'y2': 47979},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26174,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267433),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267411),
#   'unique_identifier': 'bb543b68-a2c8-4d66-a5d8-dc91cb3f7abc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56338, 'x2': 56538, 'y1': 64740, 'y2': 64938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26175,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267497),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267483),
#   'unique_identifier': '97979a91-50f0-4921-a3aa-f084947b5564',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56326, 'x2': 56524, 'y1': 81705, 'y2': 81905},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26176,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267562),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267548),
#   'unique_identifier': 'b59cd305-a2b0-4090-89fe-eb32ac465a5b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68811, 'x2': 69011, 'y1': 13864, 'y2': 14064},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26177,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267622),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267608),
#   'unique_identifier': '74317148-8803-4b83-bf68-68e3069b9a61',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68795, 'x2': 68995, 'y1': 30826, 'y2': 31026},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26178,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267679),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267665),
#   'unique_identifier': '2bbff44d-0733-46c5-812c-ad57f7bf6afd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68782, 'x2': 68982, 'y1': 47792, 'y2': 47992},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26179,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267745),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267730),
#   'unique_identifier': '8bfc1698-0e93-4f3f-8588-30ff81b85d18',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68778, 'x2': 68978, 'y1': 64749, 'y2': 64947},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26180,
#   'image': 330,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267803),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267789),
#   'unique_identifier': '63e76eee-a35f-41b5-8165-676f943ed29a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68763, 'x2': 68961, 'y1': 81718, 'y2': 81918},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26181,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267885),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267847),
#   'unique_identifier': 'c10a8bb0-1463-47cd-b90c-f470ea438e13',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15540, 'x2': 15738, 'y1': 13027, 'y2': 13225},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26182,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267952),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267938),
#   'unique_identifier': 'cb571d49-e4e3-47d0-9620-797d39c9a324',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15585, 'x2': 15783, 'y1': 33211, 'y2': 33409},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26183,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268015),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 267996),
#   'unique_identifier': 'b3a95aab-d4ca-489d-8b08-70036821058b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15619, 'x2': 15817, 'y1': 53401, 'y2': 53599},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26184,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268078),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268063),
#   'unique_identifier': 'cd99e98f-8394-4295-9748-ee803b51aad0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15668, 'x2': 15868, 'y1': 73594, 'y2': 73794},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26185,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268143),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268129),
#   'unique_identifier': 'c02c703d-555f-46e2-be73-e5a28e3fd25c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15701, 'x2': 15899, 'y1': 93777, 'y2': 93975},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26186,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268217),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268201),
#   'unique_identifier': '692e45e8-457c-496e-add7-e2747bf0f05c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25884, 'x2': 26082, 'y1': 13008, 'y2': 13206},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26187,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268308),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268292),
#   'unique_identifier': '48584a1d-e598-4fc6-a25c-2a62148082bc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25928, 'x2': 26126, 'y1': 33197, 'y2': 33395},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26188,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268375),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268355),
#   'unique_identifier': '1c8cb611-af81-4319-a3c1-22879dd41823',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25962, 'x2': 26160, 'y1': 53387, 'y2': 53585},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26189,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268462),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268440),
#   'unique_identifier': '5a750854-5819-417b-9367-432b8e722a0b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 26018, 'x2': 26218, 'y1': 73581, 'y2': 73781},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26190,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268552),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268530),
#   'unique_identifier': '42890d5f-58be-4db6-bcdc-9a6e7cd9bf31',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 26045, 'x2': 26243, 'y1': 93763, 'y2': 93961},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26191,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268628),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268613),
#   'unique_identifier': '817f8b92-e6b4-4c97-b709-fcd8f96eec0b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36228, 'x2': 36426, 'y1': 12989, 'y2': 13187},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26192,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268686),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 268672),
#   'unique_identifier': '14e88465-9914-4dd5-b8e2-62ed196aaca7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36283, 'x2': 36481, 'y1': 33186, 'y2': 33384},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
# ...
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26202,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269299),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269286),
#   'unique_identifier': '6d60ac41-58b4-4fce-9506-05c020de21e0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56968, 'x2': 57168, 'y1': 33148, 'y2': 33346},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26203,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269357),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269343),
#   'unique_identifier': 'cbe5a053-156e-47c1-875e-8068d85b3f22',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 57007, 'x2': 57207, 'y1': 53330, 'y2': 53528},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26204,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269414),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269400),
#   'unique_identifier': '3fb403fc-77ee-456c-9291-9c5daaa93fc5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 57050, 'x2': 57250, 'y1': 73502, 'y2': 73702},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26205,
#   'image': 332,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269471),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269457),
#   'unique_identifier': '90d8bb1b-ef27-46e1-ab04-67e24471126c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 57096, 'x2': 57296, 'y1': 93706, 'y2': 93906},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26206,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269529),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269515),
#   'unique_identifier': '7bcdc6f3-b5cf-41d2-af73-2852d7ad4240',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6990, 'x2': 7190, 'y1': 8001, 'y2': 8201},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26207,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269586),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269572),
#   'unique_identifier': '77c215ec-6c4f-4561-9326-4115bd00bc4a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6947, 'x2': 7145, 'y1': 25631, 'y2': 25829},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26208,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269648),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269631),
#   'unique_identifier': '58bab310-0cca-46d0-bfc6-52d176a18f06',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6933, 'x2': 7131, 'y1': 43191, 'y2': 43389},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26209,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269706),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269692),
#   'unique_identifier': '515a5e10-6410-4e31-8ff1-3dd38cec8f30',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6889, 'x2': 7089, 'y1': 60802, 'y2': 61000},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26210,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269774),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269755),
#   'unique_identifier': '19ca03ec-9798-4bd7-863d-97c89e8d3788',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 6852, 'x2': 7052, 'y1': 78362, 'y2': 78560},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26211,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269848),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269830),
#   'unique_identifier': 'e1968287-0559-4f43-89f5-194f668477b7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 20031, 'x2': 20231, 'y1': 8015, 'y2': 8215},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26212,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269932),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269917),
#   'unique_identifier': 'e5dabb71-f29d-48e0-a3bf-d9e2f48ac24d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19972, 'x2': 20170, 'y1': 25632, 'y2': 25830},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26213,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269996),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 269979),
#   'unique_identifier': 'b21190f1-5054-40fd-8ca0-b4d69b94ee5d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19958, 'x2': 20156, 'y1': 43192, 'y2': 43390},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26214,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270055),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270041),
#   'unique_identifier': '6d26dfe8-c33e-4d12-b3f8-01171450aec0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19930, 'x2': 20130, 'y1': 60810, 'y2': 61008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26215,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270113),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270099),
#   'unique_identifier': '8f30287d-57ab-4f7b-8e34-11bdb7248e54',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 19896, 'x2': 20096, 'y1': 78371, 'y2': 78569},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26216,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270170),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270156),
#   'unique_identifier': '90572960-dcfd-445e-9f01-79a313bc3456',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33068, 'x2': 33266, 'y1': 8019, 'y2': 8219},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26217,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270228),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270214),
#   'unique_identifier': '5e8b180c-cd06-4056-a342-1d312e878de9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 33035, 'x2': 33235, 'y1': 25631, 'y2': 25831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26218,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270314),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270299),
#   'unique_identifier': '0e1c3083-151c-482e-b090-5ab8f3708a4c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32996, 'x2': 33196, 'y1': 43222, 'y2': 43422},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26219,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270372),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270358),
#   'unique_identifier': 'dabe672b-570c-4787-a674-531d658aba01',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32965, 'x2': 33165, 'y1': 60821, 'y2': 61021},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26220,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270430),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270416),
#   'unique_identifier': '02412e77-6d75-44bf-833e-f71510162f55',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32932, 'x2': 33130, 'y1': 78389, 'y2': 78587},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26221,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270493),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270479),
#   'unique_identifier': 'd02517fd-eea7-4fd7-96ff-cab5dfc665e0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46105, 'x2': 46305, 'y1': 8052, 'y2': 8252},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26222,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270551),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270537),
#   'unique_identifier': '43456e83-0bda-4700-856f-3472996d0f78',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46070, 'x2': 46270, 'y1': 25641, 'y2': 25841},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26223,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270609),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270595),
#   'unique_identifier': 'f88ca87a-7b20-4713-8da2-9b7bb94989a0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46036, 'x2': 46236, 'y1': 43253, 'y2': 43453},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26224,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270666),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270652),
#   'unique_identifier': 'bbbaf6b8-ae60-4278-ba0a-0d94dee336d9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46000, 'x2': 46200, 'y1': 60837, 'y2': 61037},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26225,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270724),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270710),
#   'unique_identifier': '4de4de7b-2348-40b6-a634-d5ac621b06b4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45968, 'x2': 46168, 'y1': 78410, 'y2': 78608},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26226,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270917),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270898),
#   'unique_identifier': 'c087f152-ee2c-4d39-b350-5f0a19278d3f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 59144, 'x2': 59344, 'y1': 8081, 'y2': 8281},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26227,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270978),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 270964),
#   'unique_identifier': '0bd2dfcc-79da-439b-9200-b405ebea8406',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 59110, 'x2': 59310, 'y1': 25679, 'y2': 25879},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26228,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 271036),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 271022),
#   'unique_identifier': 'a4bec180-cd41-4c78-b899-32d8f43487ad',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 59075, 'x2': 59275, 'y1': 43291, 'y2': 43491},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26229,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 271093),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 271079),
#   'unique_identifier': 'e12a6e56-a5c4-4151-9581-a6217ef91aaa',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 59043, 'x2': 59243, 'y1': 60867, 'y2': 61067},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26230,
#   'image': 333,
#   'last_edit_time': datetime.datetime(2021, 2, 9, 13, 55, 43, 271150),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 9, 13, 55, 43, 271136),
#   'unique_identifier': '53d11e13-756a-45f1-b744-a22d6c3404a6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 59006, 'x2': 59206, 'y1': 78436, 'y2': 78634},
#   'verified_by_user': 'False'}]
