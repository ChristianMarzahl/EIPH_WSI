# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import json

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = '######' #'exact'
configuration.password = '#####' #'exact'
configuration.host = "https://euroexact01.euroimmun.de/" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download Rect annotation

# %%
annotation_types_points = {}
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
            
for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.name] = annotation_type

annotation_types_points
# Out:
# {'L0': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 11,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 2,
#   'vector_type': 1},
#  'L1': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 12,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 3,
#   'vector_type': 1},
#  'L2': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 13,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 4,
#   'vector_type': 1},
#  'L3': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 14,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 5,
#   'vector_type': 1},
#  'L4': {'area_hit_test': False,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 15,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 6,
#   'vector_type': 1},
#  'L5': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 16,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 7,
#   'vector_type': 1},
#  'L6': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 17,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 8,
#   'vector_type': 1},
#  'L7': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 18,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 9,
#   'vector_type': 1},
#  'L8': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 19,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 10,
#   'vector_type': 1},
#  'L9': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 20,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 11,
#   'vector_type': 1},
#  'L10': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 21,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 12,
#   'vector_type': 1},
#  'L11': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 22,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 13,
#   'vector_type': 1},
#  'L12': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 23,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 14,
#   'vector_type': 1},
#  'L13': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 24,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 15,
#   'vector_type': 1},
#  'L14': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 25,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 16,
#   'vector_type': 1},
#  'L15': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 26,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 17,
#   'vector_type': 1},
#  'L16': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 27,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 18,
#   'vector_type': 1},
#  'L17': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 28,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 18,
#   'vector_type': 1},
#  'L18': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 29,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 19,
#   'vector_type': 1},
#  'L19': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 30,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 20,
#   'vector_type': 1},
#  'L20': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 31,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 21,
#   'vector_type': 1},
#  'L21': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 32,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 21,
#   'vector_type': 1},
#  'L22': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 33,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 22,
#   'vector_type': 1},
#  'L23': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 34,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 23,
#   'vector_type': 1},
#  'L24': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 35,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 24,
#   'vector_type': 1}}

# %%
annotation_types_ref_rect
# Out:
# {'area_hit_test': False,
#  'closed': True,
#  'color_code': '#800080',
#  'default_height': 50000,
#  'default_width': 50000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 36,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 3,
#  'sort_order': 1,
#  'vector_type': 1}

# %%
names = [("CRC-A1-5 40X.tif", 5), ("CRC-A1-1 40X.tif", 1), 
         ("CRC-A1-5_stitched.tif", 5), ("CRC-A1-1_2_stitched.tif", 1)]

# %%
images_api.list_images(name=names[0][0])
# Out:
# {'count': 1,
#  'next': None,
#  'previous': None,
#  'results': [{'annotations': 'Annotations not load please remove '
#                              'omit=annotations',
#               'filename': 'CRC-A1-5 40X.tif',
#               'height': 105536,
#               'id': 20,
#               'image_set': 8,
#               'image_type': 0,
#               'mpp': 0.25,
#               'name': 'CRC-A1-5 40X.tif',
#               'objective_power': 40.0,
#               'time': datetime.datetime(2021, 1, 15, 23, 16, 23, 34132),
#               'width': 97840}]}

# %%
annotations = []

for name, pair_id  in names:
    
    image = images_api.list_images(name=name).results[0]
    
    for anno in annotations_api.list_annotations(image=image.id, annotation_type=annotation_types_ref_rect.id, # BoundBox ID
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        annotations.append([image.id, image.name, pair_id, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "pair", "id", "vector", "unique_identifier", "annotation_type"])
annotations.head()
# Out:
#    image_id               image_name  pair     id  \
# 0        20         CRC-A1-5 40X.tif     5  30841
# 1        19         CRC-A1-1 40X.tif     1  30843
# 2        10    CRC-A1-5_stitched.tif     5  30840
# 3        11  CRC-A1-1_2_stitched.tif     1  30842
#
#                                               vector  \
# 0  {'x1': 652, 'x2': 71998, 'y1': 6290, 'y2': 105...
# 1   {'x1': 225, 'x2': 70248, 'y1': 421, 'y2': 77413}
# 2  {'x1': 14906, 'x2': 143453, 'y1': 7915, 'y2': ...
# 3  {'x1': 23026, 'x2': 147549, 'y1': 1432, 'y2': ...
#
#                       unique_identifier  annotation_type
# 0  e3d05bf7-a2db-4bea-9b5b-2ea7038e2d7b               36
# 1  cdee5cc7-f5ce-481c-a483-689526d5d02c               36
# 2  36665283-c06e-442d-bd4e-893e8ccaec9e               36
# 3  12e73dc1-72eb-484f-b46d-b4c03d7e0cbc               36

# %%
num_lines = 5
patch_size = 100

registration_points = []
for id, bounding_box in annotations.iterrows():
    
    box_width = bounding_box.vector["x2"] - bounding_box.vector["x1"]
    box_height = bounding_box.vector["y2"] - bounding_box.vector["y1"]
    
    step_size_x = box_width // num_lines
    step_size_y = box_height // num_lines
        
    point_index = 0
    for x in range(bounding_box.vector["x1"] + step_size_x //2, bounding_box.vector["x2"], step_size_x):
        for y in range(bounding_box.vector["y1"] + step_size_y //2, bounding_box.vector["y2"], step_size_y):
            
            ref_point = annotation_types_points[f"L{point_index}"]
                
            vector = {"x1": x - patch_size, "y1": y - patch_size, 
                          "x2": x + patch_size, "y2": y + patch_size}
                
            point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id]
                
            registration_points.append(point)
                
            point_index += 1
    
registration_points = pd.DataFrame(registration_points, 
                                   columns=["image_id", "vector", "point_index", "point_name", "point_id"])
registration_points
# Out:
#     image_id                                             vector  point_index  \
# 0         20  {'x1': 7686, 'y1': 16069, 'x2': 7886, 'y2': 16...            0
# 1         20  {'x1': 7686, 'y1': 35827, 'x2': 7886, 'y2': 36...            1
# 2         20  {'x1': 7686, 'y1': 55585, 'x2': 7886, 'y2': 55...            2
# 3         20  {'x1': 7686, 'y1': 75343, 'x2': 7886, 'y2': 75...            3
# 4         20  {'x1': 7686, 'y1': 95101, 'x2': 7886, 'y2': 95...            4
# ..       ...                                                ...          ...
# 95        11  {'x1': 134994, 'y1': 15674, 'x2': 135194, 'y2'...           20
# 96        11  {'x1': 134994, 'y1': 44359, 'x2': 135194, 'y2'...           21
# 97        11  {'x1': 134994, 'y1': 73044, 'x2': 135194, 'y2'...           22
# 98        11  {'x1': 134994, 'y1': 101729, 'x2': 135194, 'y2...           23
# 99        11  {'x1': 134994, 'y1': 130414, 'x2': 135194, 'y2...           24
#
#    point_name  point_id
# 0          L0        11
# 1          L1        12
# 2          L2        13
# 3          L3        14
# 4          L4        15
# ..        ...       ...
# 95        L20        31
# 96        L21        32
# 97        L22        33
# 98        L23        34
# 99        L24        35
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Upload ref Points to EXACT

# %%
annotations_to_upload = []

for id, bounding_box in tqdm(registration_points.iterrows()):
    
    
    exact_annos =  annotations_api.list_annotations(image=bounding_box.image_id, annotation_type=bounding_box.point_id).results
    
    if len(exact_annos) == 0:
        anno = Annotation(annotation_type=bounding_box.point_id, 
                          vector=bounding_box.vector, 
                          image=bounding_box.image_id)

        annotations_to_upload.append(anno)

    else:
        prinf(f"ImageId: {bounding_box.image_id}, AnnotationType: {bounding_box.point_id} combination allready exists!")
# Out:
# 100it [00:18,  5.42it/s]

# %%
annotations_to_upload[:3]
# Out:
# [{'annotation_type': 11,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 20,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 16069, 'y2': 16269},
#   'verified_by_user': None},
#  {'annotation_type': 12,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 20,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 35827, 'y2': 36027},
#   'verified_by_user': None},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 20,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 55585, 'y2': 55785},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
#annotations_api.create_annotation(body=annotations_to_upload)
# Out:
# [{'annotation_type': 11,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30844,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519762),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519735),
#   'unique_identifier': 'a8c564e8-fd69-43b7-b9a5-f1f16c7bbbd5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 16069, 'y2': 16269},
#   'verified_by_user': 'False'},
#  {'annotation_type': 12,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30845,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519815),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519806),
#   'unique_identifier': '9a8e6a0c-0a43-4f6c-b6d5-4eeeca8b0dcc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 35827, 'y2': 36027},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30846,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519851),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519842),
#   'unique_identifier': 'aacda99c-5297-402f-bddc-8d043aeff4ed',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 55585, 'y2': 55785},
#   'verified_by_user': 'False'},
#  {'annotation_type': 14,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30847,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519884),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519875),
#   'unique_identifier': '74a268f2-dab0-497f-b11b-57dd327313ba',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 75343, 'y2': 75543},
#   'verified_by_user': 'False'},
#  {'annotation_type': 15,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30848,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519916),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519908),
#   'unique_identifier': '88a2ff08-15a3-40e9-9005-3ded346f4340',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7686, 'x2': 7886, 'y1': 95101, 'y2': 95301},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30849,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519948),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519940),
#   'unique_identifier': 'cbad03e3-cc30-4d09-964d-283d20d23c87',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21955, 'x2': 22155, 'y1': 16069, 'y2': 16269},
#   'verified_by_user': 'False'},
#  {'annotation_type': 17,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30850,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519980),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 519972),
#   'unique_identifier': '7242c882-9ad0-4c15-85fb-661fefecd12c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21955, 'x2': 22155, 'y1': 35827, 'y2': 36027},
#   'verified_by_user': 'False'},
#  {'annotation_type': 18,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30851,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520012),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520004),
#   'unique_identifier': 'b3065a2e-1f94-4f1b-8b76-17ad7a551d0c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21955, 'x2': 22155, 'y1': 55585, 'y2': 55785},
#   'verified_by_user': 'False'},
#  {'annotation_type': 19,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30852,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520044),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520036),
#   'unique_identifier': '14d8a576-5da5-4b5f-893f-92462464d39d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21955, 'x2': 22155, 'y1': 75343, 'y2': 75543},
#   'verified_by_user': 'False'},
#  {'annotation_type': 20,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30853,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520076),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520068),
#   'unique_identifier': 'f5bb57ec-d1d7-4d7f-8698-33b47a5ad9ab',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21955, 'x2': 22155, 'y1': 95101, 'y2': 95301},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30854,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520108),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520100),
#   'unique_identifier': '03adbb52-3d0e-491a-ab11-0d97a53bddbd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36224, 'x2': 36424, 'y1': 16069, 'y2': 16269},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30855,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520140),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520132),
#   'unique_identifier': '49a77c8f-cb72-4af5-8c8c-df67dfaf5548',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36224, 'x2': 36424, 'y1': 35827, 'y2': 36027},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30856,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520172),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520164),
#   'unique_identifier': 'c87bc74b-5f4a-479a-a331-ac65fcc2137d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36224, 'x2': 36424, 'y1': 55585, 'y2': 55785},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30857,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520204),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520196),
#   'unique_identifier': '721f22de-25c7-4bc8-8562-6ae2e20cbb60',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36224, 'x2': 36424, 'y1': 75343, 'y2': 75543},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30858,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520236),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520228),
#   'unique_identifier': '06f36fa8-3965-41ec-9020-11716059d914',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36224, 'x2': 36424, 'y1': 95101, 'y2': 95301},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30859,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520276),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520266),
#   'unique_identifier': 'fbfd2d0e-259c-4abf-bdf6-5d9e0c75cbf7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50493, 'x2': 50693, 'y1': 16069, 'y2': 16269},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30860,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520309),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520300),
#   'unique_identifier': '812e4c9d-b622-4c78-ad86-27a9883e6385',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50493, 'x2': 50693, 'y1': 35827, 'y2': 36027},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30861,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520341),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520333),
#   'unique_identifier': '3973b1d1-7de4-4cfa-a364-03f8fa1ee85a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50493, 'x2': 50693, 'y1': 55585, 'y2': 55785},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30862,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520373),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520364),
#   'unique_identifier': '7bfbeef4-307d-4c2f-a6fe-fb47024188c2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50493, 'x2': 50693, 'y1': 75343, 'y2': 75543},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30863,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520405),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520396),
#   'unique_identifier': 'e612421d-a329-4201-915a-c2d8cfde14a6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 50493, 'x2': 50693, 'y1': 95101, 'y2': 95301},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30864,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520437),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520429),
#   'unique_identifier': 'a39bf213-f2a5-4ebd-8df7-33a90b26e848',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64762, 'x2': 64962, 'y1': 16069, 'y2': 16269},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30865,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520469),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520461),
#   'unique_identifier': '486dba7b-2de9-4726-b11b-7a8c1f85f4bd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64762, 'x2': 64962, 'y1': 35827, 'y2': 36027},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30866,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520501),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520492),
#   'unique_identifier': '270fad24-c041-478c-8cab-661282620b7e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64762, 'x2': 64962, 'y1': 55585, 'y2': 55785},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30867,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520533),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520525),
#   'unique_identifier': 'c8da5df0-f644-488f-b093-e5bea1908263',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64762, 'x2': 64962, 'y1': 75343, 'y2': 75543},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30868,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520565),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520557),
#   'unique_identifier': '09caac96-822b-4e32-a3e3-90791b42f324',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64762, 'x2': 64962, 'y1': 95101, 'y2': 95301},
#   'verified_by_user': 'False'},
#  {'annotation_type': 11,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30869,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520597),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520588),
#   'unique_identifier': 'a3d2737f-61a7-4365-b1a1-64aa4c53fcaa',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7127, 'x2': 7327, 'y1': 8020, 'y2': 8220},
#   'verified_by_user': 'False'},
#  {'annotation_type': 12,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30870,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520629),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520620),
#   'unique_identifier': 'dcc5c5ee-3dd7-4076-ae57-e7a039ce2257',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7127, 'x2': 7327, 'y1': 23418, 'y2': 23618},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30871,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520660),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520652),
#   'unique_identifier': '8d09083f-188a-4783-953f-bc8aa732ee5f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7127, 'x2': 7327, 'y1': 38816, 'y2': 39016},
#   'verified_by_user': 'False'},
#  {'annotation_type': 14,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30872,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520692),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520684),
#   'unique_identifier': 'c88e0efa-98f5-4eaa-84ab-1f0e55e4ed2f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7127, 'x2': 7327, 'y1': 54214, 'y2': 54414},
#   'verified_by_user': 'False'},
#  {'annotation_type': 15,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30873,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520723),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520715),
#   'unique_identifier': 'cce82770-5022-4ebf-903e-7a40490c5df4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 7127, 'x2': 7327, 'y1': 69612, 'y2': 69812},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30874,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520755),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520747),
#   'unique_identifier': '71f9a520-a5e0-4046-aa73-3e3c7bf70a95',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21131, 'x2': 21331, 'y1': 8020, 'y2': 8220},
#   'verified_by_user': 'False'},
#  {'annotation_type': 17,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30875,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520787),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520778),
#   'unique_identifier': 'e6f8e48c-b62e-4047-b9d4-b1c604e0c11c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21131, 'x2': 21331, 'y1': 23418, 'y2': 23618},
#   'verified_by_user': 'False'},
#  {'annotation_type': 18,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30876,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520818),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520810),
#   'unique_identifier': '3ee3d536-42e7-4a44-89a4-599a3f1fadf5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21131, 'x2': 21331, 'y1': 38816, 'y2': 39016},
#   'verified_by_user': 'False'},
#  {'annotation_type': 19,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30877,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520849),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520841),
#   'unique_identifier': '9287c4df-2c63-4525-aa9c-46af21b81eda',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21131, 'x2': 21331, 'y1': 54214, 'y2': 54414},
#   'verified_by_user': 'False'},
#  {'annotation_type': 20,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30878,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520881),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520873),
#   'unique_identifier': 'e6ea3c44-5fa4-45d4-9362-6a9bf1efc628',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 21131, 'x2': 21331, 'y1': 69612, 'y2': 69812},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30879,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520912),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520904),
#   'unique_identifier': '968ec794-17c0-4356-a898-6066a5230cde',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35135, 'x2': 35335, 'y1': 8020, 'y2': 8220},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30880,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520944),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520935),
#   'unique_identifier': '2b220ce4-245e-4c4f-a806-d3eae2ca6aba',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35135, 'x2': 35335, 'y1': 23418, 'y2': 23618},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30881,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520975),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520967),
#   'unique_identifier': '8499ef15-e9dd-4905-8bc7-dccb03ab1549',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35135, 'x2': 35335, 'y1': 38816, 'y2': 39016},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30882,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521006),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 520998),
#   'unique_identifier': 'de5b6313-3661-4944-9221-2a694311760c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35135, 'x2': 35335, 'y1': 54214, 'y2': 54414},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30883,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521038),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521030),
#   'unique_identifier': 'a637247f-476a-4ae4-ad39-8ddab577cf10',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35135, 'x2': 35335, 'y1': 69612, 'y2': 69812},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30884,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521069),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521061),
#   'unique_identifier': '81e12530-e1c6-4fff-80e6-03bee56c3fe9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49139, 'x2': 49339, 'y1': 8020, 'y2': 8220},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30885,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521102),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521093),
#   'unique_identifier': 'b43d92af-0f88-4a30-acb6-ac9ad56a1af8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49139, 'x2': 49339, 'y1': 23418, 'y2': 23618},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30886,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521133),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521125),
#   'unique_identifier': '09b3d09a-d73b-456a-bb39-c795048d41c9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49139, 'x2': 49339, 'y1': 38816, 'y2': 39016},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30887,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521165),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521157),
#   'unique_identifier': '8030f35b-cd3c-456e-8021-18a848551d0b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49139, 'x2': 49339, 'y1': 54214, 'y2': 54414},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30888,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521196),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521188),
#   'unique_identifier': 'b317a3dd-ca0c-42ee-8758-7e14ce837189',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49139, 'x2': 49339, 'y1': 69612, 'y2': 69812},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30889,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521228),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521219),
#   'unique_identifier': '14b963be-cd95-48df-be89-1dbdba468386',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 63143, 'x2': 63343, 'y1': 8020, 'y2': 8220},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30890,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521259),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521250),
#   'unique_identifier': 'fcc7ff7c-e244-4656-8969-45420d4a222e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 63143, 'x2': 63343, 'y1': 23418, 'y2': 23618},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30891,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521290),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521282),
#   'unique_identifier': '0e2dd11e-a33f-40d1-b262-c745d3dd9f04',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 63143, 'x2': 63343, 'y1': 38816, 'y2': 39016},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30892,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521322),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521313),
#   'unique_identifier': '1f1b39b7-818e-4182-a44a-49ce82879fc7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 63143, 'x2': 63343, 'y1': 54214, 'y2': 54414},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30893,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521353),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521345),
#   'unique_identifier': '43084c8a-f38f-4d79-bfaf-09b12d42b264',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 63143, 'x2': 63343, 'y1': 69612, 'y2': 69812},
#   'verified_by_user': 'False'},
#  {'annotation_type': 11,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30894,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521385),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521377),
#   'unique_identifier': 'bba292f4-46f3-42af-ab39-02aef0ab3883',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 27660, 'x2': 27860, 'y1': 26305, 'y2': 26505},
#   'verified_by_user': 'False'},
#  {'annotation_type': 12,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30895,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521417),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521409),
#   'unique_identifier': '6078de72-3d04-4369-91b0-cd201599dbbb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 27660, 'x2': 27860, 'y1': 63285, 'y2': 63485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30896,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521449),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521441),
#   'unique_identifier': '2881ab98-6105-4683-8a85-e133c1e17449',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 27660, 'x2': 27860, 'y1': 100265, 'y2': 100465},
#   'verified_by_user': 'False'},
#  {'annotation_type': 14,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30897,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521480),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521472),
#   'unique_identifier': '39c65cac-ebd1-4223-bee2-40bf7633acdb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 27660, 'x2': 27860, 'y1': 137245, 'y2': 137445},
#   'verified_by_user': 'False'},
#  {'annotation_type': 15,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30898,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521512),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521504),
#   'unique_identifier': '9f1377ad-2346-4fc1-92cb-211abf0afb61',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 27660, 'x2': 27860, 'y1': 174225, 'y2': 174425},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30899,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521544),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521536),
#   'unique_identifier': '2c0b3988-8b89-485d-83bd-5cd5deac5a5d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53369, 'x2': 53569, 'y1': 26305, 'y2': 26505},
#   'verified_by_user': 'False'},
#  {'annotation_type': 17,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30900,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521575),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521567),
#   'unique_identifier': '30403a86-04ce-49f3-bc55-fb56fbce8144',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53369, 'x2': 53569, 'y1': 63285, 'y2': 63485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 18,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30901,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521607),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521599),
#   'unique_identifier': 'e83a11e6-a273-441a-8c12-5a2c9eccacda',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53369, 'x2': 53569, 'y1': 100265, 'y2': 100465},
#   'verified_by_user': 'False'},
#  {'annotation_type': 19,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30902,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521638),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521630),
#   'unique_identifier': 'c2818c1d-c53a-4350-92fa-2fef30ab1375',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53369, 'x2': 53569, 'y1': 137245, 'y2': 137445},
#   'verified_by_user': 'False'},
#  {'annotation_type': 20,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30903,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521672),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521664),
#   'unique_identifier': 'edc6f2a8-7560-450b-aed9-cb4c6a599e01',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53369, 'x2': 53569, 'y1': 174225, 'y2': 174425},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30904,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521705),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521696),
#   'unique_identifier': 'c8534b0b-b3bf-4753-a05d-4e71f89d72e8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 79078, 'x2': 79278, 'y1': 26305, 'y2': 26505},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30905,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521737),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521728),
#   'unique_identifier': '8fb0ae4c-aea2-4de6-b124-fab4a308026c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 79078, 'x2': 79278, 'y1': 63285, 'y2': 63485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30906,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521768),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521760),
#   'unique_identifier': 'c8a5d505-558a-4c3b-b618-e47b9ac70f0f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 79078, 'x2': 79278, 'y1': 100265, 'y2': 100465},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30907,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521799),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521791),
#   'unique_identifier': 'b669fff3-304f-4f2a-a5ef-c51c944e327c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 79078, 'x2': 79278, 'y1': 137245, 'y2': 137445},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30908,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521831),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521823),
#   'unique_identifier': '53224e94-c79c-491d-bbc4-f3355ec8d6b0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 79078, 'x2': 79278, 'y1': 174225, 'y2': 174425},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30909,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521863),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521854),
#   'unique_identifier': '32b88981-4a10-42aa-bc09-357028872452',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 104787, 'x2': 104987, 'y1': 26305, 'y2': 26505},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30910,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521895),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521886),
#   'unique_identifier': 'f8bff564-fea6-4b91-93a7-481de0a78e63',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 104787, 'x2': 104987, 'y1': 63285, 'y2': 63485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30911,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521926),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521918),
#   'unique_identifier': '46706674-43de-4bae-a4e5-769affdaa492',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 104787, 'x2': 104987, 'y1': 100265, 'y2': 100465},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30912,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521958),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521950),
#   'unique_identifier': '3f6854eb-24c6-4d0b-a000-77c73ee70739',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 104787, 'x2': 104987, 'y1': 137245, 'y2': 137445},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30913,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521990),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 521982),
#   'unique_identifier': 'dbae2b2f-06e2-4dec-b15e-c6b81debe25d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 104787, 'x2': 104987, 'y1': 174225, 'y2': 174425},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30914,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522022),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522014),
#   'unique_identifier': 'bad164b7-67e2-4c6a-b2b3-7685dc2a85fc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 130496, 'x2': 130696, 'y1': 26305, 'y2': 26505},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30915,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522054),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522045),
#   'unique_identifier': '586a3c1c-8f6f-476e-bd00-ad7c8c3b0f0f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 130496, 'x2': 130696, 'y1': 63285, 'y2': 63485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30916,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522086),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522077),
#   'unique_identifier': '26f2177f-561e-4bb6-83cb-cdbe365965d4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 130496, 'x2': 130696, 'y1': 100265, 'y2': 100465},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30917,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522119),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522111),
#   'unique_identifier': 'd49a122c-74be-4b7c-a84b-d4a9a46ebf9c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 130496, 'x2': 130696, 'y1': 137245, 'y2': 137445},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30918,
#   'image': 10,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522151),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522143),
#   'unique_identifier': '6ade9585-f839-4ff4-b02d-3a3bf1d0b333',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 130496, 'x2': 130696, 'y1': 174225, 'y2': 174425},
#   'verified_by_user': 'False'},
#  {'annotation_type': 11,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30919,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522183),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522174),
#   'unique_identifier': '9de3acad-3251-491d-9d22-998728ea6202',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35378, 'x2': 35578, 'y1': 15674, 'y2': 15874},
#   'verified_by_user': 'False'},
#  {'annotation_type': 12,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30920,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522215),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522206),
#   'unique_identifier': '8beac2d9-7db4-4c6e-aabc-40e9669891bb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35378, 'x2': 35578, 'y1': 44359, 'y2': 44559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 13,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30921,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522246),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522238),
#   'unique_identifier': 'eeac75a8-a480-499f-b570-305c51eab13d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35378, 'x2': 35578, 'y1': 73044, 'y2': 73244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 14,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30922,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522278),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522270),
#   'unique_identifier': '0773d8a9-eee4-4e99-8db2-36d683dbaded',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35378, 'x2': 35578, 'y1': 101729, 'y2': 101929},
#   'verified_by_user': 'False'},
#  {'annotation_type': 15,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30923,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522310),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522302),
#   'unique_identifier': '611582da-e86c-4b7c-a501-c6042622f1af',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35378, 'x2': 35578, 'y1': 130414, 'y2': 130614},
#   'verified_by_user': 'False'},
#  {'annotation_type': 16,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30924,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522342),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522334),
#   'unique_identifier': 'bd035a5f-c7f5-4253-bed0-51b0d04056c3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 60282, 'x2': 60482, 'y1': 15674, 'y2': 15874},
#   'verified_by_user': 'False'},
#  {'annotation_type': 17,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30925,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522374),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522366),
#   'unique_identifier': 'bce8ee21-777b-4382-97f0-e077f66d186f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 60282, 'x2': 60482, 'y1': 44359, 'y2': 44559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 18,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30926,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522407),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522398),
#   'unique_identifier': '3698470d-2eef-403a-a12d-e0b56dba8e59',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 60282, 'x2': 60482, 'y1': 73044, 'y2': 73244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 19,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30927,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522439),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522431),
#   'unique_identifier': 'e402d2b8-5d7c-4e07-ad75-e3b908ed8095',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 60282, 'x2': 60482, 'y1': 101729, 'y2': 101929},
#   'verified_by_user': 'False'},
#  {'annotation_type': 20,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30928,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522479),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522470),
#   'unique_identifier': '2b0c70da-8247-49a3-92f5-c7c47721f05b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 60282, 'x2': 60482, 'y1': 130414, 'y2': 130614},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30929,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522513),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522504),
#   'unique_identifier': '50507710-c13f-4342-a560-e5443d1aec42',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85186, 'x2': 85386, 'y1': 15674, 'y2': 15874},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30930,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522545),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522537),
#   'unique_identifier': 'ce26fb47-36f6-405d-930e-421f9b951013',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85186, 'x2': 85386, 'y1': 44359, 'y2': 44559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30931,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522577),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522569),
#   'unique_identifier': 'ba1f4aa3-139c-4eab-8877-bf1ac02c68a3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85186, 'x2': 85386, 'y1': 73044, 'y2': 73244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30932,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522609),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522601),
#   'unique_identifier': '3a0ec26c-5556-4c08-930d-ef467d722933',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85186, 'x2': 85386, 'y1': 101729, 'y2': 101929},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30933,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522642),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522634),
#   'unique_identifier': 'ff364dac-c2d4-4291-89e6-1043f581849e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85186, 'x2': 85386, 'y1': 130414, 'y2': 130614},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30934,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522688),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522678),
#   'unique_identifier': '4409f85d-e5dd-47c4-a1a1-e8b97c7f5411',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110090, 'x2': 110290, 'y1': 15674, 'y2': 15874},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30935,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522722),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522713),
#   'unique_identifier': 'd3034cd1-3cdb-4363-bf27-057e58eb2d41',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110090, 'x2': 110290, 'y1': 44359, 'y2': 44559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30936,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522755),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522746),
#   'unique_identifier': 'a7d86c36-20eb-4706-ba6a-70a01a50bee2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110090, 'x2': 110290, 'y1': 73044, 'y2': 73244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30937,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522787),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522779),
#   'unique_identifier': 'b95851d0-aec6-42b6-ad5f-5a1e08139f5e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110090, 'x2': 110290, 'y1': 101729, 'y2': 101929},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30938,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522819),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522811),
#   'unique_identifier': 'f28d47a8-0b0b-466c-894f-eb588fdecae3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110090, 'x2': 110290, 'y1': 130414, 'y2': 130614},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30939,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522851),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522843),
#   'unique_identifier': '2e2cc11c-25dc-4eff-93fa-32c383fe442e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 134994, 'x2': 135194, 'y1': 15674, 'y2': 15874},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30940,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522883),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522875),
#   'unique_identifier': '60fb9616-56de-4aa6-b73e-7169e48ec35c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 134994, 'x2': 135194, 'y1': 44359, 'y2': 44559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30941,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522915),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522907),
#   'unique_identifier': '9393e63d-af48-4080-8c76-1113edde1cda',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 134994, 'x2': 135194, 'y1': 73044, 'y2': 73244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30942,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522948),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522939),
#   'unique_identifier': 'c21f0694-6802-4483-88e6-7fedf29936a6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 134994, 'x2': 135194, 'y1': 101729, 'y2': 101929},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30943,
#   'image': 11,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522979),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 10, 44, 18, 522971),
#   'unique_identifier': '3464bedf-4642-4779-8251-a9d6e863aa3e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 134994, 'x2': 135194, 'y1': 130414, 'y2': 130614},
#   'verified_by_user': 'False'}]
