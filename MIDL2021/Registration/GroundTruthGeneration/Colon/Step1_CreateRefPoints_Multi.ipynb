# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import json

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'exact' #'exact'
configuration.password = 'exact' #'exact'
configuration.host = "http://127.0.0.1:1337" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download Rect annotation

# %%
annotation_types_points = {}
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
            
for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.name] = annotation_type

annotation_types_points
# Out:
# {'L0': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 21,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L1': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 22,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L2': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 23,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L3': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 24,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L4': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 25,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L5': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 26,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L6': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 27,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L7': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 28,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L8': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 29,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L9': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 30,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L10': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 31,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L11': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 32,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L12': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 33,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L13': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 34,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L14': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 35,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L15': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 36,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L16': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 37,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L17': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 38,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L18': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 39,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L19': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 40,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L20': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 41,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L21': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 42,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L22': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 43,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L23': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 44,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L24': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 45,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotation_types_ref_rect
# Out:
# {'area_hit_test': True,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 5000,
#  'default_width': 5000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 10,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 6,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="Multi_IHC", expand="product_set,product_set.annotationtype_set").results[0]


for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id, annotation_type=annotation_types_ref_rect.id, # BoundBox ID
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        annotations.append([image.id, image.name, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "id", "vector", "unique_identifier", "annotation_type"])
annotations.head()
# Out:
#    image_id     image_name     id  \
# 0       334   CRC-A1-1.tif  26231
# 1       336   CRC-A1-2.tif  26232
# 2       338   CRC-A1-5.tif  26233
# 3       339  CRC-A1-10.tif  26234
# 4       341  CRC-A1-13.tif  26235
#
#                                               vector  \
# 0  {'x1': 11416, 'x2': 149099, 'y1': 2174, 'y2': ...
# 1  {'x1': 1513, 'x2': 122258, 'y1': 739, 'y2': 14...
# 2  {'x1': 9664, 'x2': 153871, 'y1': 5846, 'y2': 1...
# 3  {'x1': 3561, 'x2': 151374, 'y1': 4162, 'y2': 1...
# 4  {'x1': 40, 'x2': 117686, 'y1': 1425, 'y2': 145...
#
#                       unique_identifier  annotation_type
# 0  a67f3a29-b7ce-41b3-8510-478721ad7ec5               10
# 1  81c548d9-dad8-47dc-9792-435488beacb1               10
# 2  b749b0cb-a7e3-47b0-b70e-666a2434f6dd               10
# 3  59ce9693-433a-4772-a163-5c1a98928f25               10
# 4  87f879d5-df29-4eed-bf46-44f5e397f3b6               10

# %%
num_lines = 5
patch_size = 100

registration_points = []
for id, bounding_box in annotations.iterrows():
    
    box_width = bounding_box.vector["x2"] - bounding_box.vector["x1"]
    box_height = bounding_box.vector["y2"] - bounding_box.vector["y1"]
    
    step_size_x = box_width // num_lines
    step_size_y = box_height // num_lines
        
    point_index = 0
    for x in range(bounding_box.vector["x1"] + step_size_x //2, bounding_box.vector["x2"], step_size_x):
        for y in range(bounding_box.vector["y1"] + step_size_y //2, bounding_box.vector["y2"], step_size_y):
            
            ref_point = annotation_types_points[f"L{point_index}"]
                
            vector = {"x1": x - patch_size, "y1": y - patch_size, 
                          "x2": x + patch_size, "y2": y + patch_size}
                
            point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id]
                
            registration_points.append(point)
                
            point_index += 1
    
registration_points = pd.DataFrame(registration_points, 
                                   columns=["image_id", "vector", "point_index", "point_name", "point_id"])
registration_points
# Out:
#      image_id                                             vector  point_index  \
# 0         334  {'x1': 25084, 'y1': 16467, 'x2': 25284, 'y2': ...            0
# 1         334  {'x1': 25084, 'y1': 45253, 'x2': 25284, 'y2': ...            1
# 2         334  {'x1': 25084, 'y1': 74039, 'x2': 25284, 'y2': ...            2
# 3         334  {'x1': 25084, 'y1': 102825, 'x2': 25284, 'y2':...            3
# 4         334  {'x1': 25084, 'y1': 131611, 'x2': 25284, 'y2':...            4
# ..        ...                                                ...          ...
# 120       341  {'x1': 105820, 'y1': 15738, 'x2': 106020, 'y2'...           20
# 121       341  {'x1': 105820, 'y1': 44564, 'x2': 106020, 'y2'...           21
# 122       341  {'x1': 105820, 'y1': 73390, 'x2': 106020, 'y2'...           22
# 123       341  {'x1': 105820, 'y1': 102216, 'x2': 106020, 'y2...           23
# 124       341  {'x1': 105820, 'y1': 131042, 'x2': 106020, 'y2...           24
#
#     point_name  point_id
# 0           L0        21
# 1           L1        22
# 2           L2        23
# 3           L3        24
# 4           L4        25
# ..         ...       ...
# 120        L20        41
# 121        L21        42
# 122        L22        43
# 123        L23        44
# 124        L24        45
#
# [125 rows x 5 columns]

# %% [markdown]
# ## Upload ref Points to EXACT

# %%
annotations_to_upload = []

for id, bounding_box in tqdm(registration_points.iterrows()):
    
    
    exact_annos =  annotations_api.list_annotations(image=bounding_box.image_id, annotation_type=bounding_box.point_id).results
    
    if len(exact_annos) == 0:
        anno = Annotation(annotation_type=bounding_box.point_id, 
                          vector=bounding_box.vector, 
                          image=bounding_box.image_id)

        annotations_to_upload.append(anno)

    else:
        prinf(f"ImageId: {bounding_box.image_id}, AnnotationType: {bounding_box.point_id} combination allready exists!")
# Out:
# 125it [00:44,  2.79it/s]

# %%
annotations_to_upload[:3]
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 334,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 16467, 'y2': 16667},
#   'verified_by_user': None},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 334,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 45253, 'y2': 45453},
#   'verified_by_user': None},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 334,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 74039, 'y2': 74239},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
annotations_api.create_annotation(body=annotations_to_upload)
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26236,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 821846),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 821823),
#   'unique_identifier': 'd68e7b9a-d3ae-43ea-9c7c-4dcac427c588',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 16467, 'y2': 16667},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26237,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 821908),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 821894),
#   'unique_identifier': '0ca22054-a283-4010-bde9-ecb8482c1bd3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 45253, 'y2': 45453},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26238,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 821961),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 821948),
#   'unique_identifier': '7fb53235-d051-4d81-9d70-da87725bc6f6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 74039, 'y2': 74239},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26239,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822014),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822000),
#   'unique_identifier': '2a73c263-0dae-4151-82e0-c661ad26930c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 102825, 'y2': 103025},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26240,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822067),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822053),
#   'unique_identifier': '0b4c38dd-b8a5-49bb-b0be-735b43e47cac',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 25084, 'x2': 25284, 'y1': 131611, 'y2': 131811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26241,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822120),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822106),
#   'unique_identifier': '325de832-a522-4d95-ab15-d5748eaba0fa',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52620, 'x2': 52820, 'y1': 16467, 'y2': 16667},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26242,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822172),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822158),
#   'unique_identifier': '457a2078-06a5-4cab-bcab-8df0b6beda54',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52620, 'x2': 52820, 'y1': 45253, 'y2': 45453},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26243,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822224),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822210),
#   'unique_identifier': '274036df-4e5d-41c6-8283-f7fa0c126ad3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52620, 'x2': 52820, 'y1': 74039, 'y2': 74239},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26244,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822276),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822262),
#   'unique_identifier': '2fe4e5c3-57f1-481a-b1a4-3827ca1546f8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52620, 'x2': 52820, 'y1': 102825, 'y2': 103025},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26245,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822328),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822314),
#   'unique_identifier': '30857dcd-173d-42ca-80d8-ef2436d16a68',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52620, 'x2': 52820, 'y1': 131611, 'y2': 131811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26246,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822401),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822385),
#   'unique_identifier': '288cbf3b-aa20-475b-abef-36b45981fe1b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 80156, 'x2': 80356, 'y1': 16467, 'y2': 16667},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26247,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822457),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822442),
#   'unique_identifier': '9ca8de64-4762-439b-909e-697abf038651',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 80156, 'x2': 80356, 'y1': 45253, 'y2': 45453},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26248,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822511),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822497),
#   'unique_identifier': '40e1fb87-e690-4865-a990-b115d8e05730',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 80156, 'x2': 80356, 'y1': 74039, 'y2': 74239},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26249,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822565),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822551),
#   'unique_identifier': '16acd5bb-3935-45cd-8a78-98ae1fd76d02',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 80156, 'x2': 80356, 'y1': 102825, 'y2': 103025},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26250,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822618),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822604),
#   'unique_identifier': 'be54ff16-955d-4c02-91ab-946bf71841b8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 80156, 'x2': 80356, 'y1': 131611, 'y2': 131811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26251,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822672),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822658),
#   'unique_identifier': 'c8621c63-9e83-485b-ac46-367ef7a3dc83',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 107692, 'x2': 107892, 'y1': 16467, 'y2': 16667},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26252,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822726),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822712),
#   'unique_identifier': '76dae074-fd03-4197-b723-f9be7ef7f48b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 107692, 'x2': 107892, 'y1': 45253, 'y2': 45453},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26253,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822779),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822765),
#   'unique_identifier': 'c7c8fb06-3920-4cf6-8078-a6eaf0bad327',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 107692, 'x2': 107892, 'y1': 74039, 'y2': 74239},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26254,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822833),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822819),
#   'unique_identifier': 'c1172b5b-5b50-4d83-b8d6-c83d4771f6b8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 107692, 'x2': 107892, 'y1': 102825, 'y2': 103025},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26255,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822886),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822872),
#   'unique_identifier': '8a4fd4ee-d34b-49d5-aa29-ee2d2148494a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 107692, 'x2': 107892, 'y1': 131611, 'y2': 131811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26256,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822940),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822926),
#   'unique_identifier': '57894415-b3ad-4437-bac7-e92a54a964e3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 135228, 'x2': 135428, 'y1': 16467, 'y2': 16667},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26257,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822993),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 822979),
#   'unique_identifier': '0c69175e-582c-46d9-94d3-7ed43dadffc3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 135228, 'x2': 135428, 'y1': 45253, 'y2': 45453},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26258,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823047),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823033),
#   'unique_identifier': '6ebca8d1-cd3c-4e20-abd0-eefcfc375be7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 135228, 'x2': 135428, 'y1': 74039, 'y2': 74239},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26259,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823100),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823086),
#   'unique_identifier': 'ed7b9d6b-5bad-404c-8cf3-6229c0534ee0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 135228, 'x2': 135428, 'y1': 102825, 'y2': 103025},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26260,
#   'image': 334,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823153),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823140),
#   'unique_identifier': '18fc5000-67da-4d57-93b7-7cb4ae36a867',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 135228, 'x2': 135428, 'y1': 131611, 'y2': 131811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26261,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823207),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823193),
#   'unique_identifier': 'daf61391-755c-4eae-9550-1b05c424c698',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 13487, 'x2': 13687, 'y1': 14808, 'y2': 15008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26262,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823260),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823246),
#   'unique_identifier': '42e439ad-e575-4b28-a2bc-8e3db4bb9793',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 13487, 'x2': 13687, 'y1': 43146, 'y2': 43346},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26263,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823313),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823299),
#   'unique_identifier': '863b284b-3d35-4bae-b232-c2166e61c43d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 13487, 'x2': 13687, 'y1': 71484, 'y2': 71684},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26264,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823366),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823353),
#   'unique_identifier': 'afe498fd-f92c-4164-9e14-540c8701b671',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 13487, 'x2': 13687, 'y1': 99822, 'y2': 100022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26265,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823437),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823422),
#   'unique_identifier': '8d4cee97-bcd4-4418-8851-5f0d20d8c884',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 13487, 'x2': 13687, 'y1': 128160, 'y2': 128360},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26266,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823492),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823478),
#   'unique_identifier': '141bd5fd-59aa-48f9-a1b6-1478a810be33',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 37636, 'x2': 37836, 'y1': 14808, 'y2': 15008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26267,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823546),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823532),
#   'unique_identifier': '587fdcdf-dd8f-49ad-bbd7-1c4ef1a938b4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 37636, 'x2': 37836, 'y1': 43146, 'y2': 43346},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26268,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823599),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823585),
#   'unique_identifier': '75e6e7e7-27c5-48ec-b909-aab1b5150af2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 37636, 'x2': 37836, 'y1': 71484, 'y2': 71684},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26269,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823653),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823639),
#   'unique_identifier': '2ea2e601-0a7c-4ecf-b9ef-c3ddb2d5d3f6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 37636, 'x2': 37836, 'y1': 99822, 'y2': 100022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26270,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823707),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823693),
#   'unique_identifier': '9ed9d56e-fa3e-4b5f-b8ac-ac7a5225920a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 37636, 'x2': 37836, 'y1': 128160, 'y2': 128360},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26271,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823761),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823747),
#   'unique_identifier': '8cdfd1e5-7640-493c-b1a6-3f19fba6a215',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61785, 'x2': 61985, 'y1': 14808, 'y2': 15008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26272,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823814),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823800),
#   'unique_identifier': '56d45d88-6a98-45fb-81dd-425609652a46',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61785, 'x2': 61985, 'y1': 43146, 'y2': 43346},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26273,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823889),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823874),
#   'unique_identifier': '13325fc3-69e8-42b0-80bb-b36d95f82358',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61785, 'x2': 61985, 'y1': 71484, 'y2': 71684},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26274,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823944),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823930),
#   'unique_identifier': 'ca02bd91-50e6-4791-97c8-66553834838a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61785, 'x2': 61985, 'y1': 99822, 'y2': 100022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26275,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823998),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 823983),
#   'unique_identifier': '78dc0a86-8c02-44e1-9140-4f064d332e3c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61785, 'x2': 61985, 'y1': 128160, 'y2': 128360},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26276,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824051),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824037),
#   'unique_identifier': '7af7cda3-f079-43ed-91db-3b13c307dfb3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85934, 'x2': 86134, 'y1': 14808, 'y2': 15008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26277,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824105),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824091),
#   'unique_identifier': '82deb685-47c3-43da-92f8-1f95c03c0a47',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85934, 'x2': 86134, 'y1': 43146, 'y2': 43346},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26278,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824159),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824144),
#   'unique_identifier': '771b24f1-7f49-432c-9807-8ff0f55f46ce',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85934, 'x2': 86134, 'y1': 71484, 'y2': 71684},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26279,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824212),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824198),
#   'unique_identifier': '3a9700c4-c411-4d87-aedc-f92dfe893836',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85934, 'x2': 86134, 'y1': 99822, 'y2': 100022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26280,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824266),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824251),
#   'unique_identifier': 'aa0700e9-20e9-4caa-8111-077e9dc1d415',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85934, 'x2': 86134, 'y1': 128160, 'y2': 128360},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26281,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824319),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824305),
#   'unique_identifier': 'f3721e13-d9c2-48f7-843e-2a3281950591',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110083, 'x2': 110283, 'y1': 14808, 'y2': 15008},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26282,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824372),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824358),
#   'unique_identifier': 'd052c048-140d-472c-aaa3-6f16d3eee186',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110083, 'x2': 110283, 'y1': 43146, 'y2': 43346},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26283,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824455),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824440),
#   'unique_identifier': 'bc96093c-69ca-4b60-ab9a-37d3f4d64f6f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110083, 'x2': 110283, 'y1': 71484, 'y2': 71684},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26284,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824510),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824496),
#   'unique_identifier': '054355bb-c37a-404e-8f0b-df33e0754478',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110083, 'x2': 110283, 'y1': 99822, 'y2': 100022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26285,
#   'image': 336,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824563),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824550),
#   'unique_identifier': '57ffffaf-18b2-4630-b7bc-5b569d30f4a1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110083, 'x2': 110283, 'y1': 128160, 'y2': 128360},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26286,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824616),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824602),
#   'unique_identifier': '25bdf7d7-7a2a-4158-bbd7-76a88d954466',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23984, 'x2': 24184, 'y1': 24824, 'y2': 25024},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26287,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824669),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824656),
#   'unique_identifier': 'c4c26108-2f69-483c-8a88-ed2e139f6fa2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23984, 'x2': 24184, 'y1': 62981, 'y2': 63181},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26288,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824722),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824708),
#   'unique_identifier': '7e14ad77-d7f3-483f-bf1b-d6bdfbb07298',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23984, 'x2': 24184, 'y1': 101138, 'y2': 101338},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26289,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824775),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824761),
#   'unique_identifier': '38d03977-9603-4c67-ac23-54c116c698e1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23984, 'x2': 24184, 'y1': 139295, 'y2': 139495},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26290,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824828),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824814),
#   'unique_identifier': '1e5d386a-a96b-4aa0-aed8-a6450535026e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23984, 'x2': 24184, 'y1': 177452, 'y2': 177652},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26291,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824881),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824867),
#   'unique_identifier': '9cce1674-fb6f-4321-85a3-0c842cec7036',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52825, 'x2': 53025, 'y1': 24824, 'y2': 25024},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26292,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824934),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824921),
#   'unique_identifier': '9a1eb2ef-4490-4674-9875-c89569154bd0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52825, 'x2': 53025, 'y1': 62981, 'y2': 63181},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26293,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824988),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 824974),
#   'unique_identifier': 'aa5dd31e-1d80-495e-97ff-3460983b2d62',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52825, 'x2': 53025, 'y1': 101138, 'y2': 101338},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26294,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825041),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825027),
#   'unique_identifier': 'd7cd0ac7-d29a-42bd-b0d7-428ab967c0bc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52825, 'x2': 53025, 'y1': 139295, 'y2': 139495},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26295,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825094),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825080),
#   'unique_identifier': 'c691f707-fd25-44d6-92b6-4063b212bb47',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 52825, 'x2': 53025, 'y1': 177452, 'y2': 177652},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26296,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825147),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825133),
#   'unique_identifier': '3159713c-2fdb-4e3c-bb9f-97d4897bd176',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 81666, 'x2': 81866, 'y1': 24824, 'y2': 25024},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26297,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825199),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825185),
#   'unique_identifier': 'b988ff2d-2b27-40ad-b30d-432a63dbe633',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 81666, 'x2': 81866, 'y1': 62981, 'y2': 63181},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26298,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825252),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825238),
#   'unique_identifier': 'b5a246f8-57db-446b-8cab-b10463bc78f2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 81666, 'x2': 81866, 'y1': 101138, 'y2': 101338},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26299,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825305),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825291),
#   'unique_identifier': 'bcceb605-cc51-4a59-ab5c-fb1d4d4a74a1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 81666, 'x2': 81866, 'y1': 139295, 'y2': 139495},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26300,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825358),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825344),
#   'unique_identifier': '5be2e414-cc62-4bea-8bdc-ab12a811d4a7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 81666, 'x2': 81866, 'y1': 177452, 'y2': 177652},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26301,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825426),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825410),
#   'unique_identifier': 'd8514704-7224-486b-af19-e685b259f805',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110507, 'x2': 110707, 'y1': 24824, 'y2': 25024},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26302,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825481),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825467),
#   'unique_identifier': '12ff06eb-9aa5-41ac-803a-2ff94cda16a5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110507, 'x2': 110707, 'y1': 62981, 'y2': 63181},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26303,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825535),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825521),
#   'unique_identifier': 'a0303548-815c-4e54-8c79-5a0645d3cbe1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110507, 'x2': 110707, 'y1': 101138, 'y2': 101338},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26304,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825588),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825574),
#   'unique_identifier': '479c334e-feb9-43eb-8d08-df7a1577eff6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110507, 'x2': 110707, 'y1': 139295, 'y2': 139495},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26305,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825642),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825628),
#   'unique_identifier': '758d10fe-7cdc-4b90-9a50-9ef67fb25ed9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 110507, 'x2': 110707, 'y1': 177452, 'y2': 177652},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26306,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825695),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825681),
#   'unique_identifier': '0349222b-f13a-4e99-ad87-7c6db405036b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 139348, 'x2': 139548, 'y1': 24824, 'y2': 25024},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26307,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825749),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825735),
#   'unique_identifier': '521d3a61-fab4-47ca-9310-3d7ba11b7e22',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 139348, 'x2': 139548, 'y1': 62981, 'y2': 63181},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26308,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825802),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825788),
#   'unique_identifier': 'cf75a689-d7f1-41eb-968a-6fe1eee57357',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 139348, 'x2': 139548, 'y1': 101138, 'y2': 101338},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26309,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825856),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825842),
#   'unique_identifier': 'e8130192-b084-435c-8db0-6cd68ceb99e3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 139348, 'x2': 139548, 'y1': 139295, 'y2': 139495},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26310,
#   'image': 338,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825910),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825896),
#   'unique_identifier': 'f1822351-39fe-45b2-8284-f202dd2a90f6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 139348, 'x2': 139548, 'y1': 177452, 'y2': 177652},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26311,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825963),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 825949),
#   'unique_identifier': '3b129a56-bcae-4f14-afa4-607141c90dfb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18242, 'x2': 18442, 'y1': 18399, 'y2': 18599},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26312,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826017),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826003),
#   'unique_identifier': 'ae2f6255-6812-44b0-b7ec-fcd0a3d8d481',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18242, 'x2': 18442, 'y1': 47073, 'y2': 47273},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26313,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826070),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826056),
#   'unique_identifier': '12d4674f-20db-4613-9f1f-df790ef03bd9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18242, 'x2': 18442, 'y1': 75747, 'y2': 75947},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26314,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826124),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826110),
#   'unique_identifier': 'a6a80b17-812a-4be0-b64c-12971c08cca5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18242, 'x2': 18442, 'y1': 104421, 'y2': 104621},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26315,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826178),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826164),
#   'unique_identifier': 'c7cac6c5-c4cd-4a6b-9f9c-59b1ccf92276',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18242, 'x2': 18442, 'y1': 133095, 'y2': 133295},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26316,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826232),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826218),
#   'unique_identifier': '5e822719-fc82-4efb-aebc-58a0a77e7db4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 47804, 'x2': 48004, 'y1': 18399, 'y2': 18599},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26317,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826285),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826271),
#   'unique_identifier': '3a3004ea-1f58-4130-8f0b-5eb0bc11e990',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 47804, 'x2': 48004, 'y1': 47073, 'y2': 47273},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26318,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826338),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826324),
#   'unique_identifier': 'd2a56e96-79e3-4ae0-8055-86331363f956',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 47804, 'x2': 48004, 'y1': 75747, 'y2': 75947},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26319,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826424),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826401),
#   'unique_identifier': 'f8438cda-e468-450c-8955-fdc0dd7aae97',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 47804, 'x2': 48004, 'y1': 104421, 'y2': 104621},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26320,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826482),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826468),
#   'unique_identifier': '3faacefe-3690-48d8-9cdc-b382f976cc6c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 47804, 'x2': 48004, 'y1': 133095, 'y2': 133295},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26321,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826534),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826521),
#   'unique_identifier': '205bb792-04a7-41bd-98e6-16f4916c1aa5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 77366, 'x2': 77566, 'y1': 18399, 'y2': 18599},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26322,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826587),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 826573),
#   'unique_identifier': 'e7660b48-f279-4f70-9277-cea16cc8f4b2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 77366, 'x2': 77566, 'y1': 47073, 'y2': 47273},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
# ...
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26332,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827111),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827097),
#   'unique_identifier': '88d8b0ec-4506-482e-9f1a-cf434aac26a8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 136490, 'x2': 136690, 'y1': 47073, 'y2': 47273},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26333,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827163),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827149),
#   'unique_identifier': '0502eb1d-ece2-47ff-ae04-853c4701ec71',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 136490, 'x2': 136690, 'y1': 75747, 'y2': 75947},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26334,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827215),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827201),
#   'unique_identifier': '2c490b97-83b3-4ca5-a4a1-6cdb660033a1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 136490, 'x2': 136690, 'y1': 104421, 'y2': 104621},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26335,
#   'image': 339,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827268),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827254),
#   'unique_identifier': '24474693-f679-44a8-b6b6-3ec0a608d7cd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 136490, 'x2': 136690, 'y1': 133095, 'y2': 133295},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26336,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827320),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827306),
#   'unique_identifier': '2847d9a1-d907-4b01-9b6e-77c4f8807979',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11704, 'x2': 11904, 'y1': 15738, 'y2': 15938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26337,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827388),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827372),
#   'unique_identifier': 'ffe49b4a-7a48-4a2c-9e13-6bd93f44f00a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11704, 'x2': 11904, 'y1': 44564, 'y2': 44764},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26338,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827450),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827436),
#   'unique_identifier': 'ed5b530a-3d06-43bf-82f2-857db4afdc7d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11704, 'x2': 11904, 'y1': 73390, 'y2': 73590},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26339,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827503),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827489),
#   'unique_identifier': '47d774ae-6571-44b0-b107-c3ba6591ee98',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11704, 'x2': 11904, 'y1': 102216, 'y2': 102416},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26340,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827556),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827542),
#   'unique_identifier': '26da425b-d067-4c97-ba53-6307ca87277f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11704, 'x2': 11904, 'y1': 131042, 'y2': 131242},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26341,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827608),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827594),
#   'unique_identifier': '4f2ff903-867d-4dfc-8ab0-b56ace416ccf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35233, 'x2': 35433, 'y1': 15738, 'y2': 15938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26342,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827660),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827647),
#   'unique_identifier': '2b7ed252-a089-4f1a-8662-4b006304fdac',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35233, 'x2': 35433, 'y1': 44564, 'y2': 44764},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26343,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827713),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827699),
#   'unique_identifier': 'a50e9cd6-8c5b-4102-8eeb-3937f11f1817',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35233, 'x2': 35433, 'y1': 73390, 'y2': 73590},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26344,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827765),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827752),
#   'unique_identifier': '389ffb7c-bfe5-46d6-825c-42544fe8aa03',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35233, 'x2': 35433, 'y1': 102216, 'y2': 102416},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26345,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827817),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827804),
#   'unique_identifier': 'bc3c5c8a-16d6-492d-8ffb-3069849f1b64',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35233, 'x2': 35433, 'y1': 131042, 'y2': 131242},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26346,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827869),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827855),
#   'unique_identifier': 'f8283cca-b9ad-433c-8e68-e611710a4d94',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58762, 'x2': 58962, 'y1': 15738, 'y2': 15938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26347,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827921),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827908),
#   'unique_identifier': 'fe16573b-811e-4c7d-8989-6df19416e748',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58762, 'x2': 58962, 'y1': 44564, 'y2': 44764},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26348,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827974),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 827960),
#   'unique_identifier': '31e7b3b7-6241-4a22-8635-4d7ef5c6eeb9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58762, 'x2': 58962, 'y1': 73390, 'y2': 73590},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26349,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828026),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828012),
#   'unique_identifier': '1cf6775e-56d7-4110-a055-453614356a80',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58762, 'x2': 58962, 'y1': 102216, 'y2': 102416},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26350,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828078),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828065),
#   'unique_identifier': '69ba531c-ca10-4aa6-8119-41d25bcbd923',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58762, 'x2': 58962, 'y1': 131042, 'y2': 131242},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26351,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828131),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828117),
#   'unique_identifier': '7ac4b6b9-08a3-4d61-b8da-5f4d75436592',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 82291, 'x2': 82491, 'y1': 15738, 'y2': 15938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26352,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828184),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828170),
#   'unique_identifier': 'e770e081-daf2-465e-941a-b7f0de0a36f0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 82291, 'x2': 82491, 'y1': 44564, 'y2': 44764},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26353,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828236),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828222),
#   'unique_identifier': '2c128b02-6b5a-4157-9542-5f1f0a34183d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 82291, 'x2': 82491, 'y1': 73390, 'y2': 73590},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26354,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828288),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828274),
#   'unique_identifier': 'a6deee53-99c1-4dcf-b2bc-1050ee931b65',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 82291, 'x2': 82491, 'y1': 102216, 'y2': 102416},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26355,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828340),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828326),
#   'unique_identifier': 'eb39e668-5b64-4973-ac25-78e811915ac7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 82291, 'x2': 82491, 'y1': 131042, 'y2': 131242},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26356,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828406),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828390),
#   'unique_identifier': 'ce950f3a-6baf-428a-9edc-4fcce2a3f283',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 105820, 'x2': 106020, 'y1': 15738, 'y2': 15938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26357,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828463),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828449),
#   'unique_identifier': '5986adb0-106d-4598-9d26-e21e78bd4b0e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 105820, 'x2': 106020, 'y1': 44564, 'y2': 44764},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26358,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828517),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828503),
#   'unique_identifier': 'f36851cb-9b29-45f2-98e6-7e75f8cea08e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 105820, 'x2': 106020, 'y1': 73390, 'y2': 73590},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26359,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828570),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828556),
#   'unique_identifier': '9e0f993d-ab04-4de6-886d-6cc2f248a9d6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 105820, 'x2': 106020, 'y1': 102216, 'y2': 102416},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26360,
#   'image': 341,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828624),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 1, 40, 828610),
#   'unique_identifier': 'f84d51d8-4329-4713-9781-5194b822d66d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 105820, 'x2': 106020, 'y1': 131042, 'y2': 131242},
#   'verified_by_user': 'False'}]
