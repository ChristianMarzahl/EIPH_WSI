# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import json
import numpy as np

# %%
from probreg import transformation as tf
from probreg import cpd
from probreg import callbacks
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %%
configuration = Configuration()
configuration.username = '#####' #'exact'
configuration.password = '####' #'exact'
configuration.host = "https://euroexact01.euroimmun.de/" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %%
annotation_types_points = {}          
annotation_type_target = None

for product in product_api.list_products(name="ColonCancer").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="LymphaticVessel").results:
        annotation_type_target = annotation_type
    
for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.id] = annotation_type

        
        
annotation_types_points
# Out:
# {11: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 11,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 2,
#   'vector_type': 1},
#  12: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 12,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 3,
#   'vector_type': 1},
#  13: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 13,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 4,
#   'vector_type': 1},
#  14: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 14,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 5,
#   'vector_type': 1},
#  15: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFA500',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 15,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 6,
#   'vector_type': 1},
#  16: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 16,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 7,
#   'vector_type': 1},
#  17: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 17,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 8,
#   'vector_type': 1},
#  18: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 18,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 9,
#   'vector_type': 1},
#  19: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 19,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 10,
#   'vector_type': 1},
#  20: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 20,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 11,
#   'vector_type': 1},
#  21: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 21,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 12,
#   'vector_type': 1},
#  22: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 22,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 13,
#   'vector_type': 1},
#  23: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 23,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 14,
#   'vector_type': 1},
#  24: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 24,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 15,
#   'vector_type': 1},
#  25: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 25,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 16,
#   'vector_type': 1},
#  26: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 26,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 17,
#   'vector_type': 1},
#  27: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 27,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 18,
#   'vector_type': 1},
#  28: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 28,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 18,
#   'vector_type': 1},
#  29: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 29,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 19,
#   'vector_type': 1},
#  30: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 30,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 20,
#   'vector_type': 1},
#  31: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 31,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 21,
#   'vector_type': 1},
#  32: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 32,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 21,
#   'vector_type': 1},
#  33: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 33,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 22,
#   'vector_type': 1},
#  34: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 34,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 23,
#   'vector_type': 1},
#  35: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 35,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 4,
#   'sort_order': 24,
#   'vector_type': 1}}

# %%
annotation_type_target
# Out:
# {'area_hit_test': True,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 500,
#  'default_width': 500,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 10,
#  'name': 'LymphaticVessel',
#  'node_count': 0,
#  'product': 2,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
names = [("CRC-A1-5 40X.tif", 5, "HE"), ("CRC-A1-1 40X.tif", 1, "HE"), 
         ("CRC-A1-5_stitched.tif", 5, "D2-40"), ("CRC-A1-1_2_stitched.tif", 1, "D2-40")]

# %%
annotations = []

for name, pair_id, stain  in names:
    
    image = images_api.list_images(name=name).results[0]
    
    for anno in annotations_api.list_annotations(image=image.id, deleted=False, pagination=False,
                                                 fields="annotation_type,id,image,vector,unique_identifier",
                                                 ).results:
        
        if anno.annotation_type in annotation_types_points:
            annotations.append([image.id, image.name, stain, pair_id, anno.id, anno.vector, anno.unique_identifier, annotation_types_points[anno.annotation_type].name])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "stain", "pair", "id", "vector", "unique_identifier", "annotation_type"])


annotations["x1"] = [vector["x1"] for vector in annotations["vector"]]
annotations["x2"] = [vector["x2"] for vector in annotations["vector"]]
annotations["y1"] = [vector["y1"] for vector in annotations["vector"]]
annotations["y2"] = [vector["y2"] for vector in annotations["vector"]]


annotations["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(annotations["y1"], annotations["y2"])]

annotations.head()
# Out:
#    image_id        image_name stain  pair     id  \
# 0        20  CRC-A1-5 40X.tif    HE     5  30844
# 1        20  CRC-A1-5 40X.tif    HE     5  30845
# 2        20  CRC-A1-5 40X.tif    HE     5  30846
# 3        20  CRC-A1-5 40X.tif    HE     5  30847
# 4        20  CRC-A1-5 40X.tif    HE     5  30848
#
#                                               vector  \
# 0  {'x1': 9378, 'x2': 9578, 'y1': 15363, 'y2': 15...
# 1  {'x1': 8299, 'x2': 8499, 'y1': 36048, 'y2': 36...
# 2  {'x1': 7603, 'x2': 7803, 'y1': 54247, 'y2': 54...
# 3  {'x1': 8638, 'x2': 8838, 'y1': 83095, 'y2': 83...
# 4  {'x1': 2225, 'x2': 2425, 'y1': 96279, 'y2': 96...
#
#                       unique_identifier annotation_type    x1    x2     y1  \
# 0  a8c564e8-fd69-43b7-b9a5-f1f16c7bbbd5              L0  9378  9578  15363
# 1  9a8e6a0c-0a43-4f6c-b6d5-4eeeca8b0dcc              L1  8299  8499  36048
# 2  aacda99c-5297-402f-bddc-8d043aeff4ed              L2  7603  7803  54247
# 3  74a268f2-dab0-497f-b11b-57dd327313ba              L3  8638  8838  83095
# 4  88a2ff08-15a3-40e9-9005-3ded346f4340              L4  2225  2425  96279
#
#       y2  center_x  center_y
# 0  15563    9478.0   15463.0
# 1  36248    8399.0   36148.0
# 2  54447    7703.0   54347.0
# 3  83295    8738.0   83195.0
# 4  96479    2325.0   96379.0

# %%
source_anno["image_name"].unique()[0]
# Out:
# 'CRC-A1-1_2_stitched.tif'

# %%
tf_param.b
# Out:
# array([[ 0.55464862,  0.0092813 ],
#        [-0.01803478,  0.5429615 ]])

# %%
tf_param.t
# Out:
# array([-12090.45440953,   1028.76986763])

# %%
# %%time

results = {}

for pair in annotations["pair"].unique():
    
    source_anno = annotations[(annotations["pair"] == pair) & (annotations["stain"] == "D2-40")]
    target_anno = annotations[(annotations["pair"] == pair) & (annotations["stain"] == "HE")]
    
    source =  np.array([[center_x, center_y] for center_x, center_y in zip(source_anno["center_x"], source_anno["center_y"])])
    target =  np.array([[center_x, center_y] for center_x, center_y in zip(target_anno["center_x"], target_anno["center_y"])])
    
    tf_param, sigma2, q = cpd.registration_cpd(source, target, 'affine') # ‘rigid’, ‘affine’, ‘nonrigid’   
    
    
    results[source_anno["image_name"].unique()[0]] = {
        "target": target_anno["image_name"].unique()[0],
        "b": tf_param.b,
        "t": tf_param.t,
        "sigma2": sigma2,
        "q": q
    }
# Out:
# Wall time: 46 ms

# %%
results
# Out:
# {'CRC-A1-5_stitched.tif': {'target': 'CRC-A1-5 40X.tif',
#   'b': array([[ 0.55519829, -0.05122972],
#          [ 0.05300909,  0.53146395]]),
#   't': array([-3687.08431348,  1405.46596613]),
#   'sigma2': 510090.1898897553,
#   'q': 353.5585707996683},
#  'CRC-A1-1_2_stitched.tif': {'target': 'CRC-A1-1 40X.tif',
#   'b': array([[ 0.55464862,  0.0092813 ],
#          [-0.01803478,  0.5429615 ]]),
#   't': array([-12090.45440953,   1028.76986763]),
#   'sigma2': 249929.90756729126,
#   'q': 335.7233946950652}}

# %%
annotations_to_upload = []
urls = []


for source_name, result in results.items():
    
    target_name = result["target"]
    tf_param = tf.AffineTransformation(result["b"], result["t"])
    
    source_image = images_api.list_images(name=source_name).results[0]
    taret_image = images_api.list_images(name=target_name).results[0]
    
    for anno in annotations_api.list_annotations(image=source_image.id, deleted=False, pagination=False, 
                                                 annotation_type=annotation_type_target.id,
                                                 fields="annotation_type,id,image,vector,unique_identifier",
                                                 ).results:
        
        xmin, ymin, xmax, ymax = anno.vector["x1"], anno.vector["y1"], anno.vector["x2"], anno.vector["y2"]
        source_url = f"https://euroexact01.euroimmun.de/annotations/{source_image.id}/?xmin={xmin}&ymin={ymin}&xmax={xmax}&ymax={ymax}"

        x1, y1 = tf_param.transform([xmin, ymin])
        x2, y2 = tf_param.transform([xmax, ymax])
        vector = {"x1": x1, "y1": y1, "x2": x2, "y2": y2}
        
        target_url = f"https://euroexact01.euroimmun.de/annotations/{taret_image.id}/?xmin={x1}&ymin={y1}&xmax={x2}&ymax={y2}"
    
        urls.append((source_url, target_url))
    
        anno = Annotation(annotation_type=anno.annotation_type, 
                          vector=vector, 
                          unique_identifier=anno.unique_identifier,
                          image=taret_image.id)

        annotations_to_upload.append(anno)

# %%
for source_url, target_url in urls[:5]:
    print(f"{source_url} ->  {target_url}")
# Out:
# https://euroexact01.euroimmun.de/annotations/10/?xmin=151583&ymin=111317&xmax=153538&ymax=112283 ->  https://euroexact01.euroimmun.de/annotations/20/?xmin=74768.79862207935&ymin=68601.71477155056&xmax=75804.7233613096&ymax=69218.74171205441
# https://euroexact01.euroimmun.de/annotations/10/?xmin=151483&ymin=112006&xmax=151900&ymax=112261 ->  https://euroexact01.euroimmun.de/annotations/20/?xmin=74677.98151478675&ymin=68962.59252178599&xmax=74896.43562125953&ymax=69120.22061808076
# https://euroexact01.euroimmun.de/annotations/10/?xmin=152122&ymin=112272&xmax=152372&ymax=112522 ->  https://euroexact01.euroimmun.de/annotations/20/?xmin=75019.12611400655&ymin=69137.83473916422&xmax=75145.11825517846&ymax=69283.95299792799
# https://euroexact01.euroimmun.de/annotations/10/?xmin=150545&ymin=106389&xmax=153694&ymax=108861 ->  https://euroexact01.euroimmun.de/annotations/20/?xmin=74444.96287133126&ymin=65927.63700951266&xmax=76066.64240346897&ymax=67408.34150516157
# https://euroexact01.euroimmun.de/annotations/10/?xmin=151344&ymin=103606&xmax=152111&ymax=104744 ->  https://euroexact01.euroimmun.de/annotations/20/?xmin=75031.13861947364&ymin=64490.927108374526&xmax=75398.67628164908&ymax=65136.391050390965

# %%
annotations_to_upload[:3]
# Out:
# [{'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 20,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'e5820fbb-7971-461d-ba5c-d69ceb502a04',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 74768.79862207935,
#              'x2': 75804.7233613096,
#              'y1': 68601.71477155056,
#              'y2': 69218.74171205441},
#   'verified_by_user': None},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 20,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '162df800-118b-488f-892e-95727f77979b',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 74677.98151478675,
#              'x2': 74896.43562125953,
#              'y1': 68962.59252178599,
#              'y2': 69120.22061808076},
#   'verified_by_user': None},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 20,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '3d8bf141-72a7-47e9-8b32-14d454366676',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 75019.12611400655,
#              'x2': 75145.11825517846,
#              'y1': 69137.83473916422,
#              'y2': 69283.95299792799},
#   'verified_by_user': None}]

# %%
#annotations_api.create_annotation(body=annotations_to_upload)
# Out:
# [{'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30944,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991814),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991793),
#   'unique_identifier': 'e5820fbb-7971-461d-ba5c-d69ceb502a04',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 74768.79862207935,
#              'x2': 75804.7233613096,
#              'y1': 68601.71477155056,
#              'y2': 69218.74171205441},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30945,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991880),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991870),
#   'unique_identifier': '162df800-118b-488f-892e-95727f77979b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 74677.98151478675,
#              'x2': 74896.43562125953,
#              'y1': 68962.59252178599,
#              'y2': 69120.22061808076},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30946,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991925),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991916),
#   'unique_identifier': '3d8bf141-72a7-47e9-8b32-14d454366676',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 75019.12611400655,
#              'x2': 75145.11825517846,
#              'y1': 69137.83473916422,
#              'y2': 69283.95299792799},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 30947,
#   'image': 20,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991966),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 21, 991957),
#   'unique_identifier': '88bb0d4f-0a47-4b13-9e03-f0d62b64647a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1':

#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 42219.49034462122,
#              'x2': 42428.0490092642,
#              'y1': 75353.38790461322,
#              'y2': 75639.42539072892},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31931,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31828),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31819),
#   'unique_identifier': '2876b433-da1f-4963-a109-94ad03e29a8f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 40851.135426873116,
#              'x2': 41315.70303595383,
#              'y1': 75265.86791920266,
#              'y2': 75432.21212524833},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31932,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31867),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31858),
#   'unique_identifier': '2bd7a6dc-0293-41ce-9255-4e77f050402d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32153.549687641724,
#              'x2': 32294.53216819692,
#              'y1': 69436.96384066623,
#              'y2': 69568.19552164752},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31933,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31906),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31897),
#   'unique_identifier': '02eadd86-8857-4276-9dc8-6eb659ab4092',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32377.752439942364,
#              'x2': 32518.734920497554,
#              'y1': 68820.13232347742,
#              'y2': 68951.36400445871},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31934,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31945),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31936),
#   'unique_identifier': '968025f3-85b1-493f-be44-083a307b26be',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32497.100258787286,
#              'x2': 32644.65685602007,
#              'y1': 68497.35609630606,
#              'y2': 68785.92036957087},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31935,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31986),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 31977),
#   'unique_identifier': '91574f8e-87b5-41b5-8e58-bd45905cd676',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32687.24714422589,
#              'x2': 32874.481159700794,
#              'y1': 69362.02439482274,
#              'y2': 69536.84302866843},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31936,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32025),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32017),
#   'unique_identifier': '7bc272de-a1b0-4ac2-8a6f-2115854348c9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35615.17080700865,
#              'x2': 35864.99176255247,
#              'y1': 69782.37782092547,
#              'y2': 70014.92035962429},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31937,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32064),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32055),
#   'unique_identifier': '5e2ab6d0-3d6f-4d9c-bc73-11a9afeb9c07',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32128.95416297909,
#              'x2': 32299.82492941198,
#              'y1': 66374.84515047078,
#              'y2': 66533.89794782009},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31938,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32111),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32102),
#   'unique_identifier': '12398e71-ff5e-4f33-be98-94784a0375d5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30768.145990290875,
#              'x2': 30967.989923859895,
#              'y1': 65527.59769771461,
#              'y2': 65985.58974898056},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31939,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32152),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32143),
#   'unique_identifier': '868b81c9-9169-4e95-a751-01df12a04f72',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30018.40646358089,
#              'x2': 30159.388944136088,
#              'y1': 63352.846191201315,
#              'y2': 63484.0778721826},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31940,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32191),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32182),
#   'unique_identifier': '338c0d32-4789-4a92-a745-5b6336f6b8c7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30288.49959494776,
#              'x2': 30459.370361380657,
#              'y1': 64122.0169603304,
#              'y2': 64281.06975767971},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31941,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32230),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32221),
#   'unique_identifier': '045a058a-9595-4b46-8234-b221f2ec0a8e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 29704.24558184506,
#              'x2': 29925.904572865576,
#              'y1': 64193.71091750416,
#              'y2': 64499.42317930558},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31942,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32268),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32260),
#   'unique_identifier': '5bf62cc7-283d-4883-aed5-01ecfc661212',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 29639.66121191954,
#              'x2': 30206.592679982277,
#              'y1': 62233.543917967014,
#              'y2': 62447.08317926327},
#   'verified_by_user': 'False'},
#  {'annotation_type': 10,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 31943,
#   'image': 19,
#   'last_edit_time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32308),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 16, 13, 49, 22, 32299),
#   'unique_identifier': '96c4d1e7-b645-4813-b917-5812d8b79c13',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 30401.3469680973,
#              'x2': 30644.78279826585,
#              'y1': 59717.91499988877,
#              'y2': 60258.69544087292},
#   'verified_by_user': 'False'},
#  ...]
