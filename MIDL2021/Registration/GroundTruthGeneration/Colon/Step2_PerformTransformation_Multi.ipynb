# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import pickle
import numpy as np

# %%
from openslide import OpenSlide

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %%
# Python < 3.8?
import sys
#! pip install pickle5

if sys.version_info.minor < 8:
    import pickle5 as pickle

# %%
import sys
sys.path.append("../..")
from registration_tree import Rect, QuadTree

# %%
slide_list = {path.name: path for path in Path(r"D:\Datasets\ColonCancer\SingleSlide").glob("*/*.*") 
                      if path.suffix in [".tif"]}

slide_list
# Out:
# {'CRC-AI-11 F X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-11 F X40.tif'),
#  'CRC-AI-14 1G X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-14 1G X40.tif'),
#  'CRC-AI-15 X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-15 X40.tif'),
#  'CRC-AI-8 E X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-8 E X40.tif'),
#  'CRC-AI-8 H X40.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/HE/CRC-AI-8 H X40.tif'),
#  'CRC-AI-11 F X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-11 F X40 IHC.tif'),
#  'CRC-AI-14 1G X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-14 1G X40 IHC.tif'),
#  'CRC-AI-15 X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-15 X40 IHC.tif'),
#  'CRC-AI-8 E X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-8 E X40 IHC.tif'),
#  'CRC-AI-8 H X40 IHC.tif': WindowsPath('D:/Datasets/ColonCancer/SingleSlide/IHC/CRC-AI-8 H X40 IHC.tif')}

# %%
configuration = Configuration()
configuration.username = 'exact' #'exact'
configuration.password = 'exact' #'exact'
configuration.host = "http://127.0.0.1:1337" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %%
annotation_types_points = {}

for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.id] = annotation_type

annotation_types_points
# Out:
# {21: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 21,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  22: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 22,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  23: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 23,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  24: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 100,
#   'default_width': 100,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 24,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  25: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 25,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  26: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 26,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  27: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 27,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  28: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 28,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  29: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 29,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  30: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 30,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  31: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 31,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  32: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 32,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  33: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 33,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  34: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 34,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  35: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 35,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  36: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 36,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  37: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 37,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  38: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 38,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  39: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 39,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  40: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 40,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  41: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 41,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  42: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 42,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  43: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 43,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  44: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 44,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1},
#  45: {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 45,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 7,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="Multi_IHC", expand="product_set,product_set.annotationtype_set").results[0]

for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id,
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        if anno.annotation_type in annotation_types_points:
            short = Path(image.name).stem.split(" HE")[0]
            
            annotations.append([image.id, image.name, short, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "image_name_short", "id", "vector", "unique_identifier", "annotation_type"])
annotations
# Out:
#      image_id     image_name image_name_short     id  \
# 0         334   CRC-A1-1.tif         CRC-A1-1  26236
# 1         334   CRC-A1-1.tif         CRC-A1-1  26237
# 2         334   CRC-A1-1.tif         CRC-A1-1  26238
# 3         334   CRC-A1-1.tif         CRC-A1-1  26239
# 4         334   CRC-A1-1.tif         CRC-A1-1  26240
# ..        ...            ...              ...    ...
# 120       341  CRC-A1-13.tif        CRC-A1-13  26356
# 121       341  CRC-A1-13.tif        CRC-A1-13  26357
# 122       341  CRC-A1-13.tif        CRC-A1-13  26358
# 123       341  CRC-A1-13.tif        CRC-A1-13  26359
# 124       341  CRC-A1-13.tif        CRC-A1-13  26360
#
#                                                 vector  \
# 0    {'x1': 25084, 'x2': 25284, 'y1': 16467, 'y2': ...
# 1    {'x1': 25084, 'x2': 25284, 'y1': 45253, 'y2': ...
# 2    {'x1': 25084, 'x2': 25284, 'y1': 74039, 'y2': ...
# 3    {'x1': 25084, 'x2': 25284, 'y1': 102825, 'y2':...
# 4    {'x1': 25084, 'x2': 25284, 'y1': 131611, 'y2':...
# ..                                                 ...
# 120  {'x1': 105820, 'x2': 106020, 'y1': 15738, 'y2'...
# 121  {'x1': 105820, 'x2': 106020, 'y1': 44564, 'y2'...
# 122  {'x1': 105820, 'x2': 106020, 'y1': 73390, 'y2'...
# 123  {'x1': 105820, 'x2': 106020, 'y1': 102216, 'y2...
# 124  {'x1': 105820, 'x2': 106020, 'y1': 131042, 'y2...
#
#                         unique_identifier  annotation_type
# 0    d68e7b9a-d3ae-43ea-9c7c-4dcac427c588               21
# 1    0ca22054-a283-4010-bde9-ecb8482c1bd3               22
# 2    7fb53235-d051-4d81-9d70-da87725bc6f6               23
# 3    2a73c263-0dae-4151-82e0-c661ad26930c               24
# 4    0b4c38dd-b8a5-49bb-b0be-735b43e47cac               25
# ..                                    ...              ...
# 120  ce950f3a-6baf-428a-9edc-4fcce2a3f283               41
# 121  5986adb0-106d-4598-9d26-e21e78bd4b0e               42
# 122  f36851cb-9b29-45f2-98e6-7e75f8cea08e               43
# 123  9e0f993d-ab04-4de6-886d-6cc2f248a9d6               44
# 124  f84d51d8-4329-4713-9781-5194b822d66d               45
#
# [125 rows x 7 columns]

# %%
annotations["x1"] = [vector['x1'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y1"] = [vector['y1'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["x2"] = [vector['x2'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y2"] = [vector['y2'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(annotations["y1"], annotations["y2"])]

annotations["anno_width"] = [x2-x1 for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["anno_height"]= [y2-y1 for y1, y2 in zip(annotations["y1"], annotations["y2"])]

# %%
transformed_annotations_to_upload = []

for image_set_name in tqdm(["Multi_HE"]):
    image_set = image_sets_api.list_image_sets(name=image_set_name, expand="product_set,product_set.annotationtype_set").results[0]

    for image_id in image_set.images:
        
        target_image = images_api.retrieve_image(id=image_id)
        short = Path(target_image.name).stem.split(" HE")[0]
        
        source_annos = annotations[annotations["image_name_short"] == short]
        
        source_name = list(source_annos["image_name"].unique())[0]
        target_name = target_image.name
        
        qtree = pickle.load(open(f'../../ColonCancer/Depth_2/2048/{Path(source_name).stem}-To-{Path(target_name).stem}.pickle', "rb" ))
        #qtree.source_slide = OpenSlide(str(slide_list[source_name]))
        #qtree.target_slide = OpenSlide(str(slide_list[target_name]))
        
        for id, source_anno in source_annos.iterrows():

            box = [source_anno.center_x, source_anno.center_y, source_anno.anno_width, source_anno.anno_height]

            trans_box = qtree.transform_boxes(np.array([box]))[0]

            new_x1 = int(trans_box[0] - trans_box[2] // 2)
            new_y1 = int(trans_box[1] - trans_box[3] // 2)
            new_x2 = int(trans_box[0] + trans_box[2] // 2)
            new_y2 = int(trans_box[1] + trans_box[3] // 2)

            vector = {'x1': new_x1, 'x2': new_x2, 'y1': new_y1, 'y2': new_y2}

            anno = Annotation(annotation_type=source_anno.annotation_type, 
                                  vector=vector, 
                                  image=target_image.id,
                                 unique_identifier=source_anno.unique_identifier)

            transformed_annotations_to_upload.append(anno)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.24s/it]

# %%
transformed_annotations_to_upload[:3]
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 335,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'd68e7b9a-d3ae-43ea-9c7c-4dcac427c588',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 11318, 'x2': 11520, 'y1': 18798, 'y2': 18996},
#   'verified_by_user': None},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 335,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '0ca22054-a283-4010-bde9-ecb8482c1bd3',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 11500, 'x2': 11702, 'y1': 47468, 'y2': 47666},
#   'verified_by_user': None},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 335,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '7fb53235-d051-4d81-9d70-da87725bc6f6',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 11683, 'x2': 11885, 'y1': 76138, 'y2': 76336},
#   'verified_by_user': None}]

# %%
#annotations_api.create_annotation(body=transformed_annotations_to_upload)
# Out:
# [{'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26361,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 938998),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 938972),
#   'unique_identifier': 'd68e7b9a-d3ae-43ea-9c7c-4dcac427c588',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11318, 'x2': 11520, 'y1': 18798, 'y2': 18996},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26362,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939073),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939058),
#   'unique_identifier': '0ca22054-a283-4010-bde9-ecb8482c1bd3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11500, 'x2': 11702, 'y1': 47468, 'y2': 47666},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26363,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939163),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939147),
#   'unique_identifier': '7fb53235-d051-4d81-9d70-da87725bc6f6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11683, 'x2': 11885, 'y1': 76138, 'y2': 76336},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26364,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939226),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939211),
#   'unique_identifier': '2a73c263-0dae-4151-82e0-c661ad26930c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11865, 'x2': 12067, 'y1': 104807, 'y2': 105005},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26365,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939288),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939273),
#   'unique_identifier': '0b4c38dd-b8a5-49bb-b0be-735b43e47cac',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 12047, 'x2': 12249, 'y1': 133477, 'y2': 133675},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26366,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939348),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939334),
#   'unique_identifier': '325de832-a522-4d95-ab15-d5748eaba0fa',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39265, 'x2': 39467, 'y1': 18138, 'y2': 18336},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26367,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939409),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939394),
#   'unique_identifier': '457a2078-06a5-4cab-bcab-8df0b6beda54',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39447, 'x2': 39649, 'y1': 46808, 'y2': 47006},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26368,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939469),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939454),
#   'unique_identifier': '274036df-4e5d-41c6-8283-f7fa0c126ad3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39629, 'x2': 39831, 'y1': 75477, 'y2': 75675},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26369,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939531),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939515),
#   'unique_identifier': '2fe4e5c3-57f1-481a-b1a4-3827ca1546f8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39811, 'x2': 40013, 'y1': 104147, 'y2': 104345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26370,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939670),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939652),
#   'unique_identifier': '30857dcd-173d-42ca-80d8-ef2436d16a68',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39994, 'x2': 40196, 'y1': 132817, 'y2': 133015},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26371,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939730),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939716),
#   'unique_identifier': '288cbf3b-aa20-475b-abef-36b45981fe1b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 67936, 'x2': 68136, 'y1': 18330, 'y2': 18526},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26372,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939790),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939775),
#   'unique_identifier': '9ca8de64-4762-439b-909e-697abf038651',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 67455, 'x2': 67655, 'y1': 46714, 'y2': 46910},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26373,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939851),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939836),
#   'unique_identifier': '40e1fb87-e690-4865-a990-b115d8e05730',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 67501, 'x2': 67701, 'y1': 75089, 'y2': 75289},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26374,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939911),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939897),
#   'unique_identifier': '16acd5bb-3935-45cd-8a78-98ae1fd76d02',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68658, 'x2': 68858, 'y1': 103963, 'y2': 104163},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26375,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939972),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 939957),
#   'unique_identifier': 'be54ff16-955d-4c02-91ab-946bf71841b8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 70696, 'x2': 70896, 'y1': 133768, 'y2': 133972},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26376,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940033),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940018),
#   'unique_identifier': 'c8621c63-9e83-485b-ac46-367ef7a3dc83',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 95689, 'x2': 95889, 'y1': 17259, 'y2': 17455},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26377,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940093),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940079),
#   'unique_identifier': '76dae074-fd03-4197-b723-f9be7ef7f48b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 95208, 'x2': 95408, 'y1': 45642, 'y2': 45838},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26378,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940156),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940141),
#   'unique_identifier': 'c7c8fb06-3920-4cf6-8078-a6eaf0bad327',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 95057, 'x2': 95257, 'y1': 73796, 'y2': 73996},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26379,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940217),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940202),
#   'unique_identifier': 'c1172b5b-5b50-4d83-b8d6-c83d4771f6b8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 96213, 'x2': 96413, 'y1': 102670, 'y2': 102870},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26380,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940279),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940265),
#   'unique_identifier': '8a4fd4ee-d34b-49d5-aa29-ee2d2148494a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 98312, 'x2': 98512, 'y1': 132425, 'y2': 132629},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26381,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940342),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940327),
#   'unique_identifier': '57894415-b3ad-4437-bac7-e92a54a964e3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 123442, 'x2': 123642, 'y1': 16188, 'y2': 16384},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26382,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940406),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940391),
#   'unique_identifier': '0c69175e-582c-46d9-94d3-7ed43dadffc3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 122961, 'x2': 123161, 'y1': 44571, 'y2': 44767},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26383,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940467),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940452),
#   'unique_identifier': '6ebca8d1-cd3c-4e20-abd0-eefcfc375be7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 122555, 'x2': 122755, 'y1': 72285, 'y2': 72489},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26384,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940530),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940515),
#   'unique_identifier': 'ed7b9d6b-5bad-404c-8cf3-6229c0534ee0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 124241, 'x2': 124441, 'y1': 101683, 'y2': 101887},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26385,
#   'image': 335,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940644),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940625),
#   'unique_identifier': '18fc5000-67da-4d57-93b7-7cb4ae36a867',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 125928, 'x2': 126128, 'y1': 131081, 'y2': 131285},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26386,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940709),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940694),
#   'unique_identifier': 'daf61391-755c-4eae-9550-1b05c424c698',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 12567, 'x2': 12763, 'y1': 60459, 'y2': 60655},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26387,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940769),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940754),
#   'unique_identifier': '42e439ad-e575-4b28-a2bc-8e3db4bb9793',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15349, 'x2': 15545, 'y1': 88326, 'y2': 88522},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26388,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940827),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940813),
#   'unique_identifier': '863b284b-3d35-4bae-b232-c2166e61c43d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18258, 'x2': 18458, 'y1': 116442, 'y2': 116632},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26389,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940887),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940873),
#   'unique_identifier': 'afe498fd-f92c-4164-9e14-540c8701b671',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 20725, 'x2': 20925, 'y1': 143443, 'y2': 143633},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26390,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940947),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940933),
#   'unique_identifier': '8d4cee97-bcd4-4418-8851-5f0d20d8c884',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23717, 'x2': 23913, 'y1': 170959, 'y2': 171151},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26391,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941008),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 940994),
#   'unique_identifier': '141bd5fd-59aa-48f9-a1b6-1478a810be33',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 36393, 'x2': 36589, 'y1': 57439, 'y2': 57635},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26392,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941069),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941054),
#   'unique_identifier': '587fdcdf-dd8f-49ad-bbd7-1c4ef1a938b4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39175, 'x2': 39371, 'y1': 85305, 'y2': 85501},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26393,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941135),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941120),
#   'unique_identifier': '75e6e7e7-27c5-48ec-b909-aab1b5150af2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41778, 'x2': 41974, 'y1': 114065, 'y2': 114257},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26394,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941199),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941183),
#   'unique_identifier': '2ea2e601-0a7c-4ecf-b9ef-c3ddb2d5d3f6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 44592, 'x2': 44788, 'y1': 141397, 'y2': 141589},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26395,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941262),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941248),
#   'unique_identifier': '9ed9d56e-fa3e-4b5f-b8ac-ac7a5225920a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45566, 'x2': 45774, 'y1': 166944, 'y2': 167118},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26396,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941325),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941309),
#   'unique_identifier': '8cdfd1e5-7640-493c-b1a6-3f19fba6a215',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61457, 'x2': 61655, 'y1': 54351, 'y2': 54553},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26397,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941388),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941373),
#   'unique_identifier': '56d45d88-6a98-45fb-81dd-425609652a46',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 64842, 'x2': 65040, 'y1': 83066, 'y2': 83268},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26398,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941450),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941435),
#   'unique_identifier': '13325fc3-69e8-42b0-80bb-b36d95f82358',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 65848, 'x2': 66052, 'y1': 110620, 'y2': 110822},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26399,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941515),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941499),
#   'unique_identifier': 'ca02bd91-50e6-4791-97c8-66553834838a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 68931, 'x2': 69135, 'y1': 139283, 'y2': 139485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26400,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941598),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941561),
#   'unique_identifier': '78dc0a86-8c02-44e1-9140-4f064d332e3c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 75406, 'x2': 75596, 'y1': 171927, 'y2': 172121},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26401,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941669),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941653),
#   'unique_identifier': '7af7cda3-f079-43ed-91db-3b13c307dfb3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85481, 'x2': 85679, 'y1': 51779, 'y2': 51981},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26402,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941734),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941719),
#   'unique_identifier': '82deb685-47c3-43da-92f8-1f95c03c0a47',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 88866, 'x2': 89064, 'y1': 80494, 'y2': 80696},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26403,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941795),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941780),
#   'unique_identifier': '771b24f1-7f49-432c-9807-8ff0f55f46ce',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 90589, 'x2': 90793, 'y1': 108114, 'y2': 108316},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26404,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941856),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941841),
#   'unique_identifier': '3a9700c4-c411-4d87-aedc-f92dfe893836',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 93672, 'x2': 93876, 'y1': 136778, 'y2': 136980},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26405,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941917),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941902),
#   'unique_identifier': 'aa0700e9-20e9-4caa-8111-077e9dc1d415',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 98575, 'x2': 98765, 'y1': 163729, 'y2': 163923},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26406,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941979),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 941964),
#   'unique_identifier': 'f3721e13-d9c2-48f7-843e-2a3281950591',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 109505, 'x2': 109703, 'y1': 49206, 'y2': 49408},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26407,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942042),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942027),
#   'unique_identifier': 'd052c048-140d-472c-aaa3-6f16d3eee186',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 112890, 'x2': 113088, 'y1': 77922, 'y2': 78124},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26408,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942106),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942091),
#   'unique_identifier': 'bc96093c-69ca-4b60-ab9a-37d3f4d64f6f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 115330, 'x2': 115534, 'y1': 105609, 'y2': 105811},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26409,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942167),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942153),
#   'unique_identifier': '054355bb-c37a-404e-8f0b-df33e0754478',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 118414, 'x2': 118618, 'y1': 134272, 'y2': 134474},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26410,
#   'image': 337,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942230),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942215),
#   'unique_identifier': '57ffffaf-18b2-4630-b7bc-5b569d30f4a1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 121497, 'x2': 121701, 'y1': 162936, 'y2': 163138},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26411,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942292),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942277),
#   'unique_identifier': '25bdf7d7-7a2a-4158-bbd7-76a88d954466',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 23578, 'x2': 23774, 'y1': 25796, 'y2': 26000},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26412,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942356),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942341),
#   'unique_identifier': 'c4c26108-2f69-483c-8a88-ed2e139f6fa2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18742, 'x2': 18938, 'y1': 64727, 'y2': 64931},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26413,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942418),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942403),
#   'unique_identifier': '7e14ad77-d7f3-483f-bf1b-d6bdfbb07298',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 8719, 'x2': 8923, 'y1': 100903, 'y2': 101099},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26414,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942482),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942466),
#   'unique_identifier': '38d03977-9603-4c67-ac23-54c116c698e1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 1893, 'x2': 2097, 'y1': 138391, 'y2': 138587},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26415,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942547),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942531),
#   'unique_identifier': '1e5d386a-a96b-4aa0-aed8-a6450535026e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': -4931, 'x2': -4727, 'y1': 175878, 'y2': 176074},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26416,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942639),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942621),
#   'unique_identifier': '9cce1674-fb6f-4321-85a3-0c842cec7036',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 51236, 'x2': 51428, 'y1': 30381, 'y2': 30577},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26417,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942705),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942689),
#   'unique_identifier': '9a1eb2ef-4490-4674-9875-c89569154bd0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 47039, 'x2': 47235, 'y1': 69750, 'y2': 69954},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26418,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942771),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942755),
#   'unique_identifier': 'aa5dd31e-1d80-495e-97ff-3460983b2d62',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 38183, 'x2': 38387, 'y1': 105869, 'y2': 106065},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26419,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942833),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942818),
#   'unique_identifier': 'd7cd0ac7-d29a-42bd-b0d7-428ab967c0bc',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 31357, 'x2': 31561, 'y1': 143357, 'y2': 143553},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26420,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942896),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942881),
#   'unique_identifier': 'c691f707-fd25-44d6-92b6-4063b212bb47',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 24532, 'x2': 24736, 'y1': 180844, 'y2': 181040},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26421,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942966),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 942951),
#   'unique_identifier': '3159713c-2fdb-4e3c-bb9f-97d4897bd176',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 79152, 'x2': 79350, 'y1': 35401, 'y2': 35605},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26422,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943035),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943019),
#   'unique_identifier': 'b988ff2d-2b27-40ad-b30d-432a63dbe633',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 74896, 'x2': 75094, 'y1': 74590, 'y2': 74794},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26423,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943104),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943088),
#   'unique_identifier': 'b5a246f8-57db-446b-8cab-b10463bc78f2',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 67647, 'x2': 67851, 'y1': 110836, 'y2': 111032},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26424,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943170),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943154),
#   'unique_identifier': 'bcceb605-cc51-4a59-ab5c-fb1d4d4a74a1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 60821, 'x2': 61025, 'y1': 148323, 'y2': 148519},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26425,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943234),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943219),
#   'unique_identifier': '5be2e414-cc62-4bea-8bdc-ab12a811d4a7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 53996, 'x2': 54200, 'y1': 185810, 'y2': 186006},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26426,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943296),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943281),
#   'unique_identifier': 'd8514704-7224-486b-af19-e685b259f805',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 107987, 'x2': 108185, 'y1': 39233, 'y2': 39437},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26427,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943359),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943344),
#   'unique_identifier': '12ff06eb-9aa5-41ac-803a-2ff94cda16a5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 103732, 'x2': 103930, 'y1': 78422, 'y2': 78626},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26428,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943421),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943406),
#   'unique_identifier': 'a0303548-815c-4e54-8c79-5a0645d3cbe1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 97111, 'x2': 97315, 'y1': 115802, 'y2': 115998},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26429,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943484),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943469),
#   'unique_identifier': '479c334e-feb9-43eb-8d08-df7a1577eff6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 90285, 'x2': 90489, 'y1': 153289, 'y2': 153485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26430,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943548),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943533),
#   'unique_identifier': '758d10fe-7cdc-4b90-9a50-9ef67fb25ed9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 83460, 'x2': 83664, 'y1': 190776, 'y2': 190972},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26431,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943640),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943622),
#   'unique_identifier': '0349222b-f13a-4e99-ad87-7c6db405036b',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 136823, 'x2': 137021, 'y1': 43066, 'y2': 43270},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26432,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943704),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943689),
#   'unique_identifier': '521d3a61-fab4-47ca-9310-3d7ba11b7e22',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 132568, 'x2': 132766, 'y1': 82255, 'y2': 82459},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26433,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943767),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943752),
#   'unique_identifier': 'cf75a689-d7f1-41eb-968a-6fe1eee57357',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 126575, 'x2': 126779, 'y1': 120768, 'y2': 120964},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26434,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943828),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943813),
#   'unique_identifier': 'e8130192-b084-435c-8db0-6cd68ceb99e3',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 119749, 'x2': 119953, 'y1': 158255, 'y2': 158451},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26435,
#   'image': 340,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943886),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943872),
#   'unique_identifier': 'f1822351-39fe-45b2-8284-f202dd2a90f6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 112924, 'x2': 113128, 'y1': 195742, 'y2': 195938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26436,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943945),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943931),
#   'unique_identifier': '3b129a56-bcae-4f14-afa4-607141c90dfb',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 14841, 'x2': 15045, 'y1': 9582, 'y2': 9784},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26437,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944004),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 943990),
#   'unique_identifier': 'ae2f6255-6812-44b0-b7ec-fcd0a3d8d481',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 15726, 'x2': 15930, 'y1': 38588, 'y2': 38790},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26438,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944062),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944048),
#   'unique_identifier': '12d4674f-20db-4613-9f1f-df790ef03bd9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 16611, 'x2': 16815, 'y1': 67595, 'y2': 67797},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26439,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944121),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944106),
#   'unique_identifier': 'a6a80b17-812a-4be0-b64c-12971c08cca5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 17656, 'x2': 17870, 'y1': 89589, 'y2': 89801},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26440,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944179),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944165),
#   'unique_identifier': 'c7cac6c5-c4cd-4a6b-9f9c-59b1ccf92276',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 41348, 'x2': 41562, 'y1': 120150, 'y2': 120362},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26441,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944237),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944222),
#   'unique_identifier': '5e822719-fc82-4efb-aebc-58a0a77e7db4',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 45196, 'x2': 45400, 'y1': 11592, 'y2': 11794},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26442,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944296),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944281),
#   'unique_identifier': '3a3004ea-1f58-4130-8f0b-5eb0bc11e990',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46081, 'x2': 46285, 'y1': 40599, 'y2': 40801},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26443,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944354),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944339),
#   'unique_identifier': 'd2a56e96-79e3-4ae0-8055-86331363f956',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 46966, 'x2': 47170, 'y1': 69605, 'y2': 69807},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26444,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944412),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944398),
#   'unique_identifier': 'f8438cda-e468-450c-8955-fdc0dd7aae97',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 49380, 'x2': 49594, 'y1': 108606, 'y2': 108818},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26445,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944470),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944456),
#   'unique_identifier': '3faacefe-3690-48d8-9cdc-b382f976cc6c',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 73071, 'x2': 73285, 'y1': 139166, 'y2': 139378},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26446,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944528),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944514),
#   'unique_identifier': '205bb792-04a7-41bd-98e6-16f4916c1aa5',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 75551, 'x2': 75755, 'y1': 13603, 'y2': 13805},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26447,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944617),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 944594),
#   'unique_identifier': 'e7660b48-f279-4f70-9277-cea16cc8f4b2',
#   'uploaded_media_files': [],
#   'user': 2,
# ...
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26457,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945229),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945214),
#   'unique_identifier': '88d8b0ec-4506-482e-9f1a-cf434aac26a8',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 127631, 'x2': 127679, 'y1': 38749, 'y2': 38759},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26458,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945287),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945273),
#   'unique_identifier': '0502eb1d-ece2-47ff-ae04-853c4701ec71',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 112527, 'x2': 112575, 'y1': 40324, 'y2': 40334},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26459,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945346),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945331),
#   'unique_identifier': '2c490b97-83b3-4ca5-a4a1-6cdb660033a1',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 133663, 'x2': 133791, 'y1': 94910, 'y2': 95026},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26460,
#   'image': 342,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945403),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945389),
#   'unique_identifier': '24474693-f679-44a8-b6b6-3ec0a608d7cd',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 131823, 'x2': 132017, 'y1': 122791, 'y2': 122955},
#   'verified_by_user': 'False'},
#  {'annotation_type': 21,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26461,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945460),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945446),
#   'unique_identifier': '2847d9a1-d907-4b01-9b6e-77c4f8807979',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 9089, 'x2': 9289, 'y1': 31838, 'y2': 32034},
#   'verified_by_user': 'False'},
#  {'annotation_type': 22,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26462,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945517),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945503),
#   'unique_identifier': 'ffe49b4a-7a48-4a2c-9e13-6bd93f44f00a',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 11452, 'x2': 11652, 'y1': 60207, 'y2': 60403},
#   'verified_by_user': 'False'},
#  {'annotation_type': 23,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26463,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945575),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945561),
#   'unique_identifier': 'ed5b530a-3d06-43bf-82f2-857db4afdc7d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 13815, 'x2': 14015, 'y1': 88575, 'y2': 88771},
#   'verified_by_user': 'False'},
#  {'annotation_type': 24,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26464,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945654),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945638),
#   'unique_identifier': '47d774ae-6571-44b0-b107-c3ba6591ee98',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 16178, 'x2': 16378, 'y1': 116943, 'y2': 117139},
#   'verified_by_user': 'False'},
#  {'annotation_type': 25,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26465,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945715),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945701),
#   'unique_identifier': '26da425b-d067-4c97-ba53-6307ca87277f',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 18541, 'x2': 18741, 'y1': 145312, 'y2': 145508},
#   'verified_by_user': 'False'},
#  {'annotation_type': 26,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26466,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945775),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945760),
#   'unique_identifier': '4f2ff903-867d-4dfc-8ab0-b56ace416ccf',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 32821, 'x2': 33021, 'y1': 29831, 'y2': 30027},
#   'verified_by_user': 'False'},
#  {'annotation_type': 27,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26467,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945835),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945820),
#   'unique_identifier': '2b7ed252-a089-4f1a-8662-4b006304fdac',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 35184, 'x2': 35384, 'y1': 58200, 'y2': 58396},
#   'verified_by_user': 'False'},
#  {'annotation_type': 28,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26468,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945894),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945879),
#   'unique_identifier': 'a50e9cd6-8c5b-4102-8eeb-3937f11f1817',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 37547, 'x2': 37747, 'y1': 86568, 'y2': 86764},
#   'verified_by_user': 'False'},
#  {'annotation_type': 29,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26469,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945953),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945938),
#   'unique_identifier': '389ffb7c-bfe5-46d6-825c-42544fe8aa03',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 39910, 'x2': 40110, 'y1': 114937, 'y2': 115133},
#   'verified_by_user': 'False'},
#  {'annotation_type': 30,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26470,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946011),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 945997),
#   'unique_identifier': 'bc3c5c8a-16d6-492d-8ffb-3069849f1b64',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 42273, 'x2': 42473, 'y1': 143305, 'y2': 143501},
#   'verified_by_user': 'False'},
#  {'annotation_type': 31,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26471,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946069),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946055),
#   'unique_identifier': 'f8283cca-b9ad-433c-8e68-e611710a4d94',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 56553, 'x2': 56753, 'y1': 27825, 'y2': 28021},
#   'verified_by_user': 'False'},
#  {'annotation_type': 32,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26472,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946144),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946129),
#   'unique_identifier': 'fe16573b-811e-4c7d-8989-6df19416e748',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 58916, 'x2': 59116, 'y1': 56193, 'y2': 56389},
#   'verified_by_user': 'False'},
#  {'annotation_type': 33,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26473,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946203),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946188),
#   'unique_identifier': '31e7b3b7-6241-4a22-8635-4d7ef5c6eeb9',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 61279, 'x2': 61479, 'y1': 84561, 'y2': 84757},
#   'verified_by_user': 'False'},
#  {'annotation_type': 34,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26474,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946261),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946247),
#   'unique_identifier': '1cf6775e-56d7-4110-a055-453614356a80',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 63815, 'x2': 64015, 'y1': 113057, 'y2': 113255},
#   'verified_by_user': 'False'},
#  {'annotation_type': 35,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26475,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946319),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946305),
#   'unique_identifier': '69ba531c-ca10-4aa6-8119-41d25bcbd923',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 66172, 'x2': 66374, 'y1': 141649, 'y2': 141845},
#   'verified_by_user': 'False'},
#  {'annotation_type': 36,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26476,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946378),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946364),
#   'unique_identifier': '7ac4b6b9-08a3-4d61-b8da-5f4d75436592',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 80284, 'x2': 80484, 'y1': 25818, 'y2': 26014},
#   'verified_by_user': 'False'},
#  {'annotation_type': 37,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26477,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946437),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946423),
#   'unique_identifier': 'e770e081-daf2-465e-941a-b7f0de0a36f0',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 82647, 'x2': 82847, 'y1': 54186, 'y2': 54382},
#   'verified_by_user': 'False'},
#  {'annotation_type': 38,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26478,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946496),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946481),
#   'unique_identifier': '2c128b02-6b5a-4157-9542-5f1f0a34183d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 85010, 'x2': 85210, 'y1': 82555, 'y2': 82751},
#   'verified_by_user': 'False'},
#  {'annotation_type': 39,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26479,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946554),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946540),
#   'unique_identifier': 'a6deee53-99c1-4dcf-b2bc-1050ee931b65',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 87484, 'x2': 87684, 'y1': 111019, 'y2': 111217},
#   'verified_by_user': 'False'},
#  {'annotation_type': 40,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26480,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946626),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946598),
#   'unique_identifier': 'eb39e668-5b64-4973-ac25-78e811915ac7',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 90066, 'x2': 90268, 'y1': 139867, 'y2': 140063},
#   'verified_by_user': 'False'},
#  {'annotation_type': 41,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26481,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946689),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946675),
#   'unique_identifier': 'ce950f3a-6baf-428a-9edc-4fcce2a3f283',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 104016, 'x2': 104216, 'y1': 23811, 'y2': 24007},
#   'verified_by_user': 'False'},
#  {'annotation_type': 42,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26482,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946747),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946733),
#   'unique_identifier': '5986adb0-106d-4598-9d26-e21e78bd4b0e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 106379, 'x2': 106579, 'y1': 52180, 'y2': 52376},
#   'verified_by_user': 'False'},
#  {'annotation_type': 43,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26483,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946805),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946791),
#   'unique_identifier': 'f36851cb-9b29-45f2-98e6-7e75f8cea08e',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 108742, 'x2': 108942, 'y1': 80548, 'y2': 80744},
#   'verified_by_user': 'False'},
#  {'annotation_type': 44,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26484,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946863),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946849),
#   'unique_identifier': '9e0f993d-ab04-4de6-886d-6cc2f248a9d6',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 111152, 'x2': 111352, 'y1': 108980, 'y2': 109178},
#   'verified_by_user': 'False'},
#  {'annotation_type': 45,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 26485,
#   'image': 343,
#   'last_edit_time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946921),
#   'last_editor': 2,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 2, 10, 9, 15, 25, 946907),
#   'unique_identifier': 'f84d51d8-4329-4713-9781-5194b822d66d',
#   'uploaded_media_files': [],
#   'user': 2,
#   'vector': {'x1': 113615, 'x2': 113815, 'y1': 137525, 'y2': 137723},
#   'verified_by_user': 'False'}]
