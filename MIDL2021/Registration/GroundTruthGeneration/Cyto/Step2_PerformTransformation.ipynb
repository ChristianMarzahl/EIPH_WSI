# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import pickle
import numpy as np

# %%
from openslide import OpenSlide

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %%
import sys
sys.path.append("../..")
from registration_tree import Rect, QuadTree

# %% [markdown]
# ## Find and load slides from HDD

# %%
slide_list = {path.name: path for path in Path(r"D:\Datasets\ScannerStudy").glob("*/*/*.*") 
                      if path.suffix in [".svs", ".ndpi", ".tif"]}

slide_list
# Out:
# {'A_CCMCT_183715A_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_183715A_1.svs'),
#  'A_CCMCT_22108_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_22108_1.svs'),
#  'A_CCMCT_29609B_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_29609B_1.svs'),
#  'A_CCMCT_380609B_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_380609B_1.svs'),
#  'A_CCMCT_518711B_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_518711B_1.svs'),
#  'A_BB_563476_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_563476_1.svs'),
#  'A_BB_563479_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_563479_1.svs'),
#  'A_BB_568320_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_568320_1.svs'),
#  'A_BB_568381_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_568381_1.svs'),
#  'A_BB_574162_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_574162_1.svs'),
#  'Z_CCMCT_183715A_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_183715A_1.tif'),
#  'Z_CCMCT_22108_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_22108_1.tif'),
#  'Z_CCMCT_29609B_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_29609B_1.tif'),
#  'Z_CCMCT_380609B_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_380609B_1.tif'),
#  'Z_CCMCT_518711B_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_518711B_1.tif'),
#  'Z_BB_563476_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_563476_1.tif'),
#  'Z_BB_563479_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_563479_1.tif'),
#  'Z_BB_568320_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_568320_1.tif'),
#  'Z_BB_568381_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_568381_1.tif'),
#  'Z_BB_574162_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_574162_1.tif'),
#  'N2_CCMCT_183715A_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_183715A_1.ndpi'),
#  'N2_CCMCT_22108_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_22108_1.ndpi'),
#  'N2_CCMCT_29609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_29609B_1.ndpi'),
#  'N2_CCMCT_380609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_380609B_1.ndpi'),
#  'N2_CCMCT_518711B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_518711B_1.ndpi'),
#  'N2_BB_563476_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_563476_1.ndpi'),
#  'N2_BB_563479_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_563479_1.ndpi'),
#  'N2_BB_568320_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_568320_1.ndpi'),
#  'N2_BB_568381_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_568381_1.ndpi'),
#  'N2_BB_574162_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_574162_1.ndpi'),
#  'N1_CCMCT_183715A_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_183715A_1.ndpi'),
#  'N1_CCMCT_22108_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_22108_1.ndpi'),
#  'N1_CCMCT_29609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_29609B_1.ndpi'),
#  'N1_CCMCT_380609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_380609B_1.ndpi'),
#  'N1_CCMCT_518711B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_518711B_1.ndpi'),
#  'N1_BB_563476_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_563476_1.ndpi'),
#  'N1_BB_563479_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_563479_1.ndpi'),
#  'N1_BB_568320_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_568320_1.ndpi'),
#  'N1_BB_568381_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_568381_1.ndpi'),
#  'N1_BB_574162_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_574162_1.ndpi')}

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'marzahl' #'exact'
configuration.password = '###' #'exact'
configuration.host = "https://exact.cs.fau.de" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download RefPoints annotation

# %%
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
        
annotation_types_ref_rect
# Out:
# {'area_hit_test': False,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 5000,
#  'default_width': 5000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 412,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 105,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="Cyto_Aperio", expand="product_set,product_set.annotationtype_set").results[0]

for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id,
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        if anno.annotation_type != annotation_types_ref_rect.id:
            annotations.append([image.id, image.name, Path(image.name).stem.split("_")[2].split("_")[0], anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "image_name_short", "id", "vector", "unique_identifier", "annotation_type"])
annotations
# Out:
#      image_id         image_name image_name_short       id  \
# 0       10392  A_BB_574162_1.svs           574162  2754781
# 1       10392  A_BB_574162_1.svs           574162  2754782
# 2       10392  A_BB_574162_1.svs           574162  2754783
# 3       10392  A_BB_574162_1.svs           574162  2754784
# 4       10392  A_BB_574162_1.svs           574162  2754785
# ..        ...                ...              ...      ...
# 120     10378  A_BB_563476_1.svs           563476  2754901
# 121     10378  A_BB_563476_1.svs           563476  2754902
# 122     10378  A_BB_563476_1.svs           563476  2754903
# 123     10378  A_BB_563476_1.svs           563476  2754904
# 124     10378  A_BB_563476_1.svs           563476  2754905
#
#                                                 vector  \
# 0     {'x1': 5556, 'x2': 5656, 'y1': 5439, 'y2': 5539}
# 1    {'x1': 4671, 'x2': 4759, 'y1': 10586, 'y2': 10...
# 2    {'x1': 5100, 'x2': 5208, 'y1': 15401, 'y2': 15...
# 3    {'x1': 5230, 'x2': 5336, 'y1': 21108, 'y2': 21...
# 4    {'x1': 5387, 'x2': 5497, 'y1': 25652, 'y2': 25...
# ..                                                 ...
# 120  {'x1': 26701, 'x2': 26801, 'y1': 5443, 'y2': 5...
# 121  {'x1': 27491, 'x2': 27612, 'y1': 11331, 'y2': ...
# 122  {'x1': 26509, 'x2': 26624, 'y1': 16374, 'y2': ...
# 123  {'x1': 26949, 'x2': 27048, 'y1': 22715, 'y2': ...
# 124  {'x1': 26483, 'x2': 26613, 'y1': 27706, 'y2': ...
#
#                         unique_identifier  annotation_type
# 0    e4d98794-d4fb-404b-a4ae-4b312b468e8e              384
# 1    72f12897-7d3c-4458-a7d8-7fdc8e7176ab              385
# 2    a9d37e23-8267-49b1-a637-6c889bd79afa              386
# 3    42096c63-212d-4a51-bf00-e8d34de09f47              387
# 4    56efe99e-f891-4ad4-a9ee-e096ac3916aa              388
# ..                                    ...              ...
# 120  df3b63d5-da21-4fca-9336-cba6ef151289              407
# 121  39f211cd-034b-4013-9271-439fef05afb9              408
# 122  142f2230-ec26-4609-a5a5-93387387453d              409
# 123  1e9cac70-7c73-4abb-8f8c-4170a0b1b35e              410
# 124  1bdfe093-7ecd-49ac-8c16-e96adfaac0c7              411
#
# [125 rows x 7 columns]

# %% [markdown]
# ## Add some helper variables

# %%
annotations["x1"] = [vector['x1'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y1"] = [vector['y1'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["x2"] = [vector['x2'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y2"] = [vector['y2'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(annotations["y1"], annotations["y2"])]

annotations["anno_width"] = [x2-x1 for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["anno_height"]= [y2-y1 for y1, y2 in zip(annotations["y1"], annotations["y2"])]

# %% [markdown]
# ## Load QuadTree for each scanner and transform coordinates

# %%
transformed_annotations_to_upload = []

for image_set_name in tqdm(["Cyto_2.0HT", "Cyto_Axio", "Cyto_S210"]):
    image_set = image_sets_api.list_image_sets(name=image_set_name, expand="product_set,product_set.annotationtype_set").results[0]

    for image_id in image_set.images:
        
        target_image = images_api.retrieve_image(id=image_id)
        
        source_annos = annotations[annotations["image_name_short"] == Path(target_image.name).stem.split("_")[2].split("_")[0]]
        
        source_name = list(source_annos["image_name"].unique())[0]
        target_name = target_image.name
        
        qtree = pickle.load(open(f'../../Cyto/{Path(source_name).stem}-To-{Path(target_name).stem}.pickle', "rb" ))
        qtree.source_slide = OpenSlide(str(slide_list[source_name]))
        qtree.target_slide = OpenSlide(str(slide_list[target_name]))
        
        for id, source_anno in source_annos.iterrows():

            box = [source_anno.center_x, source_anno.center_y, source_anno.anno_width, source_anno.anno_height]

            trans_box = qtree.transform_boxes(np.array([box]))[0]

            new_x1 = int(trans_box[0] - trans_box[2] // 2)
            new_y1 = int(trans_box[1] - trans_box[3] // 2)
            new_x2 = int(trans_box[0] + trans_box[2] // 2)
            new_y2 = int(trans_box[1] + trans_box[3] // 2)

            vector = {'x1': new_x1, 'x2': new_x2, 'y1': new_y1, 'y2': new_y2}

            anno = Annotation(annotation_type=source_anno.annotation_type, 
                                  vector=vector, 
                                  image=target_image.id,
                                 unique_identifier=source_anno.unique_identifier)

            transformed_annotations_to_upload.append(anno)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:07<00:00,  2.40s/it]

# %%
transformed_annotations_to_upload[:3]
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10383,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'e4d98794-d4fb-404b-a4ae-4b312b468e8e',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 7273, 'x2': 7383, 'y1': 5858, 'y2': 5968},
#   'verified_by_user': None},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10383,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '72f12897-7d3c-4458-a7d8-7fdc8e7176ab',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 6301, 'x2': 6399, 'y1': 11591, 'y2': 11687},
#   'verified_by_user': None},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10383,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'a9d37e23-8267-49b1-a637-6c889bd79afa',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 6798, 'x2': 6918, 'y1': 16948, 'y2': 17068},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
annotations_api.create_annotation(body=transformed_annotations_to_upload)
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754906,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527563),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527533),
#   'unique_identifier': 'e4d98794-d4fb-404b-a4ae-4b312b468e8e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 7273, 'x2': 7383, 'y1': 5858, 'y2': 5968},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754907,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527640),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527627),
#   'unique_identifier': '72f12897-7d3c-4458-a7d8-7fdc8e7176ab',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 6301, 'x2': 6399, 'y1': 11591, 'y2': 11687},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754908,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527695),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527682),
#   'unique_identifier': 'a9d37e23-8267-49b1-a637-6c889bd79afa',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 6798, 'x2': 6918, 'y1': 16948, 'y2': 17068},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754909,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527747),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527734),
#   'unique_identifier': '42096c63-212d-4a51-bf00-e8d34de09f47',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 6963, 'x2': 7081, 'y1': 23301, 'y2': 23417},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754910,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527799),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527786),
#   'unique_identifier': '56efe99e-f891-4ad4-a9ee-e096ac3916aa',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 7155, 'x2': 7277, 'y1': 28357, 'y2': 28479},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754911,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527850),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527838),
#   'unique_identifier': '766f734f-72f8-41e8-a00e-f664651728b2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12379, 'x2': 12563, 'y1': 5084, 'y2': 5268},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754912,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527901),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527889),
#   'unique_identifier': '252e1142-3ec0-4c3e-b561-a6364e27b5be',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12516, 'x2': 12616, 'y1': 11248, 'y2': 11350},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754913,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527952),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527940),
#   'unique_identifier': '4203780e-6cdf-4110-a191-74ae3d79345a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12220, 'x2': 12318, 'y1': 17806, 'y2': 17902},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754914,
#   'image': 10383,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 528004),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 527991),
#   'unique_identifier': 'e064491d-0279-4d43-a586-82e89fb53847',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12207, 'x2': 12311, 'y1': 23449, 'y2': 23551},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2

#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 530868),
#   'unique_identifier': '747b54d4-e181-4a03-b89e-46d8dfb4393a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19058, 'x2': 19188, 'y1': 17433, 'y2': 17563},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754969,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 530933),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 530921),
#   'unique_identifier': 'efd96ca2-634e-40d2-bb94-28a7dd3a1a70',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19004, 'x2': 19120, 'y1': 22125, 'y2': 22239},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754970,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 530986),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 530973),
#   'unique_identifier': 'b89f2b57-1d78-44e1-9b5e-42c54bd1d268',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 18161, 'x2': 18299, 'y1': 28800, 'y2': 28938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754971,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531038),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531025),
#   'unique_identifier': 'a5017b9a-24e2-4991-927b-d2f9f19c8088',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24669, 'x2': 24783, 'y1': 5241, 'y2': 5355},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754972,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531091),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531078),
#   'unique_identifier': 'e1026d48-8b75-4bca-9c1c-d3bd6eebb335',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24915, 'x2': 25039, 'y1': 11337, 'y2': 11459},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754973,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531154),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531141),
#   'unique_identifier': 'fb21551d-b672-49e5-abde-93a1bb342197',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24687, 'x2': 24823, 'y1': 17184, 'y2': 17318},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754974,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531205),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531193),
#   'unique_identifier': '45bd91ba-1537-49ed-b190-2caaabc7eeab',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24390, 'x2': 24528, 'y1': 23223, 'y2': 23359},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754975,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531255),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531243),
#   'unique_identifier': '5a46c338-acce-4ce8-9b2a-8220877cab62',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24566, 'x2': 24746, 'y1': 28772, 'y2': 28950},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754976,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531307),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531294),
#   'unique_identifier': '08e5ce6e-0f1a-4d20-b595-02db7c347664',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32426, 'x2': 32536, 'y1': 6003, 'y2': 6113},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754977,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531358),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531345),
#   'unique_identifier': '8b91bf01-ab3c-42a6-b0af-b569b40a47d3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30954, 'x2': 31072, 'y1': 11412, 'y2': 11530},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754978,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531408),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531396),
#   'unique_identifier': 'bad56411-825e-4622-a0d5-6d074357d1d7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30603, 'x2': 30711, 'y1': 16995, 'y2': 17125},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754979,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531459),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531447),
#   'unique_identifier': '99688b04-ab63-4b70-b908-058f2aa96d2b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30281, 'x2': 30425, 'y1': 23117, 'y2': 23261},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754980,
#   'image': 10379,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531510),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531497),
#   'unique_identifier': '070065cd-2a6e-45aa-9ef3-2586d7413e18',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30820, 'x2': 30930, 'y1': 28184, 'y2': 28294},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754981,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531561),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531548),
#   'unique_identifier': 'b8fd261d-d9de-4c92-b7c6-1623eaf98051',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 4063, 'x2': 4239, 'y1': 7261, 'y2': 7435},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754982,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531611),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531599),
#   'unique_identifier': '351471d7-fcbd-4164-9c3b-858fde46c4b8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5545, 'x2': 5663, 'y1': 12976, 'y2': 13096},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754983,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531678),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531665),
#   'unique_identifier': '60a8477c-ba76-43e8-a1b2-140b4e616fd8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 4651, 'x2': 4775, 'y1': 19833, 'y2': 19957},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754984,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531732),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531719),
#   'unique_identifier': '140151dc-24d3-4528-9e53-a628ad25aed8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 4687, 'x2': 4863, 'y1': 26094, 'y2': 26268},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754985,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531784),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531771),
#   'unique_identifier': 'e74109b4-3639-4ddb-bcd6-700c6a80ca3d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5827, 'x2': 5937, 'y1': 32447, 'y2': 32557},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754986,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531836),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531823),
#   'unique_identifier': '8bfa88d7-7822-4ed5-92ee-d92401b46ed0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10375, 'x2': 10479, 'y1': 7175, 'y2': 7279},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754987,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531888),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531875),
#   'unique_identifier': '43ac578d-6311-4584-bcfa-264b2fe1f21f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10288, 'x2': 10400, 'y1': 12704, 'y2': 12816},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754988,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531940),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531927),
#   'unique_identifier': '80762266-ce3c-45d0-9df1-2d451acdea99',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10313, 'x2': 10459, 'y1': 19375, 'y2': 19519},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754989,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531992),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 531980),
#   'unique_identifier': 'acfa071c-fa17-4932-ad5e-289315f3acec',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10701, 'x2': 10807, 'y1': 26515, 'y2': 26621},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754990,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 532044),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 532032),
#   'unique_identifier': '968aabf4-5c40-4485-b10c-3f7bd81773d3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10517, 'x2': 10637, 'y1': 33009, 'y2': 33129},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754991,
#   'image': 10377,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 532096),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 532084),
#   'unique_identifier': 'e4804b5e-ba93-4616-8d29-d34b4b632497',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16619, 'x2': 16755, 'y1': 6213, 'y2': 6347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
# ...
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 545930),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 545918),
#   'unique_identifier': 'f5464258-80e9-494d-ab6e-ce0d5526e066',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 33825, 'x2': 33941, 'y1': 21247, 'y2': 21363},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755253,
#   'image': 10385,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 545981),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 545969),
#   'unique_identifier': '1ec50194-0150-4027-bf5c-db55876c2c3e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 34254, 'x2': 34444, 'y1': 29194, 'y2': 29384},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755254,
#   'image': 10385,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546033),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546021),
#   'unique_identifier': '0249a80a-f340-493c-981d-a15f5b7fc56d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 33932, 'x2': 34094, 'y1': 35212, 'y2': 35374},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755255,
#   'image': 10385,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546085),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546072),
#   'unique_identifier': '0835ee1c-1843-463b-8f68-7fac4b2bcddc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 33571, 'x2': 33685, 'y1': 41801, 'y2': 41915},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755256,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546137),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546124),
#   'unique_identifier': '19cd4378-267d-497e-b3da-0df13125ca58',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 6693, 'x2': 6807, 'y1': 5808, 'y2': 5922},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755257,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546188),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546175),
#   'unique_identifier': 'd48ddecc-ae07-4e45-a38f-a152e0a76c44',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 7935, 'x2': 8029, 'y1': 12960, 'y2': 13054},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755258,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546244),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546231),
#   'unique_identifier': '779ac7b4-d0e5-47ce-8d0b-d6850aba35d3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 6592, 'x2': 6704, 'y1': 19013, 'y2': 19127},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755259,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546297),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546284),
#   'unique_identifier': '989e8d61-1512-4999-806f-d8f3767317d5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 7131, 'x2': 7257, 'y1': 24823, 'y2': 24949},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755260,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546348),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546335),
#   'unique_identifier': 'dfae55eb-8fc3-4bf9-9693-93ab91613ba5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 8628, 'x2': 8742, 'y1': 30763, 'y2': 30877},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755261,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546400),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546388),
#   'unique_identifier': '8ff52e37-2b3a-472d-b16a-72ec49d29b3f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12905, 'x2': 13005, 'y1': 5449, 'y2': 5549},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755262,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546452),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546440),
#   'unique_identifier': 'd405f1e2-7340-4273-bf7a-353df8b73f08',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12311, 'x2': 12457, 'y1': 12008, 'y2': 12154},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755263,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546505),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546492),
#   'unique_identifier': '41421865-e1b6-4519-99bb-efe83e0ad63f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13076, 'x2': 13196, 'y1': 18432, 'y2': 18552},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755264,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546556),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546544),
#   'unique_identifier': 'ef151c7e-fa99-4f98-a201-d75f571db502',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13524, 'x2': 13638, 'y1': 25471, 'y2': 25585},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755265,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546608),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546596),
#   'unique_identifier': 'c47b416f-8725-4524-96b7-506b348ee110',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 14321, 'x2': 14447, 'y1': 31947, 'y2': 32073},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755266,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546660),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546647),
#   'unique_identifier': '34931f50-078c-4153-b30e-3bd50ee60fa1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19833, 'x2': 19973, 'y1': 5573, 'y2': 5711},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755267,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546711),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546699),
#   'unique_identifier': 'd5f9f294-fbc6-4f0c-8b0a-c99a4e642875',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19448, 'x2': 19632, 'y1': 11730, 'y2': 11914},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755268,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546763),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546750),
#   'unique_identifier': '42d85009-526e-4a33-80ab-a54d042e23e3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19755, 'x2': 19889, 'y1': 18425, 'y2': 18559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755269,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546814),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546801),
#   'unique_identifier': '1249e59a-1d7e-408b-a09d-153ae2adcc23',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19487, 'x2': 19615, 'y1': 24588, 'y2': 24716},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755270,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546865),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546853),
#   'unique_identifier': '5677a213-87ea-461a-9182-20959596c0b2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19697, 'x2': 19837, 'y1': 31009, 'y2': 31149},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755271,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546917),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546904),
#   'unique_identifier': '8df3b223-e1bd-48cf-999f-31715f4c3b9b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 25691, 'x2': 25831, 'y1': 5490, 'y2': 5630},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755272,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546968),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 546956),
#   'unique_identifier': '9553e58d-290b-4e32-af6e-aa8d779333c2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 25869, 'x2': 26041, 'y1': 13020, 'y2': 13192},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755273,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547020),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547007),
#   'unique_identifier': '571520f0-63d3-4395-82a8-ff023d5dbbed',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26238, 'x2': 26332, 'y1': 18442, 'y2': 18538},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755274,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547073),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547060),
#   'unique_identifier': 'b60a1d19-4219-460c-a522-0cfe70760ec8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26071, 'x2': 26237, 'y1': 24326, 'y2': 24494},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755275,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547125),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547112),
#   'unique_identifier': 'ed2648fa-4818-4751-a4a4-11dfa720aa71',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 25755, 'x2': 25913, 'y1': 31868, 'y2': 32026},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755276,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547177),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547164),
#   'unique_identifier': 'df3b63d5-da21-4fca-9336-cba6ef151289',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31825, 'x2': 31939, 'y1': 5521, 'y2': 5635},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755277,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547228),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547216),
#   'unique_identifier': '39f211cd-034b-4013-9271-439fef05afb9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32723, 'x2': 32861, 'y1': 12278, 'y2': 12414},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755278,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547280),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547267),
#   'unique_identifier': '142f2230-ec26-4609-a5a5-93387387453d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31588, 'x2': 31720, 'y1': 18062, 'y2': 18192},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755279,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547332),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547319),
#   'unique_identifier': '1e9cac70-7c73-4abb-8f8c-4170a0b1b35e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32085, 'x2': 32197, 'y1': 25337, 'y2': 25449},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755280,
#   'image': 10380,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547383),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 12, 28, 41, 547370),
#   'unique_identifier': '1bdfe093-7ecd-49ac-8c16-e96adfaac0c7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31542, 'x2': 31690, 'y1': 31061, 'y2': 31209},
#   'verified_by_user': 'False'}]
