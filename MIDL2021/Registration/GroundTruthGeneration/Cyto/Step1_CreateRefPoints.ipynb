# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'marzahl' #'exact'
configuration.password = '###' #'exact'
configuration.host = "https://exact.cs.fau.de" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download Rect annotation

# %%
annotation_types_points = {}
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
            
for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.name] = annotation_type

annotation_types_points
# Out:
# {'L0': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 384,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L1': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 385,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 1,
#   'vector_type': 1},
#  'L2': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 386,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 2,
#   'vector_type': 1},
#  'L3': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 387,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 3,
#   'vector_type': 1},
#  'L4': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 388,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 4,
#   'vector_type': 1},
#  'L5': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 389,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 5,
#   'vector_type': 1},
#  'L6': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 393,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 6,
#   'vector_type': 1},
#  'L7': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 394,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 7,
#   'vector_type': 1},
#  'L8': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 395,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 8,
#   'vector_type': 1},
#  'L9': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 396,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 9,
#   'vector_type': 1},
#  'L10': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 397,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 10,
#   'vector_type': 1},
#  'L11': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 398,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 11,
#   'vector_type': 1},
#  'L12': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 399,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L13': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 400,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L14': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 401,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L15': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 402,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L16': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 403,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L17': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 404,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L18': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 405,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L19': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 406,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L20': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 407,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L21': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 408,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L22': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 409,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L23': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 410,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L24': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 411,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotation_types_ref_rect
# Out:
# {'area_hit_test': True,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 5000,
#  'default_width': 5000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 412,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 105,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="Cyto_Aperio", expand="product_set,product_set.annotationtype_set").results[0]


for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id, annotation_type=annotation_types_ref_rect.id, # BoundBox ID
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        annotations.append([image.id, image.name, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "id", "vector", "unique_identifier", "annotation_type"])
annotations.head()
# Out:
#    image_id         image_name       id  \
# 0     10392  A_BB_574162_1.svs  2754771
# 1     10389  A_BB_568381_1.svs  2754772
# 2     10387  A_BB_568320_1.svs  2754773
# 3     10384  A_BB_563479_1.svs  2754774
# 4     10378  A_BB_563476_1.svs  2754775
#
#                                               vector  \
# 0  {'x1': 2104, 'x2': 28849, 'y1': 2210, 'y2': 28...
# 1  {'x1': 2634, 'x2': 30395, 'y1': 2927, 'y2': 28...
# 2  {'x1': 2362, 'x2': 29798, 'y1': 3279, 'y2': 29...
# 3  {'x1': 6186, 'x2': 32708, 'y1': 4456, 'y2': 32...
# 4  {'x1': 2336, 'x2': 29860, 'y1': 2826, 'y2': 30...
#
#                       unique_identifier  annotation_type
# 0  5f2be120-fc2e-4c72-afa4-a3d4ba9c86e7              412
# 1  b82de944-fca6-4708-bdd8-5d8714daceb7              412
# 2  f0289b0a-a700-4bcb-aa78-f2e7097819b9              412
# 3  4de1932e-0b82-403e-8173-eccefade512b              412
# 4  fa22bbe8-0d8c-415d-8d42-4f014054f582              412

# %% [markdown]
# ## Load GT and find closest point

# %%
Path("../../../../SDATA/Statistics/SDATA_Final_Annotations.pkl").exists()
# Out:
# True

# %%
df = pd.read_pickle("../../../../SDATA/Statistics/SDATA_Final_Annotations.pkl")

df["x1"] = [vector['x1'] if type(vector) is dict else 0 for vector in df["vector"]]
df["y1"] = [vector['y1'] if type(vector) is dict else 0 for vector in df["vector"]]

df["x2"] = [vector['x2'] if type(vector) is dict else 0 for vector in df["vector"]]
df["y2"] = [vector['y2'] if type(vector) is dict else 0 for vector in df["vector"]]

df["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(df["x1"], df["x2"])]
df["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(df["y1"], df["y2"])]

df["anno_width"] = [x2-x1 for x1, x2 in zip(df["x1"], df["x2"])]
df["anno_height"]= [y2-y1 for y1, y2 in zip(df["y1"], df["y2"])]

df = df.sort_values(by=["grade"], ascending=False)
df.head()
# Out:
#                                            id  image_id  image_set species  \
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d  2460370      5166        240  equine
# 0e97284b-9764-43e8-b077-60d5ab366db2  2344354      5200        269  equine
# 76bad88e-5708-475b-9de4-8ba6d8e9169d  2344374      5200        269  equine
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2  2344371      5200        269  equine
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec  2344368      5200        269  equine
#
#                                                             image_name  \
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d  20_EIPH_576150 berliner blau.svs
# 0e97284b-9764-43e8-b077-60d5ab366db2  14_EIPH_568381 Turnbull blue.svs
# 76bad88e-5708-475b-9de4-8ba6d8e9169d  14_EIPH_568381 Turnbull blue.svs
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2  14_EIPH_568381 Turnbull blue.svs
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec  14_EIPH_568381 Turnbull blue.svs
#
#                                      image_type  grade  \
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d   Prussian      4
# 0e97284b-9764-43e8-b077-60d5ab366db2   Turnbull      4
# 76bad88e-5708-475b-9de4-8ba6d8e9169d   Turnbull      4
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2   Turnbull      4
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec   Turnbull      4
#
#                                                                                  vector  \
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d  {'x1': 22046, 'x2': 22144, 'y1': 27764, 'y2': ...
# 0e97284b-9764-43e8-b077-60d5ab366db2  {'x1': 24442, 'x2': 24528, 'y1': 22640, 'y2': ...
# 76bad88e-5708-475b-9de4-8ba6d8e9169d  {'x1': 28238, 'x2': 28340, 'y1': 15269, 'y2': ...
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2  {'x1': 26802, 'x2': 26902, 'y1': 13212, 'y2': ...
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec  {'x1': 10663, 'x2': 10745, 'y1': 6630, 'y2': 6...
#
#                                       user_id  deleted  ...  data_set_name  \
# unique_identifier                                       ...
# c0eac559-6184-4500-b91f-556b1bc3b19d        1    False  ...           SREP
# 0e97284b-9764-43e8-b077-60d5ab366db2        1    False  ...           SREP
# 76bad88e-5708-475b-9de4-8ba6d8e9169d        1    False  ...           SREP
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2        1    False  ...           SREP
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec        1    False  ...           SREP
#
#                                       version       x1       y1       x2  \
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d  Density  22046.0  27764.0  22144.0
# 0e97284b-9764-43e8-b077-60d5ab366db2  Density  24442.0  22640.0  24528.0
# 76bad88e-5708-475b-9de4-8ba6d8e9169d  Density  28238.0  15269.0  28340.0
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2  Density  26802.0  13212.0  26902.0
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec  Density  10663.0   6630.0  10745.0
#
#                                            y2  center_x  center_y  anno_width  \
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d  27862.0   22095.0   27813.0        98.0
# 0e97284b-9764-43e8-b077-60d5ab366db2  22726.0   24485.0   22683.0        86.0
# 76bad88e-5708-475b-9de4-8ba6d8e9169d  15371.0   28289.0   15320.0       102.0
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2  13312.0   26852.0   13262.0       100.0
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec   6712.0   10704.0    6671.0        82.0
#
#                                       anno_height
# unique_identifier
# c0eac559-6184-4500-b91f-556b1bc3b19d         98.0
# 0e97284b-9764-43e8-b077-60d5ab366db2         86.0
# 76bad88e-5708-475b-9de4-8ba6d8e9169d        102.0
# 7c86d6d4-9764-468e-86ee-aa6b221e75a2        100.0
# 9641c6f1-d045-4a0a-b337-10ea8ee22fec         82.0
#
# [5 rows x 21 columns]

# %%
num_lines = 5
patch_size = 50
search_point_radius = 0.15

registration_points = []
for id, bounding_box in annotations.iterrows():
    
    df_gt = df[df["image_name"].str.contains(bounding_box.image_name.split("_")[-2])]
    
    box_width = bounding_box.vector["x2"] - bounding_box.vector["x1"]
    box_height = bounding_box.vector["y2"] - bounding_box.vector["y1"]
    
    step_size_x = box_width // num_lines
    step_size_y = box_height // num_lines
    
    gt_search_point_radius = int(step_size_x * search_point_radius)
    
    point_index = 0
    for x in range(bounding_box.vector["x1"] + step_size_x //2, bounding_box.vector["x2"], step_size_x):
        for y in range(bounding_box.vector["y1"] + step_size_y //2, bounding_box.vector["y2"], step_size_y):
            
            ref_point = annotation_types_points[f"L{point_index}"]
            
            # find closest annotation in range
            temp = df_gt[(df_gt["center_x"] > x - gt_search_point_radius) & 
                          (df_gt["center_x"] < x + gt_search_point_radius) & 
                          (df_gt["center_y"] > y - gt_search_point_radius) & 
                          (df_gt["center_y"] < y + gt_search_point_radius)].copy()
            
            temp["distance"] = [abs(cx - x) + abs(cy - y) for cx, cy in zip(temp["center_x"], temp["center_y"])]
            temp = temp.sort_values(by=["grade", "distance"], ascending=[False, True])
        
            point = None
            for uuid, gt_anno in temp.iterrows():
                
                vector = {"x1": gt_anno.vector["x1"], "y1": gt_anno.vector["y1"], 
                          "x2": gt_anno.vector["x2"], "y2": gt_anno.vector["y2"]}
                
                
                point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id, uuid]
                break
            
            if point is None: # No ref point found
                
                vector = {"x1": x - patch_size, "y1": y - patch_size, 
                          "x2": x + patch_size, "y2": y + patch_size}
                
                point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id, None]
                
            registration_points.append(point)
                
            point_index += 1
    
registration_points = pd.DataFrame(registration_points, 
                                   columns=["image_id", "vector", "point_index", "point_name", "point_id", "gt_uuid"])
registration_points
# Out:
#      image_id                                             vector  point_index  \
# 0       10392   {'x1': 4728, 'y1': 4826, 'x2': 4828, 'y2': 4926}            0
# 1       10392  {'x1': 4671, 'y1': 10586, 'x2': 4759, 'y2': 10...            1
# 2       10392  {'x1': 5100, 'y1': 15401, 'x2': 5208, 'y2': 15...            2
# 3       10392  {'x1': 5230, 'y1': 21108, 'x2': 5336, 'y2': 21...            3
# 4       10392  {'x1': 5387, 'y1': 25652, 'x2': 5497, 'y2': 25...            4
# ..        ...                                                ...          ...
# 120     10378  {'x1': 27054, 'y1': 5581, 'x2': 27154, 'y2': 5...           20
# 121     10378  {'x1': 27491, 'y1': 11331, 'x2': 27612, 'y2': ...           21
# 122     10378  {'x1': 26509, 'y1': 16374, 'x2': 26624, 'y2': ...           22
# 123     10378  {'x1': 26949, 'y1': 22715, 'x2': 27048, 'y2': ...           23
# 124     10378  {'x1': 26241, 'y1': 27817, 'x2': 26371, 'y2': ...           24
#
#     point_name  point_id                               gt_uuid
# 0           L0       384                                  None
# 1           L1       385  72f12897-7d3c-4458-a7d8-7fdc8e7176ab
# 2           L2       386  a9d37e23-8267-49b1-a637-6c889bd79afa
# 3           L3       387  42096c63-212d-4a51-bf00-e8d34de09f47
# 4           L4       388  56efe99e-f891-4ad4-a9ee-e096ac3916aa
# ..         ...       ...                                   ...
# 120        L20       407                                  None
# 121        L21       408  39f211cd-034b-4013-9271-439fef05afb9
# 122        L22       409  142f2230-ec26-4609-a5a5-93387387453d
# 123        L23       410  1e9cac70-7c73-4abb-8f8c-4170a0b1b35e
# 124        L24       411  1bdfe093-7ecd-49ac-8c16-e96adfaac0c7
#
# [125 rows x 6 columns]

# %% [markdown]
# ## Upload ref Points to EXACT

# %%
annotations_to_upload = []

for id, bounding_box in tqdm(registration_points.iterrows()):
    
    
    exact_annos =  annotations_api.list_annotations(image=bounding_box.image_id, annotation_type=bounding_box.point_id).results
    
    if len(exact_annos) == 0:
        anno = Annotation(annotation_type=bounding_box.point_id, 
                          vector=bounding_box.vector, 
                          image=bounding_box.image_id,
                         unique_identifier=bounding_box.gt_uuid)

        annotations_to_upload.append(anno)

    else:
        prinf(f"ImageId: {bounding_box.image_id}, AnnotationType: {bounding_box.point_id} combination allready exists!")
# Out:
# 125it [00:24,  5.09it/s]

# %%
annotations_to_upload[:3]
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10392,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 4728, 'x2': 4828, 'y1': 4826, 'y2': 4926},
#   'verified_by_user': None},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10392,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '72f12897-7d3c-4458-a7d8-7fdc8e7176ab',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 4671, 'x2': 4759, 'y1': 10586, 'y2': 10674},
#   'verified_by_user': None},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10392,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'a9d37e23-8267-49b1-a637-6c889bd79afa',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 5100, 'x2': 5208, 'y1': 15401, 'y2': 15509},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
#annotations_api.create_annotation(body=annotations_to_upload)
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754781,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322322),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322297),
#   'unique_identifier': 'e4d98794-d4fb-404b-a4ae-4b312b468e8e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 4728, 'x2': 4828, 'y1': 4826, 'y2': 4926},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754782,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322389),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322375),
#   'unique_identifier': '72f12897-7d3c-4458-a7d8-7fdc8e7176ab',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 4671, 'x2': 4759, 'y1': 10586, 'y2': 10674},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754783,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322451),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322438),
#   'unique_identifier': 'a9d37e23-8267-49b1-a637-6c889bd79afa',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5100, 'x2': 5208, 'y1': 15401, 'y2': 15509},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754784,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322508),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322495),
#   'unique_identifier': '42096c63-212d-4a51-bf00-e8d34de09f47',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5230, 'x2': 5336, 'y1': 21108, 'y2': 21214},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754785,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322562),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322549),
#   'unique_identifier': '56efe99e-f891-4ad4-a9ee-e096ac3916aa',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5387, 'x2': 5497, 'y1': 25652, 'y2': 25762},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754786,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322616),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322603),
#   'unique_identifier': '766f734f-72f8-41e8-a00e-f664651728b2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10125, 'x2': 10291, 'y1': 4762, 'y2': 4928},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754787,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322670),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322657),
#   'unique_identifier': '252e1142-3ec0-4c3e-b561-a6364e27b5be',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10202, 'x2': 10293, 'y1': 10131, 'y2': 10223},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754788,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322724),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322711),
#   'unique_identifier': '4203780e-6cdf-4110-a191-74ae3d79345a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9947, 'x2': 10035, 'y1': 16190, 'y2': 16278},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754789,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322778),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322765),
#   'unique_identifier': 'e064491d-0279-4d43-a586-82e89fb53847',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9824, 'x2': 9918, 'y1': 21294, 'y2': 21387},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754790,
#   'image': 10392,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322831),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 322818),
#   'unique_identifier': 'a08d5c39-44f7-4385-b71f-dac222ba035a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9606, 'x2': 9700, 'y1': 26746, 'y2': 26840},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2

#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 325961),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 325948),
#   'unique_identifier': '45bd91ba-1537-49ed-b190-2caaabc7eeab',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21213, 'x2': 21337, 'y1': 21750, 'y2': 21873},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754850,
#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326014),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326001),
#   'unique_identifier': '5a46c338-acce-4ce8-9b2a-8220877cab62',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21540, 'x2': 21701, 'y1': 27242, 'y2': 27403},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754851,
#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326068),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326055),
#   'unique_identifier': '08e5ce6e-0f1a-4d20-b595-02db7c347664',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 27003, 'x2': 27103, 'y1': 5884, 'y2': 5984},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754852,
#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326117),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326104),
#   'unique_identifier': '8b91bf01-ab3c-42a6-b0af-b569b40a47d3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26916, 'x2': 27022, 'y1': 11162, 'y2': 11268},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754853,
#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326170),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326157),
#   'unique_identifier': 'bad56411-825e-4622-a0d5-6d074357d1d7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26971, 'x2': 27069, 'y1': 16271, 'y2': 16389},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754854,
#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326223),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326210),
#   'unique_identifier': '99688b04-ab63-4b70-b908-058f2aa96d2b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26512, 'x2': 26642, 'y1': 21827, 'y2': 21957},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754855,
#   'image': 10387,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326276),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326263),
#   'unique_identifier': '070065cd-2a6e-45aa-9ef3-2586d7413e18',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 27003, 'x2': 27103, 'y1': 27128, 'y2': 27228},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754856,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326325),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326312),
#   'unique_identifier': 'b8fd261d-d9de-4c92-b7c6-1623eaf98051',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 8506, 'x2': 8664, 'y1': 7364, 'y2': 7522},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754857,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326377),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326365),
#   'unique_identifier': '351471d7-fcbd-4164-9c3b-858fde46c4b8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9437, 'x2': 9544, 'y1': 12328, 'y2': 12436},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754858,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326430),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326418),
#   'unique_identifier': '60a8477c-ba76-43e8-a1b2-140b4e616fd8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9149, 'x2': 9261, 'y1': 18659, 'y2': 18771},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754859,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326483),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326470),
#   'unique_identifier': '140151dc-24d3-4528-9e53-a628ad25aed8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9110, 'x2': 9268, 'y1': 24566, 'y2': 24723},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754860,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326536),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326523),
#   'unique_identifier': 'e74109b4-3639-4ddb-bcd6-700c6a80ca3d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 8788, 'x2': 8888, 'y1': 29786, 'y2': 29886},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754861,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326586),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326573),
#   'unique_identifier': '8bfa88d7-7822-4ed5-92ee-d92401b46ed0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13980, 'x2': 14074, 'y1': 7334, 'y2': 7428},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754862,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326639),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326626),
#   'unique_identifier': '43ac578d-6311-4584-bcfa-264b2fe1f21f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 14004, 'x2': 14105, 'y1': 12384, 'y2': 12485},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754863,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326692),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326679),
#   'unique_identifier': '80762266-ce3c-45d0-9df1-2d451acdea99',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 14003, 'x2': 14134, 'y1': 18369, 'y2': 18500},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754864,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326745),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326732),
#   'unique_identifier': 'acfa071c-fa17-4932-ad5e-289315f3acec',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 14395, 'x2': 14491, 'y1': 24688, 'y2': 24784},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754865,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326799),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326786),
#   'unique_identifier': '968aabf4-5c40-4485-b10c-3f7bd81773d3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 14216, 'x2': 14324, 'y1': 30524, 'y2': 30632},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754866,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326860),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 326847),
#   'unique_identifier': 'e4804b5e-ba93-4616-8d29-d34b4b632497',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 19731, 'x2': 19853, 'y1': 6460, 'y2': 6582},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
# ...
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327441),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327429),
#   'unique_identifier': 'f5464258-80e9-494d-ab6e-ce0d5526e066',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 29819, 'x2': 29920, 'y1': 12773, 'y2': 12875},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754878,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327494),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327481),
#   'unique_identifier': '1ec50194-0150-4027-bf5c-db55876c2c3e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30401, 'x2': 30567, 'y1': 18896, 'y2': 19062},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754879,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327547),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327534),
#   'unique_identifier': '0249a80a-f340-493c-981d-a15f5b7fc56d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30059, 'x2': 30201, 'y1': 24788, 'y2': 24930},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754880,
#   'image': 10384,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327600),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327587),
#   'unique_identifier': '0835ee1c-1843-463b-8f68-7fac4b2bcddc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30004, 'x2': 30104, 'y1': 29786, 'y2': 29886},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754881,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327649),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327637),
#   'unique_identifier': '19cd4378-267d-497e-b3da-0df13125ca58',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5038, 'x2': 5138, 'y1': 5581, 'y2': 5681},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754882,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327698),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327686),
#   'unique_identifier': 'd48ddecc-ae07-4e45-a38f-a152e0a76c44',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5830, 'x2': 5913, 'y1': 12019, 'y2': 12101},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754883,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327751),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327738),
#   'unique_identifier': '779ac7b4-d0e5-47ce-8d0b-d6850aba35d3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 4736, 'x2': 4835, 'y1': 17229, 'y2': 17329},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754884,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327804),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327791),
#   'unique_identifier': '989e8d61-1512-4999-806f-d8f3767317d5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5212, 'x2': 5323, 'y1': 22293, 'y2': 22404},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754885,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327857),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327844),
#   'unique_identifier': 'dfae55eb-8fc3-4bf9-9693-93ab91613ba5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 5038, 'x2': 5138, 'y1': 28021, 'y2': 28121},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754886,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327905),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327892),
#   'unique_identifier': '8ff52e37-2b3a-472d-b16a-72ec49d29b3f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10220, 'x2': 10308, 'y1': 5399, 'y2': 5487},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754887,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327958),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327945),
#   'unique_identifier': 'd405f1e2-7340-4273-bf7a-353df8b73f08',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9710, 'x2': 9838, 'y1': 11117, 'y2': 11245},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754888,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328011),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 327998),
#   'unique_identifier': '41421865-e1b6-4519-99bb-efe83e0ad63f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10384, 'x2': 10490, 'y1': 16728, 'y2': 16834},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754889,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328063),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328050),
#   'unique_identifier': 'ef151c7e-fa99-4f98-a201-d75f571db502',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10782, 'x2': 10882, 'y1': 22851, 'y2': 22951},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754890,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328117),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328104),
#   'unique_identifier': 'c47b416f-8725-4524-96b7-506b348ee110',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10861, 'x2': 10972, 'y1': 28442, 'y2': 28553},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754891,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328169),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328156),
#   'unique_identifier': '34931f50-078c-4153-b30e-3bd50ee60fa1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16255, 'x2': 16377, 'y1': 5500, 'y2': 5622},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754892,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328221),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328209),
#   'unique_identifier': 'd5f9f294-fbc6-4f0c-8b0a-c99a4e642875',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15927, 'x2': 16088, 'y1': 10867, 'y2': 11029},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754893,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328274),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328262),
#   'unique_identifier': '42d85009-526e-4a33-80ab-a54d042e23e3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16202, 'x2': 16319, 'y1': 16703, 'y2': 16820},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754894,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328327),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328314),
#   'unique_identifier': '1249e59a-1d7e-408b-a09d-153ae2adcc23',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15959, 'x2': 16072, 'y1': 22002, 'y2': 22115},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754895,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328379),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328366),
#   'unique_identifier': '5677a213-87ea-461a-9182-20959596c0b2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16165, 'x2': 16288, 'y1': 27672, 'y2': 27795},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754896,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328432),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328419),
#   'unique_identifier': '8df3b223-e1bd-48cf-999f-31715f4c3b9b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21536, 'x2': 21659, 'y1': 5220, 'y2': 5343},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754897,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328485),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328472),
#   'unique_identifier': '9553e58d-290b-4e32-af6e-aa8d779333c2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21521, 'x2': 21672, 'y1': 11985, 'y2': 12136},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754898,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328538),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328525),
#   'unique_identifier': '571520f0-63d3-4395-82a8-ff023d5dbbed',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21812, 'x2': 21895, 'y1': 16733, 'y2': 16817},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754899,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328591),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328578),
#   'unique_identifier': 'b60a1d19-4219-460c-a522-0cfe70760ec8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21710, 'x2': 21856, 'y1': 21841, 'y2': 21988},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754900,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328643),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328631),
#   'unique_identifier': 'ed2648fa-4818-4751-a4a4-11dfa720aa71',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21172, 'x2': 21310, 'y1': 27883, 'y2': 28022},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754901,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328696),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328683),
#   'unique_identifier': 'df3b63d5-da21-4fca-9336-cba6ef151289',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 27054, 'x2': 27154, 'y1': 5581, 'y2': 5681},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754902,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328745),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328732),
#   'unique_identifier': '39f211cd-034b-4013-9271-439fef05afb9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 27491, 'x2': 27612, 'y1': 11331, 'y2': 11451},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754903,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328798),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328785),
#   'unique_identifier': '142f2230-ec26-4609-a5a5-93387387453d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26509, 'x2': 26624, 'y1': 16374, 'y2': 16489},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754904,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328851),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328838),
#   'unique_identifier': '1e9cac70-7c73-4abb-8f8c-4170a0b1b35e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26949, 'x2': 27048, 'y1': 22715, 'y2': 22814},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2754905,
#   'image': 10378,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328904),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 11, 58, 15, 328891),
#   'unique_identifier': '1bdfe093-7ecd-49ac-8c16-e96adfaac0c7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 26241, 'x2': 26371, 'y1': 27817, 'y2': 27947},
#   'verified_by_user': 'False'}]
