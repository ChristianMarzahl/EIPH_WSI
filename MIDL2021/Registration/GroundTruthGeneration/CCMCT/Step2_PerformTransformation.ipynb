# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import pickle
import numpy as np

# %%
from openslide import OpenSlide

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %%
import sys
sys.path.append("../..")
from registration_tree import Rect, QuadTree

# %% [markdown]
# ## Find and load slides from HDD

# %%
slide_list = {path.name: path for path in Path(r"D:\Datasets\ScannerStudy").glob("*/*/*.*") 
                      if path.suffix in [".svs", ".ndpi", ".tif"]}

slide_list
# Out:
# {'A_CCMCT_183715A_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_183715A_1.svs'),
#  'A_CCMCT_22108_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_22108_1.svs'),
#  'A_CCMCT_29609B_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_29609B_1.svs'),
#  'A_CCMCT_380609B_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_380609B_1.svs'),
#  'A_CCMCT_518711B_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/CCMCT/A_CCMCT_518711B_1.svs'),
#  'A_BB_563476_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_563476_1.svs'),
#  'A_BB_563479_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_563479_1.svs'),
#  'A_BB_568320_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_568320_1.svs'),
#  'A_BB_568381_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_568381_1.svs'),
#  'A_BB_574162_1.svs': WindowsPath('D:/Datasets/ScannerStudy/Aperio/Cyto/A_BB_574162_1.svs'),
#  'Z_CCMCT_183715A_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_183715A_1.tif'),
#  'Z_CCMCT_22108_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_22108_1.tif'),
#  'Z_CCMCT_29609B_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_29609B_1.tif'),
#  'Z_CCMCT_380609B_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_380609B_1.tif'),
#  'Z_CCMCT_518711B_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/CCMCT/Z_CCMCT_518711B_1.tif'),
#  'Z_BB_563476_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_563476_1.tif'),
#  'Z_BB_563479_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_563479_1.tif'),
#  'Z_BB_568320_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_568320_1.tif'),
#  'Z_BB_568381_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_568381_1.tif'),
#  'Z_BB_574162_1.tif': WindowsPath('D:/Datasets/ScannerStudy/AxioScan/Cyto/Z_BB_574162_1.tif'),
#  'N2_CCMCT_183715A_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_183715A_1.ndpi'),
#  'N2_CCMCT_22108_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_22108_1.ndpi'),
#  'N2_CCMCT_29609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_29609B_1.ndpi'),
#  'N2_CCMCT_380609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_380609B_1.ndpi'),
#  'N2_CCMCT_518711B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/CCMCT/N2_CCMCT_518711B_1.ndpi'),
#  'N2_BB_563476_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_563476_1.ndpi'),
#  'N2_BB_563479_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_563479_1.ndpi'),
#  'N2_BB_568320_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_568320_1.ndpi'),
#  'N2_BB_568381_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_568381_1.ndpi'),
#  'N2_BB_574162_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomer2.0HT/Cyto/N2_BB_574162_1.ndpi'),
#  'N1_CCMCT_183715A_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_183715A_1.ndpi'),
#  'N1_CCMCT_22108_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_22108_1.ndpi'),
#  'N1_CCMCT_29609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_29609B_1.ndpi'),
#  'N1_CCMCT_380609B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_380609B_1.ndpi'),
#  'N1_CCMCT_518711B_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/CCMCT/N1_CCMCT_518711B_1.ndpi'),
#  'N1_BB_563476_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_563476_1.ndpi'),
#  'N1_BB_563479_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_563479_1.ndpi'),
#  'N1_BB_568320_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_568320_1.ndpi'),
#  'N1_BB_568381_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_568381_1.ndpi'),
#  'N1_BB_574162_1.ndpi': WindowsPath('D:/Datasets/ScannerStudy/NanoZoomerS210/Cyto/N1_BB_574162_1.ndpi')}

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'marzahl' #'exact'
configuration.password = '####' #'exact'
configuration.host = "https://exact.cs.fau.de" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download RefPoints annotation

# %%
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
        
annotation_types_ref_rect
# Out:
# {'area_hit_test': False,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 5000,
#  'default_width': 5000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 412,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 105,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="CCMCT_Aperio", expand="product_set,product_set.annotationtype_set").results[0]

for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id,
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        if anno.annotation_type != annotation_types_ref_rect.id:
            annotations.append([image.id, image.name, Path(image.name).stem.split("_")[2].split("_")[0], anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "image_name_short", "id", "vector", "unique_identifier", "annotation_type"])
annotations
# Out:
#      image_id             image_name image_name_short       id  \
# 0       10416  A_CCMCT_518711B_1.svs          518711B  2755281
# 1       10416  A_CCMCT_518711B_1.svs          518711B  2755282
# 2       10416  A_CCMCT_518711B_1.svs          518711B  2755283
# 3       10416  A_CCMCT_518711B_1.svs          518711B  2755284
# 4       10416  A_CCMCT_518711B_1.svs          518711B  2755285
# ..        ...                    ...              ...      ...
# 120     10398    A_CCMCT_22108_1.svs            22108  2755401
# 121     10398    A_CCMCT_22108_1.svs            22108  2755402
# 122     10398    A_CCMCT_22108_1.svs            22108  2755403
# 123     10398    A_CCMCT_22108_1.svs            22108  2755404
# 124     10398    A_CCMCT_22108_1.svs            22108  2755405
#
#                                                 vector  \
# 0    {'x1': 13431, 'x2': 13481, 'y1': 8432, 'y2': 8...
# 1    {'x1': 15560, 'x2': 15610, 'y1': 25727, 'y2': ...
# 2    {'x1': 13378, 'x2': 13428, 'y1': 42978, 'y2': ...
# 3    {'x1': 12126, 'x2': 12176, 'y1': 58187, 'y2': ...
# 4    {'x1': 13405, 'x2': 13455, 'y1': 71704, 'y2': ...
# ..                                                 ...
# 120  {'x1': 88422, 'x2': 88472, 'y1': 11835, 'y2': ...
# 121  {'x1': 88406, 'x2': 88456, 'y1': 28051, 'y2': ...
# 122  {'x1': 88353, 'x2': 88403, 'y1': 44115, 'y2': ...
# 123  {'x1': 88463, 'x2': 88513, 'y1': 60497, 'y2': ...
# 124  {'x1': 88810, 'x2': 88860, 'y1': 77062, 'y2': ...
#
#                         unique_identifier  annotation_type
# 0    ca3fde15-30ed-45bd-bd58-00aadf29eba9              384
# 1    0acc9849-e7aa-4657-8055-bb7e8b4a31e0              385
# 2    e44ca58f-3316-4d02-b6b1-1d44f2664682              386
# 3    99a54973-1bf3-4cbc-a55b-a09b62e0e38f              387
# 4    ecc654b9-910b-4792-955b-52070dbff958              388
# ..                                    ...              ...
# 120  25aa751c-06cf-463c-ace9-8397c567972b              407
# 121  8a4bc90e-afd7-4a3a-8028-1a6c24ab97f8              408
# 122  edce5b71-592c-49f4-b70c-bf8f8faec9a0              409
# 123  cd11d8de-2fc8-48c1-9699-a4a86746c0fb              410
# 124  444d96a3-d87b-4873-b6f2-2f31e18d6e41              411
#
# [125 rows x 7 columns]

# %% [markdown]
# ## Add some helper variables

# %%
annotations["x1"] = [vector['x1'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y1"] = [vector['y1'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["x2"] = [vector['x2'] if type(vector) is dict else 0 for vector in annotations["vector"]]
annotations["y2"] = [vector['y2'] if type(vector) is dict else 0 for vector in annotations["vector"]]

annotations["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(annotations["y1"], annotations["y2"])]

annotations["anno_width"] = [x2-x1 for x1, x2 in zip(annotations["x1"], annotations["x2"])]
annotations["anno_height"]= [y2-y1 for y1, y2 in zip(annotations["y1"], annotations["y2"])]

# %% [markdown]
# ## Load QuadTree for each scanner and transform coordinates

# %%
transformed_annotations_to_upload = []

for image_set_name in tqdm(["CCMCT_2.0HT", "CCMCT_Axio", "CCMCT_S210"]):
    image_set = image_sets_api.list_image_sets(name=image_set_name, expand="product_set,product_set.annotationtype_set").results[0]

    for image_id in image_set.images:
        
        target_image = images_api.retrieve_image(id=image_id)
        
        source_annos = annotations[annotations["image_name_short"] == Path(target_image.name).stem.split("_")[2].split("_")[0]]
        
        source_name = list(source_annos["image_name"].unique())[0]
        target_name = target_image.name
        
        qtree = pickle.load(open(f'../../CCMCT/{Path(source_name).stem}-To-{Path(target_name).stem}.pickle', "rb" ))
        qtree.source_slide = OpenSlide(str(slide_list[source_name]))
        qtree.target_slide = OpenSlide(str(slide_list[target_name]))
        
        for id, source_anno in source_annos.iterrows():

            box = [source_anno.center_x, source_anno.center_y, source_anno.anno_width, source_anno.anno_height]

            trans_box = qtree.transform_boxes(np.array([box]))[0]

            new_x1 = int(trans_box[0] - trans_box[2] // 2)
            new_y1 = int(trans_box[1] - trans_box[3] // 2)
            new_x2 = int(trans_box[0] + trans_box[2] // 2)
            new_y2 = int(trans_box[1] + trans_box[3] // 2)

            vector = {'x1': new_x1, 'x2': new_x2, 'y1': new_y1, 'y2': new_y2}

            anno = Annotation(annotation_type=source_anno.annotation_type, 
                                  vector=vector, 
                                  image=target_image.id,
                                 unique_identifier=source_anno.unique_identifier)

            transformed_annotations_to_upload.append(anno)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:09<00:00,  3.04s/it]

# %%
transformed_annotations_to_upload[:3]
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '95183f6e-0a00-4de4-9c97-fedfec655a27',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 20328, 'x2': 20382, 'y1': 16747, 'y2': 16801},
#   'verified_by_user': None},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': 'cc3def2b-5631-4619-ab08-51f2a69c667d',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 20265, 'x2': 20319, 'y1': 35440, 'y2': 35494},
#   'verified_by_user': None},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10410,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': '2d3de917-e55a-470f-8af2-10eb49b69687',
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 20491, 'x2': 20545, 'y1': 54126, 'y2': 54180},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
#annotations_api.create_annotation(body=transformed_annotations_to_upload)
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755406,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770035),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770002),
#   'unique_identifier': '95183f6e-0a00-4de4-9c97-fedfec655a27',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20328, 'x2': 20382, 'y1': 16747, 'y2': 16801},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755407,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770124),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770094),
#   'unique_identifier': 'cc3def2b-5631-4619-ab08-51f2a69c667d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20265, 'x2': 20319, 'y1': 35440, 'y2': 35494},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755408,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770186),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770171),
#   'unique_identifier': '2d3de917-e55a-470f-8af2-10eb49b69687',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20491, 'x2': 20545, 'y1': 54126, 'y2': 54180},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755409,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770245),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770231),
#   'unique_identifier': '611f9d35-6cdb-42ef-bc38-2f44c9aaa257',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21280, 'x2': 21334, 'y1': 72505, 'y2': 72559},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755410,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770302),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770288),
#   'unique_identifier': 'bf3ef0d3-5153-4693-96ba-96047cb3ae24',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20268, 'x2': 20322, 'y1': 91486, 'y2': 91540},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755411,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770359),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770346),
#   'unique_identifier': 'e0765891-b4ff-4eec-9443-77a37c32ae76',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 46821, 'x2': 46875, 'y1': 16676, 'y2': 16730},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755412,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770416),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770403),
#   'unique_identifier': '2331e98a-3cd0-44c5-bf5a-a57ce20d37f2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 48616, 'x2': 48670, 'y1': 35157, 'y2': 35211},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755413,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770473),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770460),
#   'unique_identifier': 'a7a9941f-7307-4276-9017-22828fc8013c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 43485, 'x2': 43539, 'y1': 54258, 'y2': 54312},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755414,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770538),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770526),
#   'unique_identifier': '7d35c9a8-6f0b-4fb8-ac47-fbb8352eb0c3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 47817, 'x2': 47871, 'y1': 73807, 'y2': 73861},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755415,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770592),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770579),
#   'unique_identifier': 'e1dfa3c3-28bc-4d12-9a3a-37b3b77746bc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 46148, 'x2': 46202, 'y1': 91317, 'y2': 91371},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755416,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770645),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770632),
#   'unique_identifier': '4a65486b-11af-4e75-bf9a-cb1dea43c15f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 73756, 'x2': 73810, 'y1': 16570, 'y2': 16624},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755417,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770698),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770685),
#   'unique_identifier': 'ce71cdb5-5764-46a8-925b-b436bdbfd1df',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 72936, 'x2': 72990, 'y1': 35715, 'y2': 35769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755418,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770750),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770738),
#   'unique_identifier': 'f06e8946-1679-448a-a743-c40deafed44c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 72675, 'x2': 72729, 'y1': 54497, 'y2': 54551},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755419,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770802),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770790),
#   'unique_identifier': '5956fa92-834c-4e96-80ab-d5ed4a923214',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 72439, 'x2': 72493, 'y1': 71040, 'y2': 71094},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755420,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770854),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770842),
#   'unique_identifier': '6056cfea-067e-4cb9-8aae-9fb8d4becbcb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 73987, 'x2': 74041, 'y1': 93364, 'y2': 93418},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755421,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770907),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770894),
#   'unique_identifier': 'd896ff6b-9d95-4316-affb-af36ff0cc3b7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 99764, 'x2': 99818, 'y1': 16511, 'y2': 16565},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755422,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770959),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770947),
#   'unique_identifier': 'f3115c15-ff56-4ecf-8039-2f019ca02327',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 99779, 'x2': 99833, 'y1': 35123, 'y2': 35177},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755423,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771012),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 770999),
#   'unique_identifier': '6c920499-c9bf-4277-b382-d916332da5d7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 100734, 'x2': 100788, 'y1': 56063, 'y2': 56117},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755424,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771065),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771052),
#   'unique_identifier': '5cc4e10f-74af-41c6-adf1-f9427b1f3299',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 103229, 'x2': 103283, 'y1': 72617, 'y2': 72671},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755425,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771117),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771104),
#   'unique_identifier': 'b17e8936-7b87-4ccc-a613-af57183a2cf5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 102249, 'x2': 102303, 'y1': 91520, 'y2': 91574},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755426,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771169),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771157),
#   'unique_identifier': '1f8ca805-a23e-4eec-8aad-8bec244fc890',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 128568, 'x2': 128622, 'y1': 16170, 'y2': 16224},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755427,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771222),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771209),
#   'unique_identifier': 'bd460419-2e47-46c5-8112-b5cdaed66178',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 128363, 'x2': 128417, 'y1': 35164, 'y2': 35218},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755428,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771275),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771263),
#   'unique_identifier': '58f2c103-e029-4064-bb67-c7807eafa68f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 126579, 'x2': 126633, 'y1': 53397, 'y2': 53451},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755429,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771328),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771316),
#   'unique_identifier': 'd7a95146-a971-49f5-a2e6-b85d891dc551',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 127268, 'x2': 127322, 'y1': 72463, 'y2': 72517},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755430,
#   'image': 10410,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771381),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771368),
#   'unique_identifier': 'bf487559-bfca-4a98-abb4-15e963f25aa5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 127580, 'x2': 127634, 'y1': 91155, 'y2': 91209},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755431,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771434),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771422),
#   'unique_identifier': 'ca3fde15-30ed-45bd-bd58-00aadf29eba9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16396, 'x2': 16450, 'y1': 8906, 'y2': 8960},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755432,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771487),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771474),
#   'unique_identifier': '0acc9849-e7aa-4657-8055-bb7e8b4a31e0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 18814, 'x2': 18868, 'y1': 28138, 'y2': 28192},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755433,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771540),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771527),
#   'unique_identifier': 'e44ca58f-3316-4d02-b6b1-1d44f2664682',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16408, 'x2': 16462, 'y1': 47330, 'y2': 47384},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755434,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771592),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771580),
#   'unique_identifier': '99a54973-1bf3-4cbc-a55b-a09b62e0e38f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15039, 'x2': 15093, 'y1': 64248, 'y2': 64302},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755435,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771645),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771632),
#   'unique_identifier': 'ecc654b9-910b-4792-955b-52070dbff958',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 16497, 'x2': 16551, 'y1': 79279, 'y2': 79333},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755436,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771697),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771684),
#   'unique_identifier': '57d03dc4-c56d-4ed1-b8c2-9577ae180fc2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 37499, 'x2': 37553, 'y1': 12654, 'y2': 12708},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755437,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771749),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771736),
#   'unique_identifier': 'eeebc67f-e541-4261-a0e5-7bd5a7ded8ec',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 38363, 'x2': 38417, 'y1': 29055, 'y2': 29109},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755438,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771801),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771789),
#   'unique_identifier': 'd2744f71-bd4b-4371-89b5-c9a4b10f8327',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 37787, 'x2': 37841, 'y1': 45922, 'y2': 45976},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755439,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771854),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771841),
#   'unique_identifier': 'efd11d62-ada1-4374-bd9b-36340963f989',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 40637, 'x2': 40691, 'y1': 64347, 'y2': 64401},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755440,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771907),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771894),
#   'unique_identifier': 'af85e94b-f67d-45eb-9db7-99b9ff192aed',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 35819, 'x2': 35873, 'y1': 84468, 'y2': 84522},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755441,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771960),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 771947),
#   'unique_identifier': '95997877-d9a2-4f48-9562-1bde8adef701',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 61582, 'x2': 61636, 'y1': 10789, 'y2': 10843},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755442,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772014),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772001),
#   'unique_identifier': '0dca7206-5161-40dc-bf01-766eadbf3411',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 60878, 'x2': 60932, 'y1': 28619, 'y2': 28673},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755443,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772066),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772054),
#   'unique_identifier': 'db7627b7-a7c0-4e6a-9fc4-82f054d2cc1b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 61014, 'x2': 61068, 'y1': 46300, 'y2': 46354},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755444,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772119),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772106),
#   'unique_identifier': '1c59ff23-d5d9-45f2-b1ef-ced165b6d072',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 61416, 'x2': 61470, 'y1': 63777, 'y2': 63831},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755445,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772172),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772159),
#   'unique_identifier': '87d95aa9-5a07-4b09-8cf7-f120dc556c0d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 61147, 'x2': 61201, 'y1': 81501, 'y2': 81555},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755446,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772225),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772212),
#   'unique_identifier': '3020e9c6-e93f-4d03-b338-571bb3fe909b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 82633, 'x2': 82687, 'y1': 13967, 'y2': 14021},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755447,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772277),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772264),
#   'unique_identifier': '5559ba61-2423-49fd-9a92-b5d85e92fca1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 84115, 'x2': 84169, 'y1': 28888, 'y2': 28942},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755448,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772330),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772317),
#   'unique_identifier': 'eb658d9d-dbff-41e4-9a6a-b35613780e6c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 84473, 'x2': 84527, 'y1': 46359, 'y2': 46413},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755449,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772382),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772370),
#   'unique_identifier': '7c93830b-8ab8-4e8b-8cd9-2fe23d1dd0c1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 84775, 'x2': 84829, 'y1': 64060, 'y2': 64114},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755450,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772435),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772422),
#   'unique_identifier': '6f516672-cf75-4e16-8eb1-2803ad9781a3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 84346, 'x2': 84400, 'y1': 81396, 'y2': 81450},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755451,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772488),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772475),
#   'unique_identifier': 'efbb7806-adfc-4f92-be3a-208391499fc1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 106786, 'x2': 106840, 'y1': 10964, 'y2': 11018},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755452,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772540),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772528),
#   'unique_identifier': '730e83bf-4247-485f-9d77-b3b4f37268b8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 107355, 'x2': 107409, 'y1': 28924, 'y2': 28978},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755453,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772594),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772580),
#   'unique_identifier': '040473b7-3fe9-4861-aea7-006f2ffebccc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 107556, 'x2': 107610, 'y1': 46291, 'y2': 46345},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755454,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772646),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772634),
#   'unique_identifier': '56eb2484-b791-4816-bca7-0285e2cbc3ba',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 107407, 'x2': 107461, 'y1': 64279, 'y2': 64333},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755455,
#   'image': 10404,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772699),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772686),
#   'unique_identifier': '669f91cf-9df7-4867-a73f-27c89d6dd91b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 108014, 'x2': 108068, 'y1': 81629, 'y2': 81683},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755456,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772751),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772739),
#   'unique_identifier': '45e2d88d-8211-419b-a754-6d71dd317ec5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 14515, 'x2': 14569, 'y1': 8218, 'y2': 8272},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755457,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772804),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772791),
#   'unique_identifier': 'ff307a78-11ec-4a05-b8c8-ad90a2cb18ed',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12064, 'x2': 12118, 'y1': 22433, 'y2': 22487},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755458,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772856),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772843),
#   'unique_identifier': 'ee578e27-99c4-4ab9-a10a-0a19fd58f4fa',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10801, 'x2': 10855, 'y1': 36584, 'y2': 36638},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755459,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772916),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772903),
#   'unique_identifier': '27f6e3b9-8627-414a-b6d8-b8e111031d54',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10982, 'x2': 11036, 'y1': 49436, 'y2': 49490},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755460,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772968),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 772956),
#   'unique_identifier': '3241e205-68af-44c2-af0c-f88461410510',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10619, 'x2': 10673, 'y1': 64496, 'y2': 64550},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755461,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773022),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773009),
#   'unique_identifier': '212779a8-3d64-4ea3-a604-a7f775bb4d0f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 27472, 'x2': 27526, 'y1': 9215, 'y2': 9269},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755462,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773094),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773081),
#   'unique_identifier': 'c0da107c-1f64-4aea-992e-b513a57fd86c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 28024, 'x2': 28078, 'y1': 23469, 'y2': 23523},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755463,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773148),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773135),
#   'unique_identifier': 'a0a485c6-7512-4cc7-9262-55d83c5d5eec',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 28401, 'x2': 28455, 'y1': 36789, 'y2': 36843},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755464,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773201),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773188),
#   'unique_identifier': '0a36744e-fffa-4cbb-a9ed-e7c0e672ebcf',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 28207, 'x2': 28261, 'y1': 50636, 'y2': 50690},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755465,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773256),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773243),
#   'unique_identifier': '23cbcc46-f1f1-4675-a3a8-e491402fcae1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 27402, 'x2': 27456, 'y1': 63984, 'y2': 64038},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755466,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773309),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773296),
#   'unique_identifier': 'd9e54ded-a295-4a96-877b-a56df0d9ef42',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 43231, 'x2': 43285, 'y1': 8884, 'y2': 8938},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755467,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773361),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773348),
#   'unique_identifier': 'c9772f33-ed8e-44de-9916-53b9f127484a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 43819, 'x2': 43873, 'y1': 22684, 'y2': 22738},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755468,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773413),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773401),
#   'unique_identifier': '0de8d67c-c163-4c50-a07f-e1ce75265a01',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 43920, 'x2': 43974, 'y1': 36559, 'y2': 36613},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755469,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773466),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773453),
#   'unique_identifier': 'e6ca2e79-51b2-4c76-9a85-72ae119f57cd',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 43019, 'x2': 43073, 'y1': 50446, 'y2': 50500},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755470,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773519),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773506),
#   'unique_identifier': '6ca099dd-0c1b-4ba2-bbf8-09f5719afdba',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 42815, 'x2': 42869, 'y1': 63923, 'y2': 63977},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755471,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773572),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773559),
#   'unique_identifier': 'f4d845f3-bc78-4d9d-9ec4-80c0a9a15d8e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 59626, 'x2': 59680, 'y1': 10453, 'y2': 10507},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755472,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773625),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773612),
#   'unique_identifier': '6e5470c0-7c72-4c5f-b074-bba46709b0fb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 60174, 'x2': 60228, 'y1': 23168, 'y2': 23222},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755473,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773678),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773665),
#   'unique_identifier': 'dac979c3-8b83-49bb-8e9c-c98f425e01cf',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 59518, 'x2': 59572, 'y1': 35091, 'y2': 35145},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755474,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773730),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773717),
#   'unique_identifier': '91f2e56a-4d14-48c2-8def-56fbe7d907c3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 60152, 'x2': 60206, 'y1': 50164, 'y2': 50218},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755475,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773784),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773771),
#   'unique_identifier': '701c7cc9-044c-438d-8b5c-99476df7de08',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 60362, 'x2': 60416, 'y1': 62876, 'y2': 62930},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755476,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773837),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773824),
#   'unique_identifier': '294c4a75-4ba2-444f-9792-8f4ba22549c5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 76406, 'x2': 76460, 'y1': 9357, 'y2': 9411},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755477,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773890),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773877),
#   'unique_identifier': '20a2bf26-907a-467b-b564-de2cf22d0ad3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 76284, 'x2': 76338, 'y1': 22236, 'y2': 22290},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755478,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773942),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773930),
#   'unique_identifier': '0e26c28e-76b6-4750-8a52-9bbf9f2fa91b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 73720, 'x2': 73774, 'y1': 37386, 'y2': 37440},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755479,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773997),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 773984),
#   'unique_identifier': '8930d408-58fb-4e63-88a6-318e75a709a9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 74640, 'x2': 74694, 'y1': 50033, 'y2': 50087},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755480,
#   'image': 10402,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774050),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774037),
#   'unique_identifier': '5cf1a3f9-8cbc-4170-9b24-688be640358b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 76506, 'x2': 76560, 'y1': 64128, 'y2': 64182},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755481,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774103),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774089),
#   'unique_identifier': '926ce459-6588-4735-9ca0-00dbef58a1f7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32029, 'x2': 32083, 'y1': 7644, 'y2': 7698},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755482,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774156),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774143),
#   'unique_identifier': '20430e9a-e2cb-480c-b184-fefa76c3a60b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32043, 'x2': 32097, 'y1': 21244, 'y2': 21298},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755483,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774210),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774197),
#   'unique_identifier': '02b4dbec-4681-4920-a2ee-8bbb1caf40dc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32215, 'x2': 32269, 'y1': 35008, 'y2': 35062},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755484,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774263),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774250),
#   'unique_identifier': 'de5944fc-6c1e-4084-9ccb-55ed0452a81c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 33644, 'x2': 33698, 'y1': 49482, 'y2': 49536},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755485,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774317),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774304),
#   'unique_identifier': 'c76f4470-f927-4499-8764-0f6e46c6fd68',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32365, 'x2': 32419, 'y1': 62605, 'y2': 62659},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755486,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774369),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774356),
#   'unique_identifier': 'e609a629-5c08-435a-96b1-2098cffdc361',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 43531, 'x2': 43585, 'y1': 7621, 'y2': 7675},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755487,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774422),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774409),
#   'unique_identifier': '121b5aa0-4b9e-4460-9af3-106e0b90a47a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 42070, 'x2': 42124, 'y1': 20324, 'y2': 20378},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755488,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774475),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774462),
#   'unique_identifier': '2c24d90c-4799-4090-badc-f4773420b6f5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 42365, 'x2': 42419, 'y1': 35093, 'y2': 35147},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755489,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774528),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774515),
#   'unique_identifier': 'c3efde27-3eee-4bc0-9a95-aa2352a185be',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 42552, 'x2': 42606, 'y1': 49902, 'y2': 49956},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755490,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774580),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774567),
#   'unique_identifier': 'e44d5208-96b1-4545-b994-bc81b4c6f7ae',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 42809, 'x2': 42863, 'y1': 62658, 'y2': 62712},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755491,
#   'image': 10400,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774633),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 774620),
#   'unique_identifier': 'cfad2fe3-fae0-495d-8ed3-57d9e70a8dc3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 51791, 'x2': 51845, 'y1': 7801, 'y2': 7855},
#   'verified_by_user': 'False'},
# ...
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788399),
#   'unique_identifier': '7b0e8205-f63b-4eb5-b329-68e0dc6b0670',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110630, 'x2': 110686, 'y1': 28520, 'y2': 28576},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755753,
#   'image': 10406,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788474),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788462),
#   'unique_identifier': '96be029d-8022-45f0-a200-22f89bf11a0e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110481, 'x2': 110537, 'y1': 42799, 'y2': 42855},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755754,
#   'image': 10406,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788525),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788513),
#   'unique_identifier': 'fd5151ff-ba52-4172-b2a7-bde980195c58',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 108873, 'x2': 108929, 'y1': 56573, 'y2': 56629},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755755,
#   'image': 10406,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788576),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788564),
#   'unique_identifier': 'ee1facfd-73f2-4597-b57f-1ab218a27f03',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 109763, 'x2': 109819, 'y1': 73674, 'y2': 73730},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755756,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788627),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788614),
#   'unique_identifier': 'c0fee0d4-22dd-4974-980d-d39625d80ee3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13538, 'x2': 13594, 'y1': 19226, 'y2': 19282},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755757,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788695),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788683),
#   'unique_identifier': 'd947744e-1e68-496e-bd5f-3facf06b0d6d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 11806, 'x2': 11862, 'y1': 36038, 'y2': 36094},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755758,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788748),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788735),
#   'unique_identifier': 'e7ad3cf8-6ccf-4cbe-8ea0-21d8022494fd',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10794, 'x2': 10850, 'y1': 55334, 'y2': 55390},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755759,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788841),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788828),
#   'unique_identifier': '5288fee0-d2f8-4083-9968-5e30f3c065f1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13497, 'x2': 13553, 'y1': 75508, 'y2': 75564},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755760,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788900),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788887),
#   'unique_identifier': '27223335-05f6-4862-83f6-0658bfc64746',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13226, 'x2': 13282, 'y1': 94106, 'y2': 94162},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755761,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788954),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788942),
#   'unique_identifier': '1f7e5640-595e-4511-9c05-e4b15939bd53',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 34629, 'x2': 34685, 'y1': 21454, 'y2': 21510},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755762,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789006),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 788994),
#   'unique_identifier': 'b3ef0d9d-1dcf-405d-a5d8-266bf55bfafc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 35000, 'x2': 35056, 'y1': 39111, 'y2': 39167},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755763,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789066),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789046),
#   'unique_identifier': 'fe8ac99d-b375-4290-8193-7ddc5441931c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 33909, 'x2': 33965, 'y1': 54374, 'y2': 54430},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755764,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789128),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789116),
#   'unique_identifier': '0417625e-7692-40ac-8e6a-796a1ffc179d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 35179, 'x2': 35235, 'y1': 75385, 'y2': 75441},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755765,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789179),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789166),
#   'unique_identifier': '7763ce6e-bae6-43d7-b51d-9a650aa55984',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 34872, 'x2': 34928, 'y1': 94665, 'y2': 94721},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755766,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789229),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789217),
#   'unique_identifier': '02fe76fe-741d-4b79-ad77-0f5a1d4cf9e9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 57050, 'x2': 57106, 'y1': 19422, 'y2': 19478},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755767,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789280),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789268),
#   'unique_identifier': '09cb79a0-24ec-4e26-aef5-1ad790068804',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56909, 'x2': 56965, 'y1': 37964, 'y2': 38020},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755768,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789330),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789318),
#   'unique_identifier': '92a1a88a-af51-4f3a-a54c-20a06e4e4817',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56650, 'x2': 56706, 'y1': 56697, 'y2': 56753},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755769,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789381),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789369),
#   'unique_identifier': 'bc4d0152-b4c0-47ae-870a-19b219dd2eb3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56742, 'x2': 56798, 'y1': 75682, 'y2': 75738},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755770,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789431),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789419),
#   'unique_identifier': '3d161424-7773-4183-8014-abf665d59862',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56696, 'x2': 56752, 'y1': 94100, 'y2': 94156},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755771,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789481),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789469),
#   'unique_identifier': '09738408-0fde-4807-b404-d278fa866abf',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 78444, 'x2': 78500, 'y1': 19249, 'y2': 19305},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755772,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789531),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789519),
#   'unique_identifier': '500487d3-7f20-4580-9bbc-3de23dc45afd',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 76727, 'x2': 76783, 'y1': 37718, 'y2': 37774},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755773,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789582),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789569),
#   'unique_identifier': '4232b8c5-1032-4e47-868f-3ace755b9ae8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 77791, 'x2': 77847, 'y1': 56564, 'y2': 56620},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755774,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789632),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789620),
#   'unique_identifier': '21c4bbb0-c310-48ba-9d94-e0c749f033f3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 79033, 'x2': 79089, 'y1': 75159, 'y2': 75215},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755775,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789683),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789670),
#   'unique_identifier': '3052bb34-91ae-4e18-951f-021e6c562592',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 78427, 'x2': 78483, 'y1': 94146, 'y2': 94202},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755776,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789734),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789722),
#   'unique_identifier': '25aa751c-06cf-463c-ace9-8397c567972b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 100159, 'x2': 100215, 'y1': 19594, 'y2': 19650},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755777,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789784),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789772),
#   'unique_identifier': '8a4bc90e-afd7-4a3a-8028-1a6c24ab97f8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 100130, 'x2': 100186, 'y1': 38184, 'y2': 38240},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755778,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789834),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789822),
#   'unique_identifier': 'edce5b71-592c-49f4-b70c-bf8f8faec9a0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 100060, 'x2': 100116, 'y1': 56599, 'y2': 56655},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755779,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789885),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789872),
#   'unique_identifier': 'cd11d8de-2fc8-48c1-9699-a4a86746c0fb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 100176, 'x2': 100232, 'y1': 75380, 'y2': 75436},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755780,
#   'image': 10403,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789935),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 17, 28, 56, 789923),
#   'unique_identifier': '444d96a3-d87b-4873-b6f2-2f31e18d6e41',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 100564, 'x2': 100620, 'y1': 94370, 'y2': 94426},
#   'verified_by_user': 'False'}]
