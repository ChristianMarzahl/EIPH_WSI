# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from pathlib import Path
import pandas as pd
from tqdm import tqdm
import json

# %%
from exact_sync.v1.api.annotations_api import AnnotationsApi
from exact_sync.v1.api.images_api import ImagesApi
from exact_sync.v1.api.image_sets_api import ImageSetsApi
from exact_sync.v1.api.annotation_types_api import AnnotationTypesApi
from exact_sync.v1.api.products_api import ProductsApi

from exact_sync.v1.models import ImageSet, Product, AnnotationType, Image, Annotation
from exact_sync.v1.rest import ApiException
from exact_sync.v1.configuration import Configuration
from exact_sync.v1.api_client import ApiClient

# %% [markdown]
# ## Connect to EXACT

# %%
configuration = Configuration()
configuration.username = 'marzahl' #'exact'
configuration.password = '###' #'exact'
configuration.host = "https://exact.cs.fau.de" #"http://127.0.0.1:8000"

client = ApiClient(configuration)

image_sets_api = ImageSetsApi(client)
annotations_api = AnnotationsApi(client)
annotation_types_api = AnnotationTypesApi(client)
images_api = ImagesApi(client)
product_api = ProductsApi(client)

# %% [markdown]
# ## Download Rect annotation

# %%
annotation_types_points = {}
annotation_types_ref_rect = None

for product in product_api.list_products(name="References").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id, name="BoundingBox").results:
        annotation_types_ref_rect = annotation_type
            
for product in product_api.list_products(name="Reference_Points").results:
    for annotation_type in annotation_types_api.list_annotation_types(product=product.id).results:
        annotation_types_points[annotation_type.name] = annotation_type

annotation_types_points
# Out:
# {'L0': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 384,
#   'name': 'L0',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L1': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 385,
#   'name': 'L1',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 1,
#   'vector_type': 1},
#  'L2': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 386,
#   'name': 'L2',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 2,
#   'vector_type': 1},
#  'L3': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 387,
#   'name': 'L3',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 3,
#   'vector_type': 1},
#  'L4': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF0000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 388,
#   'name': 'L4',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 4,
#   'vector_type': 1},
#  'L5': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 389,
#   'name': 'L5',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 5,
#   'vector_type': 1},
#  'L6': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 393,
#   'name': 'L6',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 6,
#   'vector_type': 1},
#  'L7': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 394,
#   'name': 'L7',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 7,
#   'vector_type': 1},
#  'L8': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 395,
#   'name': 'L8',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 8,
#   'vector_type': 1},
#  'L9': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#0000FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 396,
#   'name': 'L9',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 9,
#   'vector_type': 1},
#  'L10': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 397,
#   'name': 'L10',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 10,
#   'vector_type': 1},
#  'L11': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 398,
#   'name': 'L11',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 11,
#   'vector_type': 1},
#  'L12': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 399,
#   'name': 'L12',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L13': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 400,
#   'name': 'L13',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L14': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FFFF00',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 401,
#   'name': 'L14',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L15': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 402,
#   'name': 'L15',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L16': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 403,
#   'name': 'L16',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L17': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 404,
#   'name': 'L17',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L18': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 405,
#   'name': 'L18',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L19': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#FF00FF',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 406,
#   'name': 'L19',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L20': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 407,
#   'name': 'L20',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L21': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 408,
#   'name': 'L21',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L22': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 409,
#   'name': 'L22',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L23': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 410,
#   'name': 'L23',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1},
#  'L24': {'area_hit_test': True,
#   'closed': True,
#   'color_code': '#008000',
#   'default_height': 50,
#   'default_width': 50,
#   'enable_blurred': False,
#   'enable_concealed': False,
#   'id': 411,
#   'name': 'L24',
#   'node_count': 0,
#   'product': 104,
#   'sort_order': 0,
#   'vector_type': 1}}

# %%
annotation_types_ref_rect
# Out:
# {'area_hit_test': False,
#  'closed': True,
#  'color_code': '#FF0000',
#  'default_height': 5000,
#  'default_width': 5000,
#  'enable_blurred': False,
#  'enable_concealed': False,
#  'id': 412,
#  'name': 'BoundingBox',
#  'node_count': 0,
#  'product': 105,
#  'sort_order': 0,
#  'vector_type': 1}

# %%
annotations = []

image_set = image_sets_api.list_image_sets(name="CCMCT_Aperio", expand="product_set,product_set.annotationtype_set").results[0]


for image_id in image_set.images:
    
    image = images_api.retrieve_image(id=image_id)
    
    for anno in annotations_api.list_annotations(image=image_id, annotation_type=annotation_types_ref_rect.id, # BoundBox ID
                                                 deleted=False, fields="annotation_type,id,image,vector,unique_identifier").results:
        
        annotations.append([image.id, image.name, anno.id, anno.vector, anno.unique_identifier, anno.annotation_type])
        
annotations = pd.DataFrame(annotations, columns=["image_id", "image_name", "id", "vector", "unique_identifier", "annotation_type"])
annotations.head()
# Out:
#    image_id             image_name       id  \
# 0     10416  A_CCMCT_518711B_1.svs  2754780
# 1     10415  A_CCMCT_380609B_1.svs  2754776
# 2     10401  A_CCMCT_183715A_1.svs  2754779
# 3     10399   A_CCMCT_29609B_1.svs  2754778
# 4     10398    A_CCMCT_22108_1.svs  2754777
#
#                                               vector  \
# 0  {'x1': 2286, 'x2': 105081, 'y1': 2658, 'y2': 8...
# 1  {'x1': 3384, 'x2': 122851, 'y1': 3932, 'y2': 8...
# 2  {'x1': 2795, 'x2': 74520, 'y1': 1848, 'y2': 64...
# 3  {'x1': 15671, 'x2': 61564, 'y1': 3806, 'y2': 6...
# 4  {'x1': 3516, 'x2': 97828, 'y1': 3382, 'y2': 85...
#
#                       unique_identifier  annotation_type
# 0  4dc7b8b1-9f22-459c-aea8-5b6a4c3ea550              412
# 1  9ed713ff-9533-40bd-bbcf-dd63c9c4b674              412
# 2  d630bd0a-94af-4ebb-b44b-a4a548b391d1              412
# 3  94970f48-cebb-4874-9211-38e408592a13              412
# 4  a41f016f-02fb-40da-af8d-b99fb1c8686d              412

# %% [markdown]
# ## Load GT and find closest point

# %%
Path("../../CCMCT/CCMCT.csv").exists()
# Out:
# True

# %%
df = pd.read_csv("../../CCMCT/CCMCT.csv", delimiter=";", names=["image_name", "grade", "vector"])
df["vector"] = [json.loads(vector)  for vector in df["vector"]]

df["x1"] = [vector['x1'] if type(vector) is dict else 0 for vector in df["vector"]]
df["y1"] = [vector['y1'] if type(vector) is dict else 0 for vector in df["vector"]]

df["x2"] = [vector['x2'] if type(vector) is dict else 0 for vector in df["vector"]]
df["y2"] = [vector['y2'] if type(vector) is dict else 0 for vector in df["vector"]]

df["center_x"] = [x1 + ((x2-x1) / 2) for x1, x2 in zip(df["x1"], df["x2"])]
df["center_y"] = [y1 + ((y2-y1) / 2) for y1, y2 in zip(df["y1"], df["y2"])]

df["anno_width"] = [x2-x1 for x1, x2 in zip(df["x1"], df["x2"])]
df["anno_height"]= [y2-y1 for y1, y2 in zip(df["y1"], df["y2"])]

df.head()
# Out:
#              image_name    grade  \
# 0  A_CCMCT_29609B_1.svs  mitosis
# 1  A_CCMCT_29609B_1.svs  mitosis
# 2  A_CCMCT_29609B_1.svs  mitosis
# 3  A_CCMCT_29609B_1.svs  mitosis
# 4  A_CCMCT_29609B_1.svs  mitosis
#
#                                               vector     x1     y1     x2  \
# 0  {'x1': 57204, 'y1': 28229, 'x2': 57254, 'y2': ...  57204  28229  57254
# 1  {'x1': 57895, 'y1': 37440, 'x2': 57945, 'y2': ...  57895  37440  57945
# 2  {'x1': 54810, 'y1': 37131, 'x2': 54860, 'y2': ...  54810  37131  54860
# 3  {'x1': 54575, 'y1': 34537, 'x2': 54625, 'y2': ...  54575  34537  54625
# 4  {'x1': 47883, 'y1': 28677, 'x2': 47933, 'y2': ...  47883  28677  47933
#
#       y2  center_x  center_y  anno_width  anno_height
# 0  28279   57229.0   28254.0          50           50
# 1  37490   57920.0   37465.0          50           50
# 2  37181   54835.0   37156.0          50           50
# 3  34587   54600.0   34562.0          50           50
# 4  28727   47908.0   28702.0          50           50

# %%
temp
# Out:
# Empty DataFrame
# Columns: [image_name, grade, vector, x1, y1, x2, y2, center_x, center_y, anno_width, anno_height]
# Index: []

# %%
num_lines = 5
patch_size = 25
search_point_radius = 0.15

registration_points = []
for id, bounding_box in annotations.iterrows():
    
    df_gt = df[df["image_name"].str.contains(bounding_box.image_name.split("_")[-2])]
    
    box_width = bounding_box.vector["x2"] - bounding_box.vector["x1"]
    box_height = bounding_box.vector["y2"] - bounding_box.vector["y1"]
    
    step_size_x = box_width // num_lines
    step_size_y = box_height // num_lines
    
    gt_search_point_radius = int(step_size_x * search_point_radius)
    
    point_index = 0
    for x in range(bounding_box.vector["x1"] + step_size_x //2, bounding_box.vector["x2"], step_size_x):
        for y in range(bounding_box.vector["y1"] + step_size_y //2, bounding_box.vector["y2"], step_size_y):
            
            ref_point = annotation_types_points[f"L{point_index}"]
            
            point = None
            # find closest annotation in range
            temp = df_gt[(df_gt["center_x"] > x - gt_search_point_radius) & 
                          (df_gt["center_x"] < x + gt_search_point_radius) & 
                          (df_gt["center_y"] > y - gt_search_point_radius) & 
                          (df_gt["center_y"] < y + gt_search_point_radius)].copy()
            
            if len(temp) > 0:
                temp["distance"] = [abs(cx - x) + abs(cy - y) for cx, cy in zip(temp["center_x"], temp["center_y"])]
                temp = temp.sort_values(by=["distance"], ascending=[True])

                for uuid, gt_anno in temp.iterrows():

                    vector = {"x1": gt_anno.vector["x1"], "y1": gt_anno.vector["y1"], 
                              "x2": gt_anno.vector["x2"], "y2": gt_anno.vector["y2"]}


                    point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id]
                    break
            
            if point is None: # No ref point found
                
                vector = {"x1": x - patch_size, "y1": y - patch_size, 
                          "x2": x + patch_size, "y2": y + patch_size}
                
                point = [bounding_box.image_id, vector, point_index, ref_point.name, ref_point.id]
                
            registration_points.append(point)
                
            point_index += 1
    
registration_points = pd.DataFrame(registration_points, 
                                   columns=["image_id", "vector", "point_index", "point_name", "point_id"])
registration_points
# Out:
#      image_id                                             vector  point_index  \
# 0       10416  {'x1': 12540, 'y1': 10554, 'x2': 12590, 'y2': ...            0
# 1       10416  {'x1': 15549, 'y1': 25719, 'x2': 15599, 'y2': ...            1
# 2       10416  {'x1': 13378, 'y1': 42978, 'x2': 13428, 'y2': ...            2
# 3       10416  {'x1': 12126, 'y1': 58187, 'x2': 12176, 'y2': ...            3
# 4       10416  {'x1': 13407, 'y1': 71707, 'x2': 13457, 'y2': ...            4
# ..        ...                                                ...          ...
# 120     10398  {'x1': 88370, 'y1': 11524, 'x2': 88420, 'y2': ...           20
# 121     10398  {'x1': 88370, 'y1': 27859, 'x2': 88420, 'y2': ...           21
# 122     10398  {'x1': 88370, 'y1': 44194, 'x2': 88420, 'y2': ...           22
# 123     10398  {'x1': 88370, 'y1': 60529, 'x2': 88420, 'y2': ...           23
# 124     10398  {'x1': 88370, 'y1': 76864, 'x2': 88420, 'y2': ...           24
#
#     point_name  point_id
# 0           L0       384
# 1           L1       385
# 2           L2       386
# 3           L3       387
# 4           L4       388
# ..         ...       ...
# 120        L20       407
# 121        L21       408
# 122        L22       409
# 123        L23       410
# 124        L24       411
#
# [125 rows x 5 columns]

# %% [markdown]
# ## Upload ref Points to EXACT

# %%
annotations_to_upload = []

for id, bounding_box in tqdm(registration_points.iterrows()):
    
    
    exact_annos =  annotations_api.list_annotations(image=bounding_box.image_id, annotation_type=bounding_box.point_id).results
    
    if len(exact_annos) == 0:
        anno = Annotation(annotation_type=bounding_box.point_id, 
                          vector=bounding_box.vector, 
                          image=bounding_box.image_id)

        annotations_to_upload.append(anno)

    else:
        prinf(f"ImageId: {bounding_box.image_id}, AnnotationType: {bounding_box.point_id} combination allready exists!")
# Out:
# 125it [00:24,  5.09it/s]

# %%
annotations_to_upload[:3]
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10416,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 12540, 'x2': 12590, 'y1': 10554, 'y2': 10604},
#   'verified_by_user': None},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10416,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 15549, 'x2': 15599, 'y1': 25719, 'y2': 25769},
#   'verified_by_user': None},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': None,
#   'concealed': None,
#   'deleted': None,
#   'description': None,
#   'id': None,
#   'image': 10416,
#   'last_edit_time': None,
#   'last_editor': None,
#   'meta_data': None,
#   'time': None,
#   'unique_identifier': None,
#   'uploaded_media_files': [],
#   'user': None,
#   'vector': {'x1': 13378, 'x2': 13428, 'y1': 42978, 'y2': 43028},
#   'verified_by_user': None}]

# %% [markdown]
# ## Check that no error occurred and afterwards upload annotations

# %%
#annotations_api.create_annotation(body=annotations_to_upload)
# Out:
# [{'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755281,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572334),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572309),
#   'unique_identifier': 'ca3fde15-30ed-45bd-bd58-00aadf29eba9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12540, 'x2': 12590, 'y1': 10554, 'y2': 10604},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755282,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572395),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572382),
#   'unique_identifier': '0acc9849-e7aa-4657-8055-bb7e8b4a31e0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15549, 'x2': 15599, 'y1': 25719, 'y2': 25769},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755283,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572444),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572432),
#   'unique_identifier': 'e44ca58f-3316-4d02-b6b1-1d44f2664682',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13378, 'x2': 13428, 'y1': 42978, 'y2': 43028},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755284,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572492),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572479),
#   'unique_identifier': '99a54973-1bf3-4cbc-a55b-a09b62e0e38f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12126, 'x2': 12176, 'y1': 58187, 'y2': 58237},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755285,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572539),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572527),
#   'unique_identifier': 'ecc654b9-910b-4792-955b-52070dbff958',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 13407, 'x2': 13457, 'y1': 71707, 'y2': 71757},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755286,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572586),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572574),
#   'unique_identifier': '57d03dc4-c56d-4ed1-b8c2-9577ae180fc2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32291, 'x2': 32341, 'y1': 11842, 'y2': 11892},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755287,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572634),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572621),
#   'unique_identifier': 'eeebc67f-e541-4261-a0e5-7bd5a7ded8ec',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 33032, 'x2': 33082, 'y1': 26583, 'y2': 26633},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755288,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572681),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572668),
#   'unique_identifier': 'd2744f71-bd4b-4371-89b5-c9a4b10f8327',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 32489, 'x2': 32539, 'y1': 41752, 'y2': 41802},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755289,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572728),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572716),
#   'unique_identifier': 'efd11d62-ada1-4374-bd9b-36340963f989',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 35008, 'x2': 35058, 'y1': 58323, 'y2': 58373},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755290,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572776),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572763),
#   'unique_identifier': 'af85e94b-f67d-45eb-9db7-99b9ff192aed',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30667, 'x2': 30717, 'y1': 76404, 'y2': 76454},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755291,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572823),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572811),
#   'unique_identifier': '95997877-d9a2-4f48-9562-1bde8adef701',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53818, 'x2': 53868, 'y1': 10208, 'y2': 10258},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755292,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572871),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572858),
#   'unique_identifier': '0dca7206-5161-40dc-bf01-766eadbf3411',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53159, 'x2': 53209, 'y1': 26235, 'y2': 26285},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755293,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572918),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572905),
#   'unique_identifier': 'db7627b7-a7c0-4e6a-9fc4-82f054d2cc1b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53250, 'x2': 53300, 'y1': 42134, 'y2': 42184},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755294,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572965),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 572952),
#   'unique_identifier': '1c59ff23-d5d9-45f2-b1ef-ced165b6d072',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53581, 'x2': 53631, 'y1': 57849, 'y2': 57899},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755295,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573029),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573016),
#   'unique_identifier': '87d95aa9-5a07-4b09-8cf7-f120dc556c0d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53314, 'x2': 53364, 'y1': 73785, 'y2': 73835},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755296,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573093),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573080),
#   'unique_identifier': '3020e9c6-e93f-4d03-b338-571bb3fe909b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 72626, 'x2': 72676, 'y1': 13103, 'y2': 13153},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755297,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573142),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573130),
#   'unique_identifier': '5559ba61-2423-49fd-9a92-b5d85e92fca1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 73929, 'x2': 73979, 'y1': 26522, 'y2': 26572},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755298,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573191),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573178),
#   'unique_identifier': 'eb658d9d-dbff-41e4-9a6a-b35613780e6c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 74217, 'x2': 74267, 'y1': 42231, 'y2': 42281},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755299,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573240),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573227),
#   'unique_identifier': '7c93830b-8ab8-4e8b-8cd9-2fe23d1dd0c1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 74459, 'x2': 74509, 'y1': 58145, 'y2': 58195},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755300,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573289),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573276),
#   'unique_identifier': '6f516672-cf75-4e16-8eb1-2803ad9781a3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 74046, 'x2': 74096, 'y1': 73731, 'y2': 73781},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755301,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573337),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573325),
#   'unique_identifier': 'efbb7806-adfc-4f92-be3a-208391499fc1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 94776, 'x2': 94826, 'y1': 10554, 'y2': 10604},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755302,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573386),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573373),
#   'unique_identifier': '730e83bf-4247-485f-9d77-b3b4f37268b8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 94776, 'x2': 94826, 'y1': 26397, 'y2': 26447},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755303,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573435),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573422),
#   'unique_identifier': '040473b7-3fe9-4861-aea7-006f2ffebccc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 94856, 'x2': 94906, 'y1': 42206, 'y2': 42256},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755304,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573484),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573471),
#   'unique_identifier': '56eb2484-b791-4816-bca7-0285e2cbc3ba',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 94688, 'x2': 94738, 'y1': 58383, 'y2': 58433},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755305,
#   'image': 10416,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573532),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573519),
#   'unique_identifier': '669f91cf-9df7-4867-a73f-27c89d6dd91b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 95200, 'x2': 95250, 'y1': 73984, 'y2': 74034},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755306,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573581),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573568),
#   'unique_identifier': '95183f6e-0a00-4de4-9c97-fedfec655a27',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15305, 'x2': 15355, 'y1': 12297, 'y2': 12347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755307,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573630),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573617),
#   'unique_identifier': 'cc3def2b-5631-4619-ab08-51f2a69c667d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15305, 'x2': 15355, 'y1': 29078, 'y2': 29128},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755308,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573678),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573666),
#   'unique_identifier': '2d3de917-e55a-470f-8af2-10eb49b69687',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15428, 'x2': 15478, 'y1': 45817, 'y2': 45867},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755309,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573727),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573714),
#   'unique_identifier': '611f9d35-6cdb-42ef-bc38-2f44c9aaa257',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15305, 'x2': 15355, 'y1': 62640, 'y2': 62690},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755310,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573776),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573763),
#   'unique_identifier': 'bf3ef0d3-5153-4693-96ba-96047cb3ae24',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 15305, 'x2': 15355, 'y1': 79421, 'y2': 79471},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755311,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573825),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573812),
#   'unique_identifier': 'e0765891-b4ff-4eec-9443-77a37c32ae76',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 39198, 'x2': 39248, 'y1': 12297, 'y2': 12347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755312,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573874),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573861),
#   'unique_identifier': '2331e98a-3cd0-44c5-bf5a-a57ce20d37f2',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 40656, 'x2': 40706, 'y1': 28876, 'y2': 28926},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755313,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573923),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573910),
#   'unique_identifier': 'a7a9941f-7307-4276-9017-22828fc8013c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 35981, 'x2': 36031, 'y1': 46010, 'y2': 46060},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755314,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573971),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 573958),
#   'unique_identifier': '7d35c9a8-6f0b-4fb8-ac47-fbb8352eb0c3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 39772, 'x2': 39822, 'y1': 63584, 'y2': 63634},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755315,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574020),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574007),
#   'unique_identifier': 'e1dfa3c3-28bc-4d12-9a3a-37b3b77746bc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 38183, 'x2': 38233, 'y1': 79297, 'y2': 79347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755316,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574069),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574056),
#   'unique_identifier': '4a65486b-11af-4e75-bf9a-cb1dea43c15f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 63091, 'x2': 63141, 'y1': 12297, 'y2': 12347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755317,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574118),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574105),
#   'unique_identifier': 'ce71cdb5-5764-46a8-925b-b436bdbfd1df',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 62391, 'x2': 62441, 'y1': 29457, 'y2': 29507},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755318,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574167),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574154),
#   'unique_identifier': 'f06e8946-1679-448a-a743-c40deafed44c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 62079, 'x2': 62129, 'y1': 46323, 'y2': 46373},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755319,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574217),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574204),
#   'unique_identifier': '5956fa92-834c-4e96-80ab-d5ed4a923214',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 61794, 'x2': 61844, 'y1': 61178, 'y2': 61228},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755320,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574266),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574253),
#   'unique_identifier': '6056cfea-067e-4cb9-8aae-9fb8d4becbcb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 63079, 'x2': 63129, 'y1': 81230, 'y2': 81280},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755321,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574315),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574302),
#   'unique_identifier': 'd896ff6b-9d95-4316-affb-af36ff0cc3b7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 86984, 'x2': 87034, 'y1': 12297, 'y2': 12347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755322,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574364),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574351),
#   'unique_identifier': 'f3115c15-ff56-4ecf-8039-2f019ca02327',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 86984, 'x2': 87034, 'y1': 29078, 'y2': 29128},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755323,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574412),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574399),
#   'unique_identifier': '6c920499-c9bf-4277-b382-d916332da5d7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 87157, 'x2': 87207, 'y1': 47833, 'y2': 47883},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755324,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574461),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574448),
#   'unique_identifier': '5cc4e10f-74af-41c6-adf1-f9427b1f3299',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 89314, 'x2': 89364, 'y1': 62696, 'y2': 62746},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755325,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574509),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574497),
#   'unique_identifier': 'b17e8936-7b87-4ccc-a613-af57183a2cf5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 88353, 'x2': 88403, 'y1': 79670, 'y2': 79720},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755326,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574558),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574545),
#   'unique_identifier': '1f8ca805-a23e-4eec-8aad-8bec244fc890',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110877, 'x2': 110927, 'y1': 12297, 'y2': 12347},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755327,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574606),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574593),
#   'unique_identifier': 'bd460419-2e47-46c5-8112-b5cdaed66178',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110877, 'x2': 110927, 'y1': 29078, 'y2': 29128},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755328,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574656),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574643),
#   'unique_identifier': '58f2c103-e029-4064-bb67-c7807eafa68f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110877, 'x2': 110927, 'y1': 45859, 'y2': 45909},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755329,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574705),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574692),
#   'unique_identifier': 'd7a95146-a971-49f5-a2e6-b85d891dc551',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110877, 'x2': 110927, 'y1': 62640, 'y2': 62690},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755330,
#   'image': 10415,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574753),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574740),
#   'unique_identifier': 'bf487559-bfca-4a98-abb4-15e963f25aa5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 110877, 'x2': 110927, 'y1': 79421, 'y2': 79471},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755331,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574802),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574789),
#   'unique_identifier': '45e2d88d-8211-419b-a754-6d71dd317ec5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9942, 'x2': 9992, 'y1': 8050, 'y2': 8100},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755332,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574851),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574838),
#   'unique_identifier': 'ff307a78-11ec-4a05-b8c8-ad90a2cb18ed',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10295, 'x2': 10345, 'y1': 20157, 'y2': 20207},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755333,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574900),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574887),
#   'unique_identifier': 'ee578e27-99c4-4ab9-a10a-0a19fd58f4fa',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9130, 'x2': 9180, 'y1': 32877, 'y2': 32927},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755334,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574949),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574936),
#   'unique_identifier': '27f6e3b9-8627-414a-b6d8-b8e111031d54',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9261, 'x2': 9311, 'y1': 44434, 'y2': 44484},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755335,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575005),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 574992),
#   'unique_identifier': '3241e205-68af-44c2-af0c-f88461410510',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 9942, 'x2': 9992, 'y1': 57870, 'y2': 57920},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755336,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575054),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575041),
#   'unique_identifier': '212779a8-3d64-4ea3-a604-a7f775bb4d0f',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24119, 'x2': 24169, 'y1': 8310, 'y2': 8360},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755337,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575104),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575091),
#   'unique_identifier': 'c0da107c-1f64-4aea-992e-b513a57fd86c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24575, 'x2': 24625, 'y1': 21129, 'y2': 21179},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755338,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575153),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575140),
#   'unique_identifier': 'a0a485c6-7512-4cc7-9262-55d83c5d5eec',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24883, 'x2': 24933, 'y1': 33105, 'y2': 33155},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755339,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575202),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575189),
#   'unique_identifier': '0a36744e-fffa-4cbb-a9ed-e7c0e672ebcf',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24683, 'x2': 24733, 'y1': 45552, 'y2': 45602},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755340,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575252),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575239),
#   'unique_identifier': '23cbcc46-f1f1-4675-a3a8-e491402fcae1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 24287, 'x2': 24337, 'y1': 57870, 'y2': 57920},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755341,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575301),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575288),
#   'unique_identifier': 'd9e54ded-a295-4a96-877b-a56df0d9ef42',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 38231, 'x2': 38281, 'y1': 8046, 'y2': 8096},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755342,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575350),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575337),
#   'unique_identifier': 'c9772f33-ed8e-44de-9916-53b9f127484a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 38718, 'x2': 38768, 'y1': 20461, 'y2': 20511},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755343,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575398),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575386),
#   'unique_identifier': '0de8d67c-c163-4c50-a07f-e1ce75265a01',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 38632, 'x2': 38682, 'y1': 32960, 'y2': 33010},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755344,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575447),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575434),
#   'unique_identifier': 'e6ca2e79-51b2-4c76-9a85-72ae119f57cd',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 37942, 'x2': 37992, 'y1': 45430, 'y2': 45480},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755345,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575496),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575483),
#   'unique_identifier': '6ca099dd-0c1b-4ba2-bbf8-09f5719afdba',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 37719, 'x2': 37769, 'y1': 57539, 'y2': 57589},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755346,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575545),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575532),
#   'unique_identifier': 'f4d845f3-bc78-4d9d-9ec4-80c0a9a15d8e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 52898, 'x2': 52948, 'y1': 9505, 'y2': 9555},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755347,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575593),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575580),
#   'unique_identifier': '6e5470c0-7c72-4c5f-b074-bba46709b0fb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53357, 'x2': 53407, 'y1': 20937, 'y2': 20987},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755348,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575641),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575629),
#   'unique_identifier': 'dac979c3-8b83-49bb-8e9c-c98f425e01cf',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 52740, 'x2': 52790, 'y1': 31656, 'y2': 31706},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755349,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575690),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575677),
#   'unique_identifier': '91f2e56a-4d14-48c2-8def-56fbe7d907c3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53281, 'x2': 53331, 'y1': 45208, 'y2': 45258},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755350,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575739),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575727),
#   'unique_identifier': '701c7cc9-044c-438d-8b5c-99476df7de08',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 53428, 'x2': 53478, 'y1': 56641, 'y2': 56691},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755351,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575788),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575776),
#   'unique_identifier': '294c4a75-4ba2-444f-9792-8f4ba22549c5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 67322, 'x2': 67372, 'y1': 8050, 'y2': 8100},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755352,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575837),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575824),
#   'unique_identifier': '20a2bf26-907a-467b-b564-de2cf22d0ad3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 67780, 'x2': 67830, 'y1': 20138, 'y2': 20188},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755353,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575886),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575873),
#   'unique_identifier': '0e26c28e-76b6-4750-8a52-9bbf9f2fa91b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 65447, 'x2': 65497, 'y1': 33755, 'y2': 33805},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755354,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575936),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575923),
#   'unique_identifier': '8930d408-58fb-4e63-88a6-318e75a709a9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 67322, 'x2': 67372, 'y1': 45415, 'y2': 45465},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755355,
#   'image': 10401,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575985),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 575972),
#   'unique_identifier': '5cf1a3f9-8cbc-4170-9b24-688be640358b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 67322, 'x2': 67372, 'y1': 57870, 'y2': 57920},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755356,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576035),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576022),
#   'unique_identifier': '926ce459-6588-4735-9ca0-00dbef58a1f7',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20235, 'x2': 20285, 'y1': 9937, 'y2': 9987},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755357,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576095),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576071),
#   'unique_identifier': '20430e9a-e2cb-480c-b184-fefa76c3a60b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20235, 'x2': 20285, 'y1': 22249, 'y2': 22299},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755358,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576143),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576131),
#   'unique_identifier': '02b4dbec-4681-4920-a2ee-8bbb1caf40dc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20235, 'x2': 20285, 'y1': 34561, 'y2': 34611},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755359,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576191),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576179),
#   'unique_identifier': 'de5944fc-6c1e-4084-9ccb-55ed0452a81c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 21532, 'x2': 21582, 'y1': 47487, 'y2': 47537},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755360,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576238),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576226),
#   'unique_identifier': 'c76f4470-f927-4499-8764-0f6e46c6fd68',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 20235, 'x2': 20285, 'y1': 59185, 'y2': 59235},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755361,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576286),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576273),
#   'unique_identifier': 'e609a629-5c08-435a-96b1-2098cffdc361',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30501, 'x2': 30551, 'y1': 9903, 'y2': 9953},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755362,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576333),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576320),
#   'unique_identifier': '121b5aa0-4b9e-4460-9af3-106e0b90a47a',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 29155, 'x2': 29205, 'y1': 21313, 'y2': 21363},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755363,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576380),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576368),
#   'unique_identifier': '2c24d90c-4799-4090-badc-f4773420b6f5',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 29413, 'x2': 29463, 'y1': 34561, 'y2': 34611},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755364,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576427),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576415),
#   'unique_identifier': 'c3efde27-3eee-4bc0-9a95-aa2352a185be',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 29494, 'x2': 29544, 'y1': 47890, 'y2': 47940},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755365,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576474),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576462),
#   'unique_identifier': 'e44d5208-96b1-4545-b994-bc81b4c6f7ae',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 29413, 'x2': 29463, 'y1': 59185, 'y2': 59235},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755366,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576521),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 576508),
#   'unique_identifier': 'cfad2fe3-fae0-495d-8ed3-57d9e70a8dc3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 37883, 'x2': 37933, 'y1': 10091, 'y2': 10141},
#   'verified_by_user': 'False'},
# ...
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577046),
#   'unique_identifier': '7b0e8205-f63b-4eb5-b329-68e0dc6b0670',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56947, 'x2': 56997, 'y1': 22249, 'y2': 22299},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755378,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577117),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577104),
#   'unique_identifier': '96be029d-8022-45f0-a200-22f89bf11a0e',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56947, 'x2': 56997, 'y1': 34561, 'y2': 34611},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755379,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577167),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577154),
#   'unique_identifier': 'fd5151ff-ba52-4172-b2a7-bde980195c58',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56947, 'x2': 56997, 'y1': 46873, 'y2': 46923},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755380,
#   'image': 10399,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577217),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577204),
#   'unique_identifier': 'ee1facfd-73f2-4597-b57f-1ab218a27f03',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 56947, 'x2': 56997, 'y1': 59185, 'y2': 59235},
#   'verified_by_user': 'False'},
#  {'annotation_type': 384,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755381,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577266),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577253),
#   'unique_identifier': 'c0fee0d4-22dd-4974-980d-d39625d80ee3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12922, 'x2': 12972, 'y1': 11524, 'y2': 11574},
#   'verified_by_user': 'False'},
#  {'annotation_type': 385,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755382,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577316),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577303),
#   'unique_identifier': 'd947744e-1e68-496e-bd5f-3facf06b0d6d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 11438, 'x2': 11488, 'y1': 26171, 'y2': 26221},
#   'verified_by_user': 'False'},
#  {'annotation_type': 386,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755383,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577365),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577352),
#   'unique_identifier': 'e7ad3cf8-6ccf-4cbe-8ea0-21d8022494fd',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 10565, 'x2': 10615, 'y1': 43003, 'y2': 43053},
#   'verified_by_user': 'False'},
#  {'annotation_type': 387,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755384,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577414),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577401),
#   'unique_identifier': '5288fee0-d2f8-4083-9968-5e30f3c065f1',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12922, 'x2': 12972, 'y1': 60529, 'y2': 60579},
#   'verified_by_user': 'False'},
#  {'annotation_type': 388,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755385,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577463),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577450),
#   'unique_identifier': '27223335-05f6-4862-83f6-0658bfc64746',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 12922, 'x2': 12972, 'y1': 76864, 'y2': 76914},
#   'verified_by_user': 'False'},
#  {'annotation_type': 389,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755386,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577512),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577499),
#   'unique_identifier': '1f7e5640-595e-4511-9c05-e4b15939bd53',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31319, 'x2': 31369, 'y1': 13452, 'y2': 13502},
#   'verified_by_user': 'False'},
#  {'annotation_type': 393,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755387,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577561),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577548),
#   'unique_identifier': 'b3ef0d9d-1dcf-405d-a5d8-266bf55bfafc',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31651, 'x2': 31701, 'y1': 28858, 'y2': 28908},
#   'verified_by_user': 'False'},
#  {'annotation_type': 394,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755388,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577610),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577597),
#   'unique_identifier': 'fe8ac99d-b375-4290-8193-7ddc5441931c',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 30709, 'x2': 30759, 'y1': 42167, 'y2': 42217},
#   'verified_by_user': 'False'},
#  {'annotation_type': 395,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755389,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577659),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577646),
#   'unique_identifier': '0417625e-7692-40ac-8e6a-796a1ffc179d',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31784, 'x2': 31834, 'y1': 60529, 'y2': 60579},
#   'verified_by_user': 'False'},
#  {'annotation_type': 396,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755390,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577708),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577695),
#   'unique_identifier': '7763ce6e-bae6-43d7-b51d-9a650aa55984',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 31784, 'x2': 31834, 'y1': 76864, 'y2': 76914},
#   'verified_by_user': 'False'},
#  {'annotation_type': 397,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755391,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577757),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577744),
#   'unique_identifier': '02fe76fe-741d-4b79-ad77-0f5a1d4cf9e9',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 50646, 'x2': 50696, 'y1': 11524, 'y2': 11574},
#   'verified_by_user': 'False'},
#  {'annotation_type': 398,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755392,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577825),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577811),
#   'unique_identifier': '09cb79a0-24ec-4e26-aef5-1ad790068804',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 50646, 'x2': 50696, 'y1': 27859, 'y2': 27909},
#   'verified_by_user': 'False'},
#  {'annotation_type': 399,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755393,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577878),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577864),
#   'unique_identifier': '92a1a88a-af51-4f3a-a54c-20a06e4e4817',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 50646, 'x2': 50696, 'y1': 44194, 'y2': 44244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 400,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755394,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577930),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577917),
#   'unique_identifier': 'bc4d0152-b4c0-47ae-870a-19b219dd2eb3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 50646, 'x2': 50696, 'y1': 60529, 'y2': 60579},
#   'verified_by_user': 'False'},
#  {'annotation_type': 401,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755395,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577989),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 577969),
#   'unique_identifier': '3d161424-7773-4183-8014-abf665d59862',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 50646, 'x2': 50696, 'y1': 76864, 'y2': 76914},
#   'verified_by_user': 'False'},
#  {'annotation_type': 402,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755396,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578042),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578028),
#   'unique_identifier': '09738408-0fde-4807-b404-d278fa866abf',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 69508, 'x2': 69558, 'y1': 11524, 'y2': 11574},
#   'verified_by_user': 'False'},
#  {'annotation_type': 403,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755397,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578095),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578081),
#   'unique_identifier': '500487d3-7f20-4580-9bbc-3de23dc45afd',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 69508, 'x2': 69558, 'y1': 27859, 'y2': 27909},
#   'verified_by_user': 'False'},
#  {'annotation_type': 404,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755398,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578148),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578134),
#   'unique_identifier': '4232b8c5-1032-4e47-868f-3ace755b9ae8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 69508, 'x2': 69558, 'y1': 44194, 'y2': 44244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 405,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755399,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578211),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578198),
#   'unique_identifier': '21c4bbb0-c310-48ba-9d94-e0c749f033f3',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 70039, 'x2': 70089, 'y1': 60303, 'y2': 60353},
#   'verified_by_user': 'False'},
#  {'annotation_type': 406,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755400,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578260),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578247),
#   'unique_identifier': '3052bb34-91ae-4e18-951f-021e6c562592',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 69508, 'x2': 69558, 'y1': 76864, 'y2': 76914},
#   'verified_by_user': 'False'},
#  {'annotation_type': 407,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755401,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578309),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578297),
#   'unique_identifier': '25aa751c-06cf-463c-ace9-8397c567972b',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 88370, 'x2': 88420, 'y1': 11524, 'y2': 11574},
#   'verified_by_user': 'False'},
#  {'annotation_type': 408,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755402,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578369),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578356),
#   'unique_identifier': '8a4bc90e-afd7-4a3a-8028-1a6c24ab97f8',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 88370, 'x2': 88420, 'y1': 27859, 'y2': 27909},
#   'verified_by_user': 'False'},
#  {'annotation_type': 409,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755403,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578416),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578404),
#   'unique_identifier': 'edce5b71-592c-49f4-b70c-bf8f8faec9a0',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 88370, 'x2': 88420, 'y1': 44194, 'y2': 44244},
#   'verified_by_user': 'False'},
#  {'annotation_type': 410,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755404,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578464),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578451),
#   'unique_identifier': 'cd11d8de-2fc8-48c1-9699-a4a86746c0fb',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 88370, 'x2': 88420, 'y1': 60529, 'y2': 60579},
#   'verified_by_user': 'False'},
#  {'annotation_type': 411,
#   'annotationversion_set': [],
#   'blurred': 'False',
#   'concealed': 'False',
#   'deleted': False,
#   'description': '',
#   'id': 2755405,
#   'image': 10398,
#   'last_edit_time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578511),
#   'last_editor': 1,
#   'meta_data': None,
#   'time': datetime.datetime(2021, 1, 10, 16, 56, 54, 578499),
#   'unique_identifier': '444d96a3-d87b-4873-b6f2-2f31e18d6e41',
#   'uploaded_media_files': [],
#   'user': 1,
#   'vector': {'x1': 88370, 'x2': 88420, 'y1': 76864, 'y2': 76914},
#   'verified_by_user': 'False'}]
